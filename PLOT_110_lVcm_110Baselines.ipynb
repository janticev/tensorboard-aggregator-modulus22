# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

variablesKey = 'Validators'
variablesSplit = 'l2_relative_error_'
validatorsRename = {'validator':'r1.0','validator_2':'r0.85','validator_3':'r0.75'}
variablesID = 'validator'
#TODO get subfolders automatically
subfolders = [#'Baseline_1024x8000',
              'Baseline_1024x8000_75-11',
              '11-XuvYuv_lVcm',
              #'NV-Importance',
              '11-NV-Importance',
              #'Full_Size_Baseline',
              'Full_Size_Baseline_75-11'
              ] ##UPDATE
legendNames = ['Uniform_1024','SGM-S-PINN_1024','MIS_1024','Uniform_4096']
# run aggregates with these subfoldetrs
#folder = 'C:/Users/jacec/Documents/Test_Runs/'
folder = 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/'
#folder = 'C:/Users/jacec/OneDrive - stevens.edu/4_DATA/Aggregator_Runs/'
#aggregates = [folder+f+'/aggregates/' for f in os.listdir(folder) if os.path.isdir(folder+f)][0:1]
aggregates = [folder+f+'/aggregates/' for f in ['Annular_Ring_Parameterized_75-11'] if os.path.isdir(folder+f)] ##UPDATE
#all results will be in /aggregates, separated by tags from subfolders
#find all validation files separated by subfolder
files = []
#for i in aggregates:
#    csvs_by_testcase = [[i + g for g in os.listdir(i) if (g.endswith('.csv')) and (variablesKey in g) and (f in g)] for f in subfolders]
#    files = files+[i for i in csvs_by_testcase if i]
files = [[i+g for g in os.listdir(i) if g.endswith('.csv') and (variablesKey in g)] for i in aggregates]
#files = [[aggregates + g for g in os.listdir(aggregates) if ('.csv' in g) and (f in g)] for f in subfolders] 
#list of lists of the files for each individual aggregation
#Go through sub-list, load into dataframes with descriptive columns
#Find unique variables, create sub-frames with them in a format for plotting

# %%
files
# Out:
# [['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_p-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_p-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_p-Baseline_1024x8000-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_p-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_p-Full_Size_Baseline-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_p-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_p-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_p-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_u-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_u-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_u-Baseline_1024x8000-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_u-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_u-Full_Size_Baseline-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_u-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_u-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_u-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_v-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_v-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_v-Baseline_1024x8000-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_v-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_v-Full_Size_Baseline-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_v-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_v-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_v-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_p-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_p-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_p-Baseline_1024x8000-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_p-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_p-Full_Size_Baseline-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_p-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_p-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_p-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_u-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_u-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_u-Baseline_1024x8000-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_u-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_u-Full_Size_Baseline-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_u-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_u-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_u-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_v-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_v-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_v-Baseline_1024x8000-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_v-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_v-Full_Size_Baseline-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_v-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_v-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_v-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_p-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_p-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_p-Baseline_1024x8000-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_p-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_p-Full_Size_Baseline-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_p-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_p-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_p-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_u-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_u-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_u-Baseline_1024x8000-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_u-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_u-Full_Size_Baseline-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_u-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_u-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_u-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_v-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_v-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_v-Baseline_1024x8000-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_v-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_v-Full_Size_Baseline-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_v-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_v-NV-Importance-Annular_Ring_Parameterized_75-11.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_v-SGM-SGM_Ablation_1024.csv']]

# %%
#each aggregate becomes one dataframe
#extract common variable names (validator, validator_n, uvpvnu)
#load into df with descriptive columns, uses 'subfolder' name, validator name, variable name
dataframes = []
agNames = []
for aggregation in files:
    dfs = []
    agName = aggregation[0].split('/aggregates/')[0].split('/')[-1]
    for testName in subfolders:
        subtests = [csv for csv in aggregation if testName in csv]
        if not subtests:
            continue
        print(subtests)
        for k,i in enumerate(subtests):
            validatorName = i.split(variablesKey)[1].split(variablesSplit)[0]
            vv = i.split(variablesSplit)[1].split('-'+testName)[0]
            variableName = f'{testName}_{validatorsRename[validatorName]}_{vv}_'
            print(variableName)
            #df = pd.read_csv(i, index_col = 0, delimiter=';')
            df = pd.read_csv(i, delimiter=';')
            oldcols = df.keys()
            print(oldcols)
            #mapping = {i:variableName+i for i in oldcols[0:-1]}
            mapping = {'Unnamed: 0':variableName+'step'}
            if k == 0:
                mapping.update({'wall_time':testName+'_wall_time'})
            mapping.update({i:variableName+i for i in oldcols[1:-1]})
            print(mapping)
            df.rename(columns=mapping, inplace=True)
            newcols = df.keys()
            print(newcols)
            if k > 0:
                df.drop(columns='wall_time')
            dfs.append(df)
    df = pd.concat(dfs, axis=1)
    df = df.loc[:,~df.columns.duplicated()].copy() #drop duplicates based on column name alone
    #append to dataframes list
    dataframes.append(df)
    agNames.append(agName)
# Out:
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_p-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_u-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_v-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_p-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_u-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_v-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_p-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_u-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_v-Baseline_1024x8000_75-11-Annular_Ring_Parameterized_75-11.csv']
# Baseline_1024x8000_75-11_r1.0_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_75-11_r1.0_p_step', 'wall_time': 'Baseline_1024x8000_75-11_wall_time', 'mean': 'Baseline_1024x8000_75-11_r1.0_p_mean', 'amin': 'Baseline_1024x8000_75-11_r1.0_p_amin', 'amax': 'Baseline_1024x8000_75-11_r1.0_p_amax', 'median': 'Baseline_1024x8000_75-11_r1.0_p_median', 'std': 'Baseline_1024x8000_75-11_r1.0_p_std', 'var': 'Baseline_1024x8000_75-11_r1.0_p_var'}
# Index(['Baseline_1024x8000_75-11_r1.0_p_step',
#        'Baseline_1024x8000_75-11_r1.0_p_mean',
#        'Baseline_1024x8000_75-11_r1.0_p_amin',
#        'Baseline_1024x8000_75-11_r1.0_p_amax',
#        'Baseline_1024x8000_75-11_r1.0_p_median',
#        'Baseline_1024x8000_75-11_r1.0_p_std',
#        'Baseline_1024x8000_75-11_r1.0_p_var',
#        'Baseline_1024x8000_75-11_wall_time'],
#       dtype='object')
# Baseline_1024x8000_75-11_r1.0_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_75-11_r1.0_u_step', 'mean': 'Baseline_1024x8000_75-11_r1.0_u_mean', 'amin': 'Baseline_1024x8000_75-11_r1.0_u_amin', 'amax': 'Baseline_1024x8000_75-11_r1.0_u_amax', 'median': 'Baseline_1024x8000_75-11_r1.0_u_median', 'std': 'Baseline_1024x8000_75-11_r1.0_u_std', 'var': 'Baseline_1024x8000_75-11_r1.0_u_var'}
# Index(['Baseline_1024x8000_75-11_r1.0_u_step',
#        'Baseline_1024x8000_75-11_r1.0_u_mean',
#        'Baseline_1024x8000_75-11_r1.0_u_amin',
#        'Baseline_1024x8000_75-11_r1.0_u_amax',
#        'Baseline_1024x8000_75-11_r1.0_u_median',
#        'Baseline_1024x8000_75-11_r1.0_u_std',
#        'Baseline_1024x8000_75-11_r1.0_u_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_75-11_r1.0_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_75-11_r1.0_v_step', 'mean': 'Baseline_1024x8000_75-11_r1.0_v_mean', 'amin': 'Baseline_1024x8000_75-11_r1.0_v_amin', 'amax': 'Baseline_1024x8000_75-11_r1.0_v_amax', 'median': 'Baseline_1024x8000_75-11_r1.0_v_median', 'std': 'Baseline_1024x8000_75-11_r1.0_v_std', 'var': 'Baseline_1024x8000_75-11_r1.0_v_var'}
# Index(['Baseline_1024x8000_75-11_r1.0_v_step',
#        'Baseline_1024x8000_75-11_r1.0_v_mean',
#        'Baseline_1024x8000_75-11_r1.0_v_amin',
#        'Baseline_1024x8000_75-11_r1.0_v_amax',
#        'Baseline_1024x8000_75-11_r1.0_v_median',
#        'Baseline_1024x8000_75-11_r1.0_v_std',
#        'Baseline_1024x8000_75-11_r1.0_v_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_75-11_r0.85_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_75-11_r0.85_p_step', 'mean': 'Baseline_1024x8000_75-11_r0.85_p_mean', 'amin': 'Baseline_1024x8000_75-11_r0.85_p_amin', 'amax': 'Baseline_1024x8000_75-11_r0.85_p_amax', 'median': 'Baseline_1024x8000_75-11_r0.85_p_median', 'std': 'Baseline_1024x8000_75-11_r0.85_p_std', 'var': 'Baseline_1024x8000_75-11_r0.85_p_var'}
# Index(['Baseline_1024x8000_75-11_r0.85_p_step',
#        'Baseline_1024x8000_75-11_r0.85_p_mean',
#        'Baseline_1024x8000_75-11_r0.85_p_amin',
#        'Baseline_1024x8000_75-11_r0.85_p_amax',
#        'Baseline_1024x8000_75-11_r0.85_p_median',
#        'Baseline_1024x8000_75-11_r0.85_p_std',
#        'Baseline_1024x8000_75-11_r0.85_p_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_75-11_r0.85_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_75-11_r0.85_u_step', 'mean': 'Baseline_1024x8000_75-11_r0.85_u_mean', 'amin': 'Baseline_1024x8000_75-11_r0.85_u_amin', 'amax': 'Baseline_1024x8000_75-11_r0.85_u_amax', 'median': 'Baseline_1024x8000_75-11_r0.85_u_median', 'std': 'Baseline_1024x8000_75-11_r0.85_u_std', 'var': 'Baseline_1024x8000_75-11_r0.85_u_var'}
# Index(['Baseline_1024x8000_75-11_r0.85_u_step',
#        'Baseline_1024x8000_75-11_r0.85_u_mean',
#        'Baseline_1024x8000_75-11_r0.85_u_amin',
#        'Baseline_1024x8000_75-11_r0.85_u_amax',
#        'Baseline_1024x8000_75-11_r0.85_u_median',
#        'Baseline_1024x8000_75-11_r0.85_u_std',
#        'Baseline_1024x8000_75-11_r0.85_u_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_75-11_r0.85_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_75-11_r0.85_v_step', 'mean': 'Baseline_1024x8000_75-11_r0.85_v_mean', 'amin': 'Baseline_1024x8000_75-11_r0.85_v_amin', 'amax': 'Baseline_1024x8000_75-11_r0.85_v_amax', 'median': 'Baseline_1024x8000_75-11_r0.85_v_median', 'std': 'Baseline_1024x8000_75-11_r0.85_v_std', 'var': 'Baseline_1024x8000_75-11_r0.85_v_var'}
# Index(['Baseline_1024x8000_75-11_r0.85_v_step',
#        'Baseline_1024x8000_75-11_r0.85_v_mean',
#        'Baseline_1024x8000_75-11_r0.85_v_amin',
#        'Baseline_1024x8000_75-11_r0.85_v_amax',
#        'Baseline_1024x8000_75-11_r0.85_v_median',
#        'Baseline_1024x8000_75-11_r0.85_v_std',
#        'Baseline_1024x8000_75-11_r0.85_v_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_75-11_r0.75_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_75-11_r0.75_p_step', 'mean': 'Baseline_1024x8000_75-11_r0.75_p_mean', 'amin': 'Baseline_1024x8000_75-11_r0.75_p_amin', 'amax': 'Baseline_1024x8000_75-11_r0.75_p_amax', 'median': 'Baseline_1024x8000_75-11_r0.75_p_median', 'std': 'Baseline_1024x8000_75-11_r0.75_p_std', 'var': 'Baseline_1024x8000_75-11_r0.75_p_var'}
# Index(['Baseline_1024x8000_75-11_r0.75_p_step',
#        'Baseline_1024x8000_75-11_r0.75_p_mean',
#        'Baseline_1024x8000_75-11_r0.75_p_amin',
#        'Baseline_1024x8000_75-11_r0.75_p_amax',
#        'Baseline_1024x8000_75-11_r0.75_p_median',
#        'Baseline_1024x8000_75-11_r0.75_p_std',
#        'Baseline_1024x8000_75-11_r0.75_p_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_75-11_r0.75_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_75-11_r0.75_u_step', 'mean': 'Baseline_1024x8000_75-11_r0.75_u_mean', 'amin': 'Baseline_1024x8000_75-11_r0.75_u_amin', 'amax': 'Baseline_1024x8000_75-11_r0.75_u_amax', 'median': 'Baseline_1024x8000_75-11_r0.75_u_median', 'std': 'Baseline_1024x8000_75-11_r0.75_u_std', 'var': 'Baseline_1024x8000_75-11_r0.75_u_var'}
# Index(['Baseline_1024x8000_75-11_r0.75_u_step',
#        'Baseline_1024x8000_75-11_r0.75_u_mean',
#        'Baseline_1024x8000_75-11_r0.75_u_amin',
#        'Baseline_1024x8000_75-11_r0.75_u_amax',
#        'Baseline_1024x8000_75-11_r0.75_u_median',
#        'Baseline_1024x8000_75-11_r0.75_u_std',
#        'Baseline_1024x8000_75-11_r0.75_u_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_75-11_r0.75_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_75-11_r0.75_v_step', 'mean': 'Baseline_1024x8000_75-11_r0.75_v_mean', 'amin': 'Baseline_1024x8000_75-11_r0.75_v_amin', 'amax': 'Baseline_1024x8000_75-11_r0.75_v_amax', 'median': 'Baseline_1024x8000_75-11_r0.75_v_median', 'std': 'Baseline_1024x8000_75-11_r0.75_v_std', 'var': 'Baseline_1024x8000_75-11_r0.75_v_var'}
# Index(['Baseline_1024x8000_75-11_r0.75_v_step',
#        'Baseline_1024x8000_75-11_r0.75_v_mean',
#        'Baseline_1024x8000_75-11_r0.75_v_amin',
#        'Baseline_1024x8000_75-11_r0.75_v_amax',
#        'Baseline_1024x8000_75-11_r0.75_v_median',
#        'Baseline_1024x8000_75-11_r0.75_v_std',
#        'Baseline_1024x8000_75-11_r0.75_v_var', 'wall_time'],
#       dtype='object')
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_p-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_u-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_v-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_p-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_u-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_v-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_p-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_u-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_v-11-XuvYuv_lVcm-Annular_Ring_Parameterized_75-11.csv']
# 11-XuvYuv_lVcm_r1.0_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r1.0_p_step', 'wall_time': '11-XuvYuv_lVcm_wall_time', 'mean': '11-XuvYuv_lVcm_r1.0_p_mean', 'amin': '11-XuvYuv_lVcm_r1.0_p_amin', 'amax': '11-XuvYuv_lVcm_r1.0_p_amax', 'median': '11-XuvYuv_lVcm_r1.0_p_median', 'std': '11-XuvYuv_lVcm_r1.0_p_std', 'var': '11-XuvYuv_lVcm_r1.0_p_var'}
# Index(['11-XuvYuv_lVcm_r1.0_p_step', '11-XuvYuv_lVcm_r1.0_p_mean',
#        '11-XuvYuv_lVcm_r1.0_p_amin', '11-XuvYuv_lVcm_r1.0_p_amax',
#        '11-XuvYuv_lVcm_r1.0_p_median', '11-XuvYuv_lVcm_r1.0_p_std',
#        '11-XuvYuv_lVcm_r1.0_p_var', '11-XuvYuv_lVcm_wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r1.0_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r1.0_u_step', 'mean': '11-XuvYuv_lVcm_r1.0_u_mean', 'amin': '11-XuvYuv_lVcm_r1.0_u_amin', 'amax': '11-XuvYuv_lVcm_r1.0_u_amax', 'median': '11-XuvYuv_lVcm_r1.0_u_median', 'std': '11-XuvYuv_lVcm_r1.0_u_std', 'var': '11-XuvYuv_lVcm_r1.0_u_var'}
# Index(['11-XuvYuv_lVcm_r1.0_u_step', '11-XuvYuv_lVcm_r1.0_u_mean',
#        '11-XuvYuv_lVcm_r1.0_u_amin', '11-XuvYuv_lVcm_r1.0_u_amax',
#        '11-XuvYuv_lVcm_r1.0_u_median', '11-XuvYuv_lVcm_r1.0_u_std',
#        '11-XuvYuv_lVcm_r1.0_u_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r1.0_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r1.0_v_step', 'mean': '11-XuvYuv_lVcm_r1.0_v_mean', 'amin': '11-XuvYuv_lVcm_r1.0_v_amin', 'amax': '11-XuvYuv_lVcm_r1.0_v_amax', 'median': '11-XuvYuv_lVcm_r1.0_v_median', 'std': '11-XuvYuv_lVcm_r1.0_v_std', 'var': '11-XuvYuv_lVcm_r1.0_v_var'}
# Index(['11-XuvYuv_lVcm_r1.0_v_step', '11-XuvYuv_lVcm_r1.0_v_mean',
#        '11-XuvYuv_lVcm_r1.0_v_amin', '11-XuvYuv_lVcm_r1.0_v_amax',
#        '11-XuvYuv_lVcm_r1.0_v_median', '11-XuvYuv_lVcm_r1.0_v_std',
#        '11-XuvYuv_lVcm_r1.0_v_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r0.85_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r0.85_p_step', 'mean': '11-XuvYuv_lVcm_r0.85_p_mean', 'amin': '11-XuvYuv_lVcm_r0.85_p_amin', 'amax': '11-XuvYuv_lVcm_r0.85_p_amax', 'median': '11-XuvYuv_lVcm_r0.85_p_median', 'std': '11-XuvYuv_lVcm_r0.85_p_std', 'var': '11-XuvYuv_lVcm_r0.85_p_var'}
# Index(['11-XuvYuv_lVcm_r0.85_p_step', '11-XuvYuv_lVcm_r0.85_p_mean',
#        '11-XuvYuv_lVcm_r0.85_p_amin', '11-XuvYuv_lVcm_r0.85_p_amax',
#        '11-XuvYuv_lVcm_r0.85_p_median', '11-XuvYuv_lVcm_r0.85_p_std',
#        '11-XuvYuv_lVcm_r0.85_p_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r0.85_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r0.85_u_step', 'mean': '11-XuvYuv_lVcm_r0.85_u_mean', 'amin': '11-XuvYuv_lVcm_r0.85_u_amin', 'amax': '11-XuvYuv_lVcm_r0.85_u_amax', 'median': '11-XuvYuv_lVcm_r0.85_u_median', 'std': '11-XuvYuv_lVcm_r0.85_u_std', 'var': '11-XuvYuv_lVcm_r0.85_u_var'}
# Index(['11-XuvYuv_lVcm_r0.85_u_step', '11-XuvYuv_lVcm_r0.85_u_mean',
#        '11-XuvYuv_lVcm_r0.85_u_amin', '11-XuvYuv_lVcm_r0.85_u_amax',
#        '11-XuvYuv_lVcm_r0.85_u_median', '11-XuvYuv_lVcm_r0.85_u_std',
#        '11-XuvYuv_lVcm_r0.85_u_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r0.85_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r0.85_v_step', 'mean': '11-XuvYuv_lVcm_r0.85_v_mean', 'amin': '11-XuvYuv_lVcm_r0.85_v_amin', 'amax': '11-XuvYuv_lVcm_r0.85_v_amax', 'median': '11-XuvYuv_lVcm_r0.85_v_median', 'std': '11-XuvYuv_lVcm_r0.85_v_std', 'var': '11-XuvYuv_lVcm_r0.85_v_var'}
# Index(['11-XuvYuv_lVcm_r0.85_v_step', '11-XuvYuv_lVcm_r0.85_v_mean',
#        '11-XuvYuv_lVcm_r0.85_v_amin', '11-XuvYuv_lVcm_r0.85_v_amax',
#        '11-XuvYuv_lVcm_r0.85_v_median', '11-XuvYuv_lVcm_r0.85_v_std',
#        '11-XuvYuv_lVcm_r0.85_v_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r0.75_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r0.75_p_step', 'mean': '11-XuvYuv_lVcm_r0.75_p_mean', 'amin': '11-XuvYuv_lVcm_r0.75_p_amin', 'amax': '11-XuvYuv_lVcm_r0.75_p_amax', 'median': '11-XuvYuv_lVcm_r0.75_p_median', 'std': '11-XuvYuv_lVcm_r0.75_p_std', 'var': '11-XuvYuv_lVcm_r0.75_p_var'}
# Index(['11-XuvYuv_lVcm_r0.75_p_step', '11-XuvYuv_lVcm_r0.75_p_mean',
#        '11-XuvYuv_lVcm_r0.75_p_amin', '11-XuvYuv_lVcm_r0.75_p_amax',
#        '11-XuvYuv_lVcm_r0.75_p_median', '11-XuvYuv_lVcm_r0.75_p_std',
#        '11-XuvYuv_lVcm_r0.75_p_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r0.75_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r0.75_u_step', 'mean': '11-XuvYuv_lVcm_r0.75_u_mean', 'amin': '11-XuvYuv_lVcm_r0.75_u_amin', 'amax': '11-XuvYuv_lVcm_r0.75_u_amax', 'median': '11-XuvYuv_lVcm_r0.75_u_median', 'std': '11-XuvYuv_lVcm_r0.75_u_std', 'var': '11-XuvYuv_lVcm_r0.75_u_var'}
# Index(['11-XuvYuv_lVcm_r0.75_u_step', '11-XuvYuv_lVcm_r0.75_u_mean',
#        '11-XuvYuv_lVcm_r0.75_u_amin', '11-XuvYuv_lVcm_r0.75_u_amax',
#        '11-XuvYuv_lVcm_r0.75_u_median', '11-XuvYuv_lVcm_r0.75_u_std',
#        '11-XuvYuv_lVcm_r0.75_u_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r0.75_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r0.75_v_step', 'mean': '11-XuvYuv_lVcm_r0.75_v_mean', 'amin': '11-XuvYuv_lVcm_r0.75_v_amin', 'amax': '11-XuvYuv_lVcm_r0.75_v_amax', 'median': '11-XuvYuv_lVcm_r0.75_v_median', 'std': '11-XuvYuv_lVcm_r0.75_v_std', 'var': '11-XuvYuv_lVcm_r0.75_v_var'}
# Index(['11-XuvYuv_lVcm_r0.75_v_step', '11-XuvYuv_lVcm_r0.75_v_mean',
#        '11-XuvYuv_lVcm_r0.75_v_amin', '11-XuvYuv_lVcm_r0.75_v_amax',
#        '11-XuvYuv_lVcm_r0.75_v_median', '11-XuvYuv_lVcm_r0.75_v_std',
#        '11-XuvYuv_lVcm_r0.75_v_var', 'wall_time'],
#       dtype='object')
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_p-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_u-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_v-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_p-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_u-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_v-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_p-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_u-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_v-11-NV-Importance-Annular_Ring_Parameterized_75-11.csv']
# 11-NV-Importance_r1.0_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r1.0_p_step', 'wall_time': '11-NV-Importance_wall_time', 'mean': '11-NV-Importance_r1.0_p_mean', 'amin': '11-NV-Importance_r1.0_p_amin', 'amax': '11-NV-Importance_r1.0_p_amax', 'median': '11-NV-Importance_r1.0_p_median', 'std': '11-NV-Importance_r1.0_p_std', 'var': '11-NV-Importance_r1.0_p_var'}
# Index(['11-NV-Importance_r1.0_p_step', '11-NV-Importance_r1.0_p_mean',
#        '11-NV-Importance_r1.0_p_amin', '11-NV-Importance_r1.0_p_amax',
#        '11-NV-Importance_r1.0_p_median', '11-NV-Importance_r1.0_p_std',
#        '11-NV-Importance_r1.0_p_var', '11-NV-Importance_wall_time'],
#       dtype='object')
# 11-NV-Importance_r1.0_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r1.0_u_step', 'mean': '11-NV-Importance_r1.0_u_mean', 'amin': '11-NV-Importance_r1.0_u_amin', 'amax': '11-NV-Importance_r1.0_u_amax', 'median': '11-NV-Importance_r1.0_u_median', 'std': '11-NV-Importance_r1.0_u_std', 'var': '11-NV-Importance_r1.0_u_var'}
# Index(['11-NV-Importance_r1.0_u_step', '11-NV-Importance_r1.0_u_mean',
#        '11-NV-Importance_r1.0_u_amin', '11-NV-Importance_r1.0_u_amax',
#        '11-NV-Importance_r1.0_u_median', '11-NV-Importance_r1.0_u_std',
#        '11-NV-Importance_r1.0_u_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r1.0_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r1.0_v_step', 'mean': '11-NV-Importance_r1.0_v_mean', 'amin': '11-NV-Importance_r1.0_v_amin', 'amax': '11-NV-Importance_r1.0_v_amax', 'median': '11-NV-Importance_r1.0_v_median', 'std': '11-NV-Importance_r1.0_v_std', 'var': '11-NV-Importance_r1.0_v_var'}
# Index(['11-NV-Importance_r1.0_v_step', '11-NV-Importance_r1.0_v_mean',
#        '11-NV-Importance_r1.0_v_amin', '11-NV-Importance_r1.0_v_amax',
#        '11-NV-Importance_r1.0_v_median', '11-NV-Importance_r1.0_v_std',
#        '11-NV-Importance_r1.0_v_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r0.85_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r0.85_p_step', 'mean': '11-NV-Importance_r0.85_p_mean', 'amin': '11-NV-Importance_r0.85_p_amin', 'amax': '11-NV-Importance_r0.85_p_amax', 'median': '11-NV-Importance_r0.85_p_median', 'std': '11-NV-Importance_r0.85_p_std', 'var': '11-NV-Importance_r0.85_p_var'}
# Index(['11-NV-Importance_r0.85_p_step', '11-NV-Importance_r0.85_p_mean',
#        '11-NV-Importance_r0.85_p_amin', '11-NV-Importance_r0.85_p_amax',
#        '11-NV-Importance_r0.85_p_median', '11-NV-Importance_r0.85_p_std',
#        '11-NV-Importance_r0.85_p_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r0.85_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r0.85_u_step', 'mean': '11-NV-Importance_r0.85_u_mean', 'amin': '11-NV-Importance_r0.85_u_amin', 'amax': '11-NV-Importance_r0.85_u_amax', 'median': '11-NV-Importance_r0.85_u_median', 'std': '11-NV-Importance_r0.85_u_std', 'var': '11-NV-Importance_r0.85_u_var'}
# Index(['11-NV-Importance_r0.85_u_step', '11-NV-Importance_r0.85_u_mean',
#        '11-NV-Importance_r0.85_u_amin', '11-NV-Importance_r0.85_u_amax',
#        '11-NV-Importance_r0.85_u_median', '11-NV-Importance_r0.85_u_std',
#        '11-NV-Importance_r0.85_u_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r0.85_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r0.85_v_step', 'mean': '11-NV-Importance_r0.85_v_mean', 'amin': '11-NV-Importance_r0.85_v_amin', 'amax': '11-NV-Importance_r0.85_v_amax', 'median': '11-NV-Importance_r0.85_v_median', 'std': '11-NV-Importance_r0.85_v_std', 'var': '11-NV-Importance_r0.85_v_var'}
# Index(['11-NV-Importance_r0.85_v_step', '11-NV-Importance_r0.85_v_mean',
#        '11-NV-Importance_r0.85_v_amin', '11-NV-Importance_r0.85_v_amax',
#        '11-NV-Importance_r0.85_v_median', '11-NV-Importance_r0.85_v_std',
#        '11-NV-Importance_r0.85_v_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r0.75_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r0.75_p_step', 'mean': '11-NV-Importance_r0.75_p_mean', 'amin': '11-NV-Importance_r0.75_p_amin', 'amax': '11-NV-Importance_r0.75_p_amax', 'median': '11-NV-Importance_r0.75_p_median', 'std': '11-NV-Importance_r0.75_p_std', 'var': '11-NV-Importance_r0.75_p_var'}
# Index(['11-NV-Importance_r0.75_p_step', '11-NV-Importance_r0.75_p_mean',
#        '11-NV-Importance_r0.75_p_amin', '11-NV-Importance_r0.75_p_amax',
#        '11-NV-Importance_r0.75_p_median', '11-NV-Importance_r0.75_p_std',
#        '11-NV-Importance_r0.75_p_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r0.75_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r0.75_u_step', 'mean': '11-NV-Importance_r0.75_u_mean', 'amin': '11-NV-Importance_r0.75_u_amin', 'amax': '11-NV-Importance_r0.75_u_amax', 'median': '11-NV-Importance_r0.75_u_median', 'std': '11-NV-Importance_r0.75_u_std', 'var': '11-NV-Importance_r0.75_u_var'}
# Index(['11-NV-Importance_r0.75_u_step', '11-NV-Importance_r0.75_u_mean',
#        '11-NV-Importance_r0.75_u_amin', '11-NV-Importance_r0.75_u_amax',
#        '11-NV-Importance_r0.75_u_median', '11-NV-Importance_r0.75_u_std',
#        '11-NV-Importance_r0.75_u_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r0.75_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r0.75_v_step', 'mean': '11-NV-Importance_r0.75_v_mean', 'amin': '11-NV-Importance_r0.75_v_amin', 'amax': '11-NV-Importance_r0.75_v_amax', 'median': '11-NV-Importance_r0.75_v_median', 'std': '11-NV-Importance_r0.75_v_std', 'var': '11-NV-Importance_r0.75_v_var'}
# Index(['11-NV-Importance_r0.75_v_step', '11-NV-Importance_r0.75_v_mean',
#        '11-NV-Importance_r0.75_v_amin', '11-NV-Importance_r0.75_v_amax',
#        '11-NV-Importance_r0.75_v_median', '11-NV-Importance_r0.75_v_std',
#        '11-NV-Importance_r0.75_v_var', 'wall_time'],
#       dtype='object')
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_p-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_u-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidatorl2_relative_error_v-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_p-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_u-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_2l2_relative_error_v-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_p-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_u-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/Annular_Ring_Parameterized_75-11/aggregates/Validatorsvalidator_3l2_relative_error_v-Full_Size_Baseline_75-11-Annular_Ring_Parameterized_75-11.csv']
# Full_Size_Baseline_75-11_r1.0_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_75-11_r1.0_p_step', 'wall_time': 'Full_Size_Baseline_75-11_wall_time', 'mean': 'Full_Size_Baseline_75-11_r1.0_p_mean', 'amin': 'Full_Size_Baseline_75-11_r1.0_p_amin', 'amax': 'Full_Size_Baseline_75-11_r1.0_p_amax', 'median': 'Full_Size_Baseline_75-11_r1.0_p_median', 'std': 'Full_Size_Baseline_75-11_r1.0_p_std', 'var': 'Full_Size_Baseline_75-11_r1.0_p_var'}
# Index(['Full_Size_Baseline_75-11_r1.0_p_step',
#        'Full_Size_Baseline_75-11_r1.0_p_mean',
#        'Full_Size_Baseline_75-11_r1.0_p_amin',
#        'Full_Size_Baseline_75-11_r1.0_p_amax',
#        'Full_Size_Baseline_75-11_r1.0_p_median',
#        'Full_Size_Baseline_75-11_r1.0_p_std',
#        'Full_Size_Baseline_75-11_r1.0_p_var',
#        'Full_Size_Baseline_75-11_wall_time'],
#       dtype='object')
# Full_Size_Baseline_75-11_r1.0_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_75-11_r1.0_u_step', 'mean': 'Full_Size_Baseline_75-11_r1.0_u_mean', 'amin': 'Full_Size_Baseline_75-11_r1.0_u_amin', 'amax': 'Full_Size_Baseline_75-11_r1.0_u_amax', 'median': 'Full_Size_Baseline_75-11_r1.0_u_median', 'std': 'Full_Size_Baseline_75-11_r1.0_u_std', 'var': 'Full_Size_Baseline_75-11_r1.0_u_var'}
# Index(['Full_Size_Baseline_75-11_r1.0_u_step',
#        'Full_Size_Baseline_75-11_r1.0_u_mean',
#        'Full_Size_Baseline_75-11_r1.0_u_amin',
#        'Full_Size_Baseline_75-11_r1.0_u_amax',
#        'Full_Size_Baseline_75-11_r1.0_u_median',
#        'Full_Size_Baseline_75-11_r1.0_u_std',
#        'Full_Size_Baseline_75-11_r1.0_u_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_75-11_r1.0_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_75-11_r1.0_v_step', 'mean': 'Full_Size_Baseline_75-11_r1.0_v_mean', 'amin': 'Full_Size_Baseline_75-11_r1.0_v_amin', 'amax': 'Full_Size_Baseline_75-11_r1.0_v_amax', 'median': 'Full_Size_Baseline_75-11_r1.0_v_median', 'std': 'Full_Size_Baseline_75-11_r1.0_v_std', 'var': 'Full_Size_Baseline_75-11_r1.0_v_var'}
# Index(['Full_Size_Baseline_75-11_r1.0_v_step',
#        'Full_Size_Baseline_75-11_r1.0_v_mean',
#        'Full_Size_Baseline_75-11_r1.0_v_amin',
#        'Full_Size_Baseline_75-11_r1.0_v_amax',
#        'Full_Size_Baseline_75-11_r1.0_v_median',
#        'Full_Size_Baseline_75-11_r1.0_v_std',
#        'Full_Size_Baseline_75-11_r1.0_v_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_75-11_r0.85_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_75-11_r0.85_p_step', 'mean': 'Full_Size_Baseline_75-11_r0.85_p_mean', 'amin': 'Full_Size_Baseline_75-11_r0.85_p_amin', 'amax': 'Full_Size_Baseline_75-11_r0.85_p_amax', 'median': 'Full_Size_Baseline_75-11_r0.85_p_median', 'std': 'Full_Size_Baseline_75-11_r0.85_p_std', 'var': 'Full_Size_Baseline_75-11_r0.85_p_var'}
# Index(['Full_Size_Baseline_75-11_r0.85_p_step',
#        'Full_Size_Baseline_75-11_r0.85_p_mean',
#        'Full_Size_Baseline_75-11_r0.85_p_amin',
#        'Full_Size_Baseline_75-11_r0.85_p_amax',
#        'Full_Size_Baseline_75-11_r0.85_p_median',
#        'Full_Size_Baseline_75-11_r0.85_p_std',
#        'Full_Size_Baseline_75-11_r0.85_p_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_75-11_r0.85_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_75-11_r0.85_u_step', 'mean': 'Full_Size_Baseline_75-11_r0.85_u_mean', 'amin': 'Full_Size_Baseline_75-11_r0.85_u_amin', 'amax': 'Full_Size_Baseline_75-11_r0.85_u_amax', 'median': 'Full_Size_Baseline_75-11_r0.85_u_median', 'std': 'Full_Size_Baseline_75-11_r0.85_u_std', 'var': 'Full_Size_Baseline_75-11_r0.85_u_var'}
# Index(['Full_Size_Baseline_75-11_r0.85_u_step',
#        'Full_Size_Baseline_75-11_r0.85_u_mean',
#        'Full_Size_Baseline_75-11_r0.85_u_amin',
#        'Full_Size_Baseline_75-11_r0.85_u_amax',
#        'Full_Size_Baseline_75-11_r0.85_u_median',
#        'Full_Size_Baseline_75-11_r0.85_u_std',
#        'Full_Size_Baseline_75-11_r0.85_u_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_75-11_r0.85_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_75-11_r0.85_v_step', 'mean': 'Full_Size_Baseline_75-11_r0.85_v_mean', 'amin': 'Full_Size_Baseline_75-11_r0.85_v_amin', 'amax': 'Full_Size_Baseline_75-11_r0.85_v_amax', 'median': 'Full_Size_Baseline_75-11_r0.85_v_median', 'std': 'Full_Size_Baseline_75-11_r0.85_v_std', 'var': 'Full_Size_Baseline_75-11_r0.85_v_var'}
# Index(['Full_Size_Baseline_75-11_r0.85_v_step',
#        'Full_Size_Baseline_75-11_r0.85_v_mean',
#        'Full_Size_Baseline_75-11_r0.85_v_amin',
#        'Full_Size_Baseline_75-11_r0.85_v_amax',
#        'Full_Size_Baseline_75-11_r0.85_v_median',
#        'Full_Size_Baseline_75-11_r0.85_v_std',
#        'Full_Size_Baseline_75-11_r0.85_v_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_75-11_r0.75_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_75-11_r0.75_p_step', 'mean': 'Full_Size_Baseline_75-11_r0.75_p_mean', 'amin': 'Full_Size_Baseline_75-11_r0.75_p_amin', 'amax': 'Full_Size_Baseline_75-11_r0.75_p_amax', 'median': 'Full_Size_Baseline_75-11_r0.75_p_median', 'std': 'Full_Size_Baseline_75-11_r0.75_p_std', 'var': 'Full_Size_Baseline_75-11_r0.75_p_var'}
# Index(['Full_Size_Baseline_75-11_r0.75_p_step',
#        'Full_Size_Baseline_75-11_r0.75_p_mean',
#        'Full_Size_Baseline_75-11_r0.75_p_amin',
#        'Full_Size_Baseline_75-11_r0.75_p_amax',
#        'Full_Size_Baseline_75-11_r0.75_p_median',
#        'Full_Size_Baseline_75-11_r0.75_p_std',
#        'Full_Size_Baseline_75-11_r0.75_p_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_75-11_r0.75_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_75-11_r0.75_u_step', 'mean': 'Full_Size_Baseline_75-11_r0.75_u_mean', 'amin': 'Full_Size_Baseline_75-11_r0.75_u_amin', 'amax': 'Full_Size_Baseline_75-11_r0.75_u_amax', 'median': 'Full_Size_Baseline_75-11_r0.75_u_median', 'std': 'Full_Size_Baseline_75-11_r0.75_u_std', 'var': 'Full_Size_Baseline_75-11_r0.75_u_var'}
# Index(['Full_Size_Baseline_75-11_r0.75_u_step',
#        'Full_Size_Baseline_75-11_r0.75_u_mean',
#        'Full_Size_Baseline_75-11_r0.75_u_amin',
#        'Full_Size_Baseline_75-11_r0.75_u_amax',
#        'Full_Size_Baseline_75-11_r0.75_u_median',
#        'Full_Size_Baseline_75-11_r0.75_u_std',
#        'Full_Size_Baseline_75-11_r0.75_u_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_75-11_r0.75_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_75-11_r0.75_v_step', 'mean': 'Full_Size_Baseline_75-11_r0.75_v_mean', 'amin': 'Full_Size_Baseline_75-11_r0.75_v_amin', 'amax': 'Full_Size_Baseline_75-11_r0.75_v_amax', 'median': 'Full_Size_Baseline_75-11_r0.75_v_median', 'std': 'Full_Size_Baseline_75-11_r0.75_v_std', 'var': 'Full_Size_Baseline_75-11_r0.75_v_var'}
# Index(['Full_Size_Baseline_75-11_r0.75_v_step',
#        'Full_Size_Baseline_75-11_r0.75_v_mean',
#        'Full_Size_Baseline_75-11_r0.75_v_amin',
#        'Full_Size_Baseline_75-11_r0.75_v_amax',
#        'Full_Size_Baseline_75-11_r0.75_v_median',
#        'Full_Size_Baseline_75-11_r0.75_v_std',
#        'Full_Size_Baseline_75-11_r0.75_v_var', 'wall_time'],
#       dtype='object')

# %%
dataframes[0]
agNames
# Out:
# ['Annular_Ring_Parameterized_75-11']

# %%
#plot step series p
plotVars_p_allValidators = [[f'{subfolders[0]}_{j}_p_step'] + [f'{i}_{j}_p_mean' for i in subfolders ] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
sFilter = 150000
stepFilter = dataframes[0][f'{subfolders[0]}_r1.0_p_step'] >= sFilter
def set_cycler(ax):
    ax.set_prop_cycle(plt.cycler('color', ['r', 'b', 'g', 'c'])+
                      plt.cycler('linestyle', ['-','--',':','-.'])+
                      plt.cycler('marker', ['.','*','^','x']))
    
def set_cycler(ax):
    ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'g','r'])+
                      plt.cycler('linestyle', ['-','--',':',':','-.'])+
                      plt.cycler('marker', ['x','1','^','d','x']))
    
def set_cycler(ax):
    ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'r'])+
                      plt.cycler('linestyle', ['-.','--',':','-'])+
                      plt.cycler('marker', ['x','1','^','x']))

mSize=10


plotVar = 'p'
font2 = {'family':'serif','color':'black','size':20}
manualLegend_p = [[f'{j}_{i}_{plotVar}' for j in legendNames] for i in validatorsRename.values()] ##UPDATE
manualLegend_p_agg = [f'{j}_{plotVar}' for j in legendNames] ##UPDATE

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (20,5))
    #fig.suptitle(f'P step series for {agNames[i]}')
    plt.rc('legend', fontsize = 12)
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        axes[k].tick_params(axis='both', labelsize=18)
        print(f'{[(l,dataframes[i][j][l][99]) for l in dataframes[i][j]]}')
        dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k], markersize=mSize)
        axes[k].set_xlabel(j[0].split('_')[0]+str(j[0].split('_')[-3:-1]), fontdict=font2)
        axes[k].legend(manualLegend_p[k])

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (9,5))
    #fig.suptitle(f'P step series for {agNames[i]}')
    axes.set_ylabel('l2_relative_error')
    fig.suptitle(f'P Step Series for {agNames[i]}')
    for k in range(1,len(plotVars_p_allValidators[0])):
        set_cycler(axes)
        axes.ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        dataframes[i][f'{subfolders[k-1]}_p_mean'] = dataframes[i][[plotVars_p_allValidators[q][k] for q in range(len(plotVars_p_allValidators))]].mean(axis=1)
    dataframes[i][[plotVars_p_allValidators[0][0]]+[f'{subfolders[k-1]}_p_mean' for k in range(1,len(plotVars_p_allValidators[0]))]][stepFilter].plot(x=plotVars_p_allValidators[0][0],ax=axes, markersize=mSize)
    axes.legend(manualLegend_p_agg)

# for i in range(len(dataframes)):
#     fig, axes = plt.subplots(nrows=2, ncols=2, figsize = (20,16))
#     #fig.suptitle(f'P step series for {agNames[i]}')
#     plt.rc('legend', fontsize = 12)
#     axes = axes.flatten()
#     axes[0].set_ylabel('l2_relative_error', fontdict=font2)
#     for k,j in enumerate(plotVars_p_allValidators):
#         set_cycler(axes[k])
#         axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
#         axes[k].tick_params(axis='both', labelsize=18)
#         print(f'{[(l,dataframes[i][j][l][99]) for l in dataframes[i][j]]}')
#         dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k],markersize=10)
#         axes[k].set_xlabel('Step_'+str(j[0].split('_')[-3:-1]), fontdict=font2)
#         #axes[k].legend(manualLegend)


#     axes[3].set_ylabel('l2_relative_error')
#     for k in range(1,len(plotVars_p_allValidators[0])):
#         set_cycler(axes[3])
#         axes[3].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
#         dataframes[i][f'{subfolders[k-1]}_p_mean'] = dataframes[i][[plotVars_p_allValidators[q][k] for q in range(len(plotVars_p_allValidators))]].mean(axis=1)
#     dataframes[i][[plotVars_p_allValidators[0][0]]+[f'{subfolders[k-1]}_p_mean' for k in range(1,len(plotVars_p_allValidators[0]))]][stepFilter].plot(x=plotVars_p_allValidators[0][0],ax=axes[3], markersize=10)
#     axes[3].set_xlabel('Step_[mean,p]', fontdict=font2)
#     #axes[3].legend(manualLegend_agg)
# Out:
# [['Baseline_1024x8000_75-11_r1.0_p_step', 'Baseline_1024x8000_75-11_r1.0_p_mean', '11-XuvYuv_lVcm_r1.0_p_mean', '11-NV-Importance_r1.0_p_mean', 'Full_Size_Baseline_75-11_r1.0_p_mean'], ['Baseline_1024x8000_75-11_r0.85_p_step', 'Baseline_1024x8000_75-11_r0.85_p_mean', '11-XuvYuv_lVcm_r0.85_p_mean', '11-NV-Importance_r0.85_p_mean', 'Full_Size_Baseline_75-11_r0.85_p_mean'], ['Baseline_1024x8000_75-11_r0.75_p_step', 'Baseline_1024x8000_75-11_r0.75_p_mean', '11-XuvYuv_lVcm_r0.75_p_mean', '11-NV-Importance_r0.75_p_mean', 'Full_Size_Baseline_75-11_r0.75_p_mean']]
# [('Baseline_1024x8000_75-11_r1.0_p_step', 350000), ('Baseline_1024x8000_75-11_r1.0_p_mean', 0.0881275117397308), ('11-XuvYuv_lVcm_r1.0_p_mean', 0.0814367964863777), ('11-NV-Importance_r1.0_p_mean', 0.1035114035010337), ('Full_Size_Baseline_75-11_r1.0_p_mean', 0.0986334443092346)]
# [('Baseline_1024x8000_75-11_r0.85_p_step', 350000), ('Baseline_1024x8000_75-11_r0.85_p_mean', 0.1266953289508819), ('11-XuvYuv_lVcm_r0.85_p_mean', 0.120225803554058), ('11-NV-Importance_r0.85_p_mean', 0.1433752417564392), ('Full_Size_Baseline_75-11_r0.85_p_mean', 0.1368416130542755)]
# [('Baseline_1024x8000_75-11_r0.75_p_step', 350000), ('Baseline_1024x8000_75-11_r0.75_p_mean', 0.1533395498991012), ('11-XuvYuv_lVcm_r0.75_p_mean', 0.1455007761716842), ('11-NV-Importance_r0.75_p_mean', 0.1689057826995849), ('Full_Size_Baseline_75-11_r0.75_p_mean', 0.16146200299263)]

# %%
#plot step series u
plotVars_p_allValidators = [[f'{subfolders[0]}_{j}_u_step'] + [f'{i}_{j}_u_mean' for i in subfolders ] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
stepFilter = dataframes[0][f'{subfolders[0]}_r1.0_u_step'] >= sFilter
#fmt = '[marker][line][color]' linestyle='--', marker='o', color='b'
#fmts = ['-r','--*b',':^g','-.xc']
#formats = {'marker':['.','*','^','x'], 'linestyle':['-','--',':','-.'], 'color':['r','b','g','c']}

plotVar = 'u'
font2 = {'family':'serif','color':'black','size':20}
manualLegend_u = [[f'{j}_{i}_{plotVar}' for j in legendNames] for i in validatorsRename.values()] ##UPDATE
manualLegend_u_agg = [f'{j}_{plotVar}' for j in legendNames] ##UPDATE

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (20,5))
    #fig.suptitle(f'P step series for {agNames[i]}')
    plt.rc('legend', fontsize = 12)
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        axes[k].tick_params(axis='both', labelsize=18)
        print(f'{[(l,dataframes[i][j][l][99]) for l in dataframes[i][j]]}')
        dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k], markersize=mSize)
        axes[k].set_xlabel(j[0].split('_')[0]+str(j[0].split('_')[-3:-1]), fontdict=font2)
        axes[k].legend(manualLegend_u[k])

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (9,5))
    fig.suptitle(f'U step series for {agNames[i]}')
    axes.set_ylabel('l2_relative_error')
    for k in range(1,len(plotVars_p_allValidators[0])):
        set_cycler(axes)
        axes.ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        dataframes[i][f'{subfolders[k-1]}_u_mean'] = dataframes[i][[plotVars_p_allValidators[q][k] for q in range(len(plotVars_p_allValidators))]].mean(axis=1)
    dataframes[i][[plotVars_p_allValidators[0][0]]+[f'{subfolders[k-1]}_u_mean' for k in range(1,len(plotVars_p_allValidators[0]))]][stepFilter].plot(x=plotVars_p_allValidators[0][0],ax=axes, markersize=mSize)
    axes.legend(manualLegend_u_agg)
# Out:
# [['Baseline_1024x8000_75-11_r1.0_u_step', 'Baseline_1024x8000_75-11_r1.0_u_mean', '11-XuvYuv_lVcm_r1.0_u_mean', '11-NV-Importance_r1.0_u_mean', 'Full_Size_Baseline_75-11_r1.0_u_mean'], ['Baseline_1024x8000_75-11_r0.85_u_step', 'Baseline_1024x8000_75-11_r0.85_u_mean', '11-XuvYuv_lVcm_r0.85_u_mean', '11-NV-Importance_r0.85_u_mean', 'Full_Size_Baseline_75-11_r0.85_u_mean'], ['Baseline_1024x8000_75-11_r0.75_u_step', 'Baseline_1024x8000_75-11_r0.75_u_mean', '11-XuvYuv_lVcm_r0.75_u_mean', '11-NV-Importance_r0.75_u_mean', 'Full_Size_Baseline_75-11_r0.75_u_mean']]
# [('Baseline_1024x8000_75-11_r1.0_u_step', 350000), ('Baseline_1024x8000_75-11_r1.0_u_mean', 0.0288077943027019), ('11-XuvYuv_lVcm_r1.0_u_mean', 0.0275111079216003), ('11-NV-Importance_r1.0_u_mean', 0.0299384668469429), ('Full_Size_Baseline_75-11_r1.0_u_mean', 0.0286074053496122)]
# [('Baseline_1024x8000_75-11_r0.85_u_step', 350000), ('Baseline_1024x8000_75-11_r0.85_u_mean', 0.0254834938794374), ('11-XuvYuv_lVcm_r0.85_u_mean', 0.0259526498615741), ('11-NV-Importance_r0.85_u_mean', 0.0292544934898614), ('Full_Size_Baseline_75-11_r0.85_u_mean', 0.0277562476694583)]
# [('Baseline_1024x8000_75-11_r0.75_u_step', 350000), ('Baseline_1024x8000_75-11_r0.75_u_mean', 0.0324469063431024), ('11-XuvYuv_lVcm_r0.75_u_mean', 0.0311481025069952), ('11-NV-Importance_r0.75_u_mean', 0.0325848661363124), ('Full_Size_Baseline_75-11_r0.75_u_mean', 0.0318371728062629)]

# %%
#plot step series v 
plotVars_p_allValidators = [[f'{subfolders[0]}_{j}_v_step'] + [f'{i}_{j}_v_mean' for i in subfolders ] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
stepFilter = dataframes[0][f'{subfolders[0]}_r1.0_v_step'] >= sFilter
#fmt = '[marker][line][color]' linestyle='--', marker='o', color='b'
#fmts = ['-r','--*b',':^g','-.xc']
#formats = {'marker':['.','*','^','x'], 'linestyle':['-','--',':','-.'], 'color':['r','b','g','c']}

plotVar = 'v'
font2 = {'family':'serif','color':'black','size':20}
manualLegend_v = [[f'{j}_{i}_{plotVar}' for j in legendNames] for i in validatorsRename.values()] ##UPDATE
manualLegend_v_agg = [f'{j}_{plotVar}' for j in legendNames] ##UPDATE

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (20,5))
    #fig.suptitle(f'P step series for {agNames[i]}')
    plt.rc('legend', fontsize = 12)
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        axes[k].tick_params(axis='both', labelsize=18)
        print(f'{[(l,dataframes[i][j][l][99]) for l in dataframes[i][j]]}')
        dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k], markersize=mSize)
        axes[k].set_xlabel(j[0].split('_')[0]+str(j[0].split('_')[-3:-1]), fontdict=font2)
        axes[k].legend(manualLegend_v[k])

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (9,5))
    fig.suptitle(f'V Step Series for {agNames[i]}')
    axes.set_ylabel('l2_relative_error')
    for k in range(1,len(plotVars_p_allValidators[0])):
        set_cycler(axes)
        axes.ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        dataframes[i][f'{subfolders[k-1]}_v_mean'] = dataframes[i][[plotVars_p_allValidators[q][k] for q in range(len(plotVars_p_allValidators))]].mean(axis=1)
    dataframes[i][[plotVars_p_allValidators[0][0]]+[f'{subfolders[k-1]}_v_mean' for k in range(1,len(plotVars_p_allValidators[0]))]][stepFilter].plot(x=plotVars_p_allValidators[0][0],ax=axes, markersize=mSize)
    axes.legend(manualLegend_v_agg)
# Out:
# [['Baseline_1024x8000_75-11_r1.0_v_step', 'Baseline_1024x8000_75-11_r1.0_v_mean', '11-XuvYuv_lVcm_r1.0_v_mean', '11-NV-Importance_r1.0_v_mean', 'Full_Size_Baseline_75-11_r1.0_v_mean'], ['Baseline_1024x8000_75-11_r0.85_v_step', 'Baseline_1024x8000_75-11_r0.85_v_mean', '11-XuvYuv_lVcm_r0.85_v_mean', '11-NV-Importance_r0.85_v_mean', 'Full_Size_Baseline_75-11_r0.85_v_mean'], ['Baseline_1024x8000_75-11_r0.75_v_step', 'Baseline_1024x8000_75-11_r0.75_v_mean', '11-XuvYuv_lVcm_r0.75_v_mean', '11-NV-Importance_r0.75_v_mean', 'Full_Size_Baseline_75-11_r0.75_v_mean']]
# [('Baseline_1024x8000_75-11_r1.0_v_step', 350000), ('Baseline_1024x8000_75-11_r1.0_v_mean', 0.0264293037354946), ('11-XuvYuv_lVcm_r1.0_v_mean', 0.0257783200591802), ('11-NV-Importance_r1.0_v_mean', 0.0260727193206548), ('Full_Size_Baseline_75-11_r1.0_v_mean', 0.0257986631244421)]
# [('Baseline_1024x8000_75-11_r0.85_v_step', 350000), ('Baseline_1024x8000_75-11_r0.85_v_mean', 0.0239529177546501), ('11-XuvYuv_lVcm_r0.85_v_mean', 0.0238916806876659), ('11-NV-Importance_r0.85_v_mean', 0.0245715096592903), ('Full_Size_Baseline_75-11_r0.85_v_mean', 0.0242751438170671)]
# [('Baseline_1024x8000_75-11_r0.75_v_step', 350000), ('Baseline_1024x8000_75-11_r0.75_v_mean', 0.0331956379115581), ('11-XuvYuv_lVcm_r0.75_v_mean', 0.0325191795825958), ('11-NV-Importance_r0.75_v_mean', 0.0328353092074394), ('Full_Size_Baseline_75-11_r0.75_v_mean', 0.0326455757021904)]

# %%
subfolders[slice(0,2)]
# Out:
# ['Baseline_1024x8000_75-11', '11-XuvYuv_lVcm']

# %%
#plot time series p
plotVar = 'p'
plotVars_p_allValidators = [[(f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
ylims = [(.11,.17),(.07,.14),(.08,.17)]
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (20,5))
    #fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    ylims = [(.04,.17),(.07,.17),(.07,.17)]
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        if ylims[k] != ():
            axes[k].set_ylim(*ylims[k])
        axes[k].set_xlim((.5,5))
        #axes[k].set_ylim(*ylims[k])
        for l in j:
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
            rawdat[rawdat[l[0]] >= .7].plot(x=l[0],y=l[1],ax=axes[k], markersize=mSize)
            axes[k].set_xlabel('Wall Time (h)', fontdict=font2)
            axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
            axes[k].tick_params(axis='both', labelsize=18)
            print(l)
            time = [(q) for q in dataframes[i][l[0]]]
            print(f'{(time[-1]-time[1])/60/60}')
        axes[k].legend(manualLegend_p[k])

#plot time series p averaged
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (7,5))
    #fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes.set_ylabel('l2_relative_error', fontdict=font2)
    axes.ticklabel_format(axis='x', style='sci',scilimits=(0,0))
    axes.tick_params(axis='both', labelsize=18)
    axes.set_xlim((.8,5))
    axes.set_ylim((.08,.14))
    set_cycler(axes)
    for k,j in enumerate(plotVars_p_allValidators[0]): ##k is 0-3
        l = [plotVars_p_allValidators[j][k] for j in range(len(plotVars_p_allValidators))]
        l = [l[0][0]] + [j[1] for j in l]
        #print('###############################')
        #print(l)
        rawdat = dataframes[i][l]
        rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
        rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
        rawdat[rawdat[l[0]] >= .7].plot(x=l[0],y=f'{subfolders[k]}_{plotVar}_mean',ax=axes, markersize=mSize)
        time = [(q) for q in dataframes[i][l[0]]]
        print(f'{(time[-1]-time[1])/60/60}')
        axes.set_xlabel('Wall Time (h)', fontdict=font2)
        axes.legend(manualLegend_p_agg)


plotVars_p_allValidators = [[(f'{i}_{j}_{plotVar}_step',f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
for i in range(len(dataframes)):
    rawdat_runs = []
    for k,j in enumerate(plotVars_p_allValidators[0]): ##k is 0-3
        l = [plotVars_p_allValidators[j][k] for j in range(len(plotVars_p_allValidators))] #k is a given RUN, j is a given VALIDATOR (r1.0, r0.85, r0.75)
        l = [l[0][0]] + [l[0][1]] + [j[2] for j in l] ##step, time, r1.0, r0.85, r0.75
        print('###############################')
        print(l)
        rawdat = dataframes[i][l]
        rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
        rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75
        #print(rawdat)
        rawdat_runs.append(rawdat)
        time = [(q) for q in dataframes[i][l[1]]]
        print(f'{(time[-1]-time[1])/60/60}')

for i in rawdat_runs:
    keys = [list(i.columns)[1]] + [list(i.columns)[5]]
    print(keys)
    print(i[60:][keys])
# Out:
# [[('Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r1.0_p_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_p_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r1.0_p_mean'), ('Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r1.0_p_mean')], [('Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.85_p_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.85_p_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r0.85_p_mean'), ('Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.85_p_mean')], [('Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.75_p_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.75_p_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r0.75_p_mean'), ('Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.75_p_mean')]]
# ('Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r1.0_p_mean')
# 2.982753561668926
# ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_p_mean')
# 4.0283036708169515
# ('11-NV-Importance_wall_time', '11-NV-Importance_r1.0_p_mean')
# 4.69313878721661
# ('Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r1.0_p_mean')
# 7.028629274368286
# ('Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.85_p_mean')
# 2.982753561668926
# ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.85_p_mean')
# 4.0283036708169515
# ('11-NV-Importance_wall_time', '11-NV-Importance_r0.85_p_mean')
# 4.69313878721661
# ('Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.85_p_mean')
# 7.028629274368286
# ('Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.75_p_mean')
# 2.982753561668926
# ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.75_p_mean')
# 4.0283036708169515
# ('11-NV-Importance_wall_time', '11-NV-Importance_r0.75_p_mean')
# 4.69313878721661
# ('Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.75_p_mean')
# 7.028629274368286
# 2.982753561668926
# 4.0283036708169515
# 4.69313878721661
# 7.028629274368286
# [[('Baseline_1024x8000_75-11_r1.0_p_step', 'Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r1.0_p_mean'), ('11-XuvYuv_lVcm_r1.0_p_step', '11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_p_mean'), ('11-NV-Importance_r1.0_p_step', '11-NV-Importance_wall_time', '11-NV-Importance_r1.0_p_mean'), ('Full_Size_Baseline_75-11_r1.0_p_step', 'Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r1.0_p_mean')], [('Baseline_1024x8000_75-11_r0.85_p_step', 'Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.85_p_mean'), ('11-XuvYuv_lVcm_r0.85_p_step', '11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.85_p_mean'), ('11-NV-Importance_r0.85_p_step', '11-NV-Importance_wall_time', '11-NV-Importance_r0.85_p_mean'), ('Full_Size_Baseline_75-11_r0.85_p_step', 'Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.85_p_mean')], [('Baseline_1024x8000_75-11_r0.75_p_step', 'Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.75_p_mean'), ('11-XuvYuv_lVcm_r0.75_p_step', '11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.75_p_mean'), ('11-NV-Importance_r0.75_p_step', '11-NV-Importance_wall_time', '11-NV-Importance_r0.75_p_mean'), ('Full_Size_Baseline_75-11_r0.75_p_step', 'Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.75_p_mean')]]
# ###############################
# ['Baseline_1024x8000_75-11_r1.0_p_step', 'Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r1.0_p_mean', 'Baseline_1024x8000_75-11_r0.85_p_mean', 'Baseline_1024x8000_75-11_r0.75_p_mean']
# 2.982753561668926
# ###############################
# ['11-XuvYuv_lVcm_r1.0_p_step', '11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_p_mean', '11-XuvYuv_lVcm_r0.85_p_mean', '11-XuvYuv_lVcm_r0.75_p_mean']
# 4.0283036708169515
# ###############################
# ['11-NV-Importance_r1.0_p_step', '11-NV-Importance_wall_time', '11-NV-Importance_r1.0_p_mean', '11-NV-Importance_r0.85_p_mean', '11-NV-Importance_r0.75_p_mean']
# 4.69313878721661
# ###############################
# ['Full_Size_Baseline_75-11_r1.0_p_step', 'Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r1.0_p_mean', 'Full_Size_Baseline_75-11_r0.85_p_mean', 'Full_Size_Baseline_75-11_r0.75_p_mean']
# 7.028629274368286
# ['Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_p_mean']
#     Baseline_1024x8000_75-11_wall_time  Baseline_1024x8000_75-11_p_mean
# 60                            1.944831                         0.120145
# 61                            1.979434                         0.120473
# 62                            1.996487                         0.120446
# 63                            2.005014                         0.120348
# 64                            2.030744                         0.120259
# 65                            2.056889                         0.120402
# 66                            2.082606                         0.120476
# 67                            2.091226                         0.120620
# 68                            2.117426                         0.120518
# 69                            2.125976                         0.121108
# 70                            2.143099                         0.121346
# 71                            2.203769                         0.121172
# 72                            2.238193                         0.121659
# 73                            2.264466                         0.121426
# 74                            2.273017                         0.121437
# 75                            2.298872                         0.121772
# 76                            2.325138                         0.121787
# 77                            2.333696                         0.121838
# 78                            2.350827                         0.121553
# 79                            2.368120                         0.122032
# 80                            2.420065                         0.121931
# 81                            2.454570                         0.122166
# 82                            2.463697                         0.122190
# 83                            2.523791                         0.122227
# 84                            2.541483                         0.122210
# 85                            2.550038                         0.122314
# 86                            2.558601                         0.122421
# 87                            2.593028                         0.122290
# 88                            2.619294                         0.122391
# 89                            2.627851                         0.122458
# 90                            2.705824                         0.122375
# 91                            2.722936                         0.122382
# 92                            2.740640                         0.122538
# 93                            2.757752                         0.122467
# 94                            2.783613                         0.122587
# 95                            2.870033                         0.122540
# 96                            2.913585                         0.122662
# 97                            2.939256                         0.122711
# 98                            2.956958                         0.122657
# 99                            2.999925                         0.122721
# ['11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_p_mean']
#     11-XuvYuv_lVcm_wall_time  11-XuvYuv_lVcm_p_mean
# 60                  2.575395               0.114131
# 61                  2.620580               0.114446
# 62                  2.650368               0.114345
# 63                  2.659750               0.115477
# 64                  2.693092               0.115543
# 65                  2.729358               0.114969
# 66                  2.756683               0.116087
# 67                  2.766326               0.115123
# 68                  2.804292               0.116091
# 69                  2.814330               0.116278
# 70                  2.835287               0.116243
# 71                  2.951937               0.115313
# 72                  2.999905               0.115999
# 73                  3.030376               0.115904
# 74                  3.048582               0.115439
# 75                  3.081025               0.115404
# 76                  3.111897               0.115498
# 77                  3.122096               0.115941
# 78                  3.144122               0.115374
# 79                  3.166482               0.115395
# 80                  3.231481               0.115559
# 81                  3.274563               0.115682
# 82                  3.285799               0.115434
# 83                  3.399261               0.115821
# 84                  3.421567               0.116026
# 85                  3.436086               0.116249
# 86                  3.446794               0.116095
# 87                  3.491342               0.116236
# 88                  3.528897               0.116565
# 89                  3.542732               0.116442
# 90                  3.637478               0.116495
# 91                  3.656678               0.116520
# 92                  3.680629               0.116713
# 93                  3.709463               0.116668
# 94                  3.767388               0.116734
# 95                  3.884926               0.116014
# 96                  3.938292               0.115922
# 97                  3.974597               0.115874
# 98                  3.994936               0.115771
# 99                  4.045260               0.115721
# ['11-NV-Importance_wall_time', '11-NV-Importance_p_mean']
#     11-NV-Importance_wall_time  11-NV-Importance_p_mean
# 60                    2.993791                 0.136413
# 61                    3.053953                 0.137010
# 62                    3.079397                 0.135811
# 63                    3.092138                 0.136385
# 64                    3.139293                 0.137274
# 65                    3.177647                 0.136271
# 66                    3.215831                 0.136813
# 67                    3.237400                 0.136467
# 68                    3.275629                 0.137016
# 69                    3.288312                 0.137363
# 70                    3.313696                 0.136781
# 71                    3.411859                 0.137578
# 72                    3.471456                 0.138151
# 73                    3.509533                 0.138157
# 74                    3.531083                 0.137627
# 75                    3.569250                 0.138457
# 76                    3.607452                 0.137850
# 77                    3.629019                 0.137871
# 78                    3.654238                 0.137697
# 79                    3.679589                 0.136875
# 80                    3.765149                 0.137971
# 81                    3.825932                 0.138073
# 82                    3.839009                 0.138148
# 83                    3.937990                 0.137848
# 84                    3.963593                 0.138065
# 85                    3.976301                 0.138151
# 86                    3.988968                 0.138704
# 87                    4.048667                 0.138639
# 88                    4.086796                 0.138348
# 89                    4.099452                 0.138395
# 90                    4.231800                 0.138431
# 91                    4.257129                 0.138533
# 92                    4.282636                 0.138496
# 93                    4.316812                 0.138638
# 94                    4.355511                 0.138762
# 95                    4.492529                 0.138690
# 96                    4.565906                 0.138649
# 97                    4.613427                 0.138765
# 98                    4.639147                 0.138559
# 99                    4.712893                 0.138597
# ['Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_p_mean']
#     Full_Size_Baseline_75-11_wall_time  Full_Size_Baseline_75-11_p_mean
# 60                            4.587991                         0.128579
# 61                            4.669349                         0.130351
# 62                            4.709478                         0.130120
# 63                            4.729561                         0.129676
# 64                            4.790825                         0.129820
# 65                            4.852108                         0.130976
# 66                            4.913445                         0.130724
# 67                            4.933570                         0.130734
# 68                            4.994844                         0.131569
# 69                            5.014909                         0.130954
# 70                            5.055061                         0.130584
# 71                            5.197692                         0.129961
# 72                            5.279037                         0.131319
# 73                            5.340342                         0.131486
# 74                            5.360418                         0.130953
# 75                            5.421703                         0.131047
# 76                            5.483014                         0.131823
# 77                            5.503076                         0.131641
# 78                            5.543240                         0.131414
# 79                            5.584445                         0.131571
# 80                            5.706000                         0.131548
# 81                            5.787482                         0.131743
# 82                            5.808634                         0.131664
# 83                            5.950111                         0.131967
# 84                            5.991242                         0.132050
# 85                            6.011275                         0.131831
# 86                            6.031308                         0.131967
# 87                            6.112510                         0.132079
# 88                            6.173703                         0.132035
# 89                            6.193741                         0.132020
# 90                            6.377311                         0.132277
# 91                            6.417485                         0.132200
# 92                            6.458864                         0.132242
# 93                            6.499092                         0.132220
# 94                            6.560397                         0.132226
# 95                            6.763630                         0.132355
# 96                            6.866336                         0.132271
# 97                            6.926680                         0.132351
# 98                            6.968034                         0.132414
# 99                            7.069659                         0.132312
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\3861603870.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75

# %%
#plot time series u
plotVar = 'u'
plotVars_p_allValidators = [[(f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
#set plotVar to uppercase
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (20,5))
    #fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    ylims = [(.025,.055),(.02,.04),(.02,.04)]
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        if ylims[k] != ():
            axes[k].set_ylim(*ylims[k])
        axes[k].set_xlim((1,6))
        #axes[k].set_ylim(*ylims[k])
        for l in j:
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
            rawdat[rawdat[l[0]] >= .7].plot(x=l[0],y=l[1],ax=axes[k], markersize=mSize)
            axes[k].set_xlabel('Wall Time (h)', fontdict=font2)
            axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
            axes[k].tick_params(axis='both', labelsize=18)
        axes[k].legend(manualLegend_u[k])

#plot time series u averaged
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (7,5))
    #fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes.set_ylabel('l2_relative_error', fontdict=font2)
    axes.ticklabel_format(axis='x', style='sci',scilimits=(0,0))
    axes.tick_params(axis='both', labelsize=18)
    axes.set_xlim((1,5))
    axes.set_ylim((.0275,.032))
    set_cycler(axes)
    for k,j in enumerate(plotVars_p_allValidators[0]): ##k is 0-3
        l = [plotVars_p_allValidators[j][k] for j in range(len(plotVars_p_allValidators))]
        l = [l[0][0]] + [j[1] for j in l]
        #print('###############################')
        print(l)
        rawdat = dataframes[i][l]
        rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
        rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
        rawdat[rawdat[l[0]] >= .7].plot(x=l[0],y=f'{subfolders[k]}_{plotVar}_mean',ax=axes, markersize=mSize)
        time = [(q) for q in dataframes[i][l[0]]]
        print(f'{(time[-1]-time[1])/60/60}')
        axes.set_xlabel('Wall Time (h)', fontdict=font2)
        axes.legend(manualLegend_u_agg)


####find mins
plotVars_p_allValidators = [[(f'{i}_{j}_{plotVar}_step',f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
for i in range(len(dataframes)):
    rawdat_runs = []
    for k,j in enumerate(plotVars_p_allValidators[0]): ##k is 0-3
        l = [plotVars_p_allValidators[j][k] for j in range(len(plotVars_p_allValidators))] #k is a given RUN, j is a given VALIDATOR (r1.0, r0.85, r0.75)
        l = [l[0][0]] + [l[0][1]] + [j[2] for j in l] ##step, time, r1.0, r0.85, r0.75
        print('###############################')
        print(l)
        rawdat = dataframes[i][l]
        rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
        rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75
        rawdat_runs.append(rawdat)
        time = [(q) for q in dataframes[i][l[1]]]
        print(f'{(time[-1]-time[1])/60/60}')
    
    print('###############################')
    minimums = []
    for k,rawdat in enumerate(rawdat_runs):
        print(rawdat.columns)
        tm = []
        minCol = list(rawdat.columns)[-1]
        minColNum = len(list(rawdat.columns))-1
        timeCol = [j for j in list(rawdat.columns) if 'wall_time' in j][0]
        print(f'minCol, minColNum, timeCol: {minCol}, {minColNum}, {timeCol}')
        print('## min')
        tm.append(rawdat.min()[minColNum])
        print(rawdat.min()[minColNum])
        print('--idxmin')
        tm.append(rawdat.idxmin()[minColNum])
        print(rawdat.idxmin()[minColNum])
        print('--time')
        tm.append(rawdat.loc[rawdat.idxmin()[minColNum],timeCol])
        print(rawdat.loc[rawdat.idxmin()[minColNum],timeCol])
        #minimums.append((j[2],'val/idx/hr',tm))
        minimums.append(tm)
        print(minimums)

#SPADE vs baseline 4096

meanFilter = rawdat_runs[1][f'11-XuvYuv_lVcm_{plotVar}_mean'] <= minimums[-1][0]
rawdat = rawdat_runs[1][['11-XuvYuv_lVcm_wall_time',f'11-XuvYuv_lVcm_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat)

#SPADE vs Importance
meanFilter = rawdat_runs[1][f'11-XuvYuv_lVcm_{plotVar}_mean'] <= minimums[-2][0]
print(minimums[-2][0])
rawdat = rawdat_runs[1][['11-XuvYuv_lVcm_wall_time',f'11-XuvYuv_lVcm_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat)

#SPADE vs 1024
meanFilter = rawdat_runs[1][f'11-XuvYuv_lVcm_{plotVar}_mean'] <= minimums[0][0]
print(minimums[-2][0])
rawdat = rawdat_runs[1][['11-XuvYuv_lVcm_wall_time',f'11-XuvYuv_lVcm_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat)

#Importance vs baseline 4096
meanFilter = rawdat_runs[2][f'11-NV-Importance_{plotVar}_mean'] <= minimums[-1][0]
rawdat = rawdat_runs[2][['11-NV-Importance_wall_time',f'11-NV-Importance_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat)

print('Baseline 4096 vs Importance')
#Baseline 4096 vs Importance
meanFilter = rawdat_runs[3][f'Full_Size_Baseline_75-11_{plotVar}_mean'] <= minimums[-2][0]
rawdat = rawdat_runs[3][['Full_Size_Baseline_75-11_wall_time',f'Full_Size_Baseline_75-11_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat)

print('Baseline 1024 vs Importance')
#Baseline 1024 vs Importance
meanFilter = rawdat_runs[0][f'Baseline_1024x8000_75-11_{plotVar}_mean'] <= minimums[-2][0]
rawdat = rawdat_runs[0][['Baseline_1024x8000_75-11_wall_time',f'Baseline_1024x8000_75-11_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat)

#Baseline 4096 vs 1024
meanFilter = rawdat_runs[3][f'Full_Size_Baseline_75-11_{plotVar}_mean'] <= minimums[0][0]
rawdat = rawdat_runs[3][['Full_Size_Baseline_75-11_wall_time',f'Full_Size_Baseline_75-11_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat[0:1])
# Out:
# [[('Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r1.0_u_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_u_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r1.0_u_mean'), ('Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r1.0_u_mean')], [('Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.85_u_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.85_u_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r0.85_u_mean'), ('Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.85_u_mean')], [('Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.75_u_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.75_u_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r0.75_u_mean'), ('Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.75_u_mean')]]
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\1652604317.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75
# ['Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r1.0_u_mean', 'Baseline_1024x8000_75-11_r0.85_u_mean', 'Baseline_1024x8000_75-11_r0.75_u_mean']
# 2.982753561668926
# ['11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_u_mean', '11-XuvYuv_lVcm_r0.85_u_mean', '11-XuvYuv_lVcm_r0.75_u_mean']
# 4.0283036708169515
# ['11-NV-Importance_wall_time', '11-NV-Importance_r1.0_u_mean', '11-NV-Importance_r0.85_u_mean', '11-NV-Importance_r0.75_u_mean']
# 4.69313878721661
# ['Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r1.0_u_mean', 'Full_Size_Baseline_75-11_r0.85_u_mean', 'Full_Size_Baseline_75-11_r0.75_u_mean']
# 7.028629274368286
# [[('Baseline_1024x8000_75-11_r1.0_u_step', 'Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r1.0_u_mean'), ('11-XuvYuv_lVcm_r1.0_u_step', '11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_u_mean'), ('11-NV-Importance_r1.0_u_step', '11-NV-Importance_wall_time', '11-NV-Importance_r1.0_u_mean'), ('Full_Size_Baseline_75-11_r1.0_u_step', 'Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r1.0_u_mean')], [('Baseline_1024x8000_75-11_r0.85_u_step', 'Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.85_u_mean'), ('11-XuvYuv_lVcm_r0.85_u_step', '11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.85_u_mean'), ('11-NV-Importance_r0.85_u_step', '11-NV-Importance_wall_time', '11-NV-Importance_r0.85_u_mean'), ('Full_Size_Baseline_75-11_r0.85_u_step', 'Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.85_u_mean')], [('Baseline_1024x8000_75-11_r0.75_u_step', 'Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.75_u_mean'), ('11-XuvYuv_lVcm_r0.75_u_step', '11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.75_u_mean'), ('11-NV-Importance_r0.75_u_step', '11-NV-Importance_wall_time', '11-NV-Importance_r0.75_u_mean'), ('Full_Size_Baseline_75-11_r0.75_u_step', 'Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.75_u_mean')]]
# ###############################
# ['Baseline_1024x8000_75-11_r1.0_u_step', 'Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r1.0_u_mean', 'Baseline_1024x8000_75-11_r0.85_u_mean', 'Baseline_1024x8000_75-11_r0.75_u_mean']
# 2.982753561668926
# ###############################
# ['11-XuvYuv_lVcm_r1.0_u_step', '11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_u_mean', '11-XuvYuv_lVcm_r0.85_u_mean', '11-XuvYuv_lVcm_r0.75_u_mean']
# 4.0283036708169515
# ###############################
# ['11-NV-Importance_r1.0_u_step', '11-NV-Importance_wall_time', '11-NV-Importance_r1.0_u_mean', '11-NV-Importance_r0.85_u_mean', '11-NV-Importance_r0.75_u_mean']
# 4.69313878721661
# ###############################
# ['Full_Size_Baseline_75-11_r1.0_u_step', 'Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r1.0_u_mean', 'Full_Size_Baseline_75-11_r0.85_u_mean', 'Full_Size_Baseline_75-11_r0.75_u_mean']
# 7.028629274368286
# ###############################
# Index(['Baseline_1024x8000_75-11_r1.0_u_step',
#        'Baseline_1024x8000_75-11_wall_time',
#        'Baseline_1024x8000_75-11_r1.0_u_mean',
#        'Baseline_1024x8000_75-11_r0.85_u_mean',
#        'Baseline_1024x8000_75-11_r0.75_u_mean',
#        'Baseline_1024x8000_75-11_u_mean'],
#       dtype='object')
# minCol, minColNum, timeCol: Baseline_1024x8000_75-11_u_mean, 5, Baseline_1024x8000_75-11_wall_time
# ## min
# 0.028867764398455564
# --idxmin
# 71
# --time
# 2.2037693115075427
# [[0.028867764398455564, 71, 2.2037693115075427]]
# Index(['11-XuvYuv_lVcm_r1.0_u_step', '11-XuvYuv_lVcm_wall_time',
#        '11-XuvYuv_lVcm_r1.0_u_mean', '11-XuvYuv_lVcm_r0.85_u_mean',
#        '11-XuvYuv_lVcm_r0.75_u_mean', '11-XuvYuv_lVcm_u_mean'],
#       dtype='object')
# minCol, minColNum, timeCol: 11-XuvYuv_lVcm_u_mean, 5, 11-XuvYuv_lVcm_wall_time
# ## min
# 0.02777713984251017
# --idxmin
# 50
# --time
# 2.1417313008838232
# [[0.028867764398455564, 71, 2.2037693115075427], [0.02777713984251017, 50, 2.1417313008838232]]
# Index(['11-NV-Importance_r1.0_u_step', '11-NV-Importance_wall_time',
#        '11-NV-Importance_r1.0_u_mean', '11-NV-Importance_r0.85_u_mean',
#        '11-NV-Importance_r0.75_u_mean', '11-NV-Importance_u_mean'],
#       dtype='object')
# minCol, minColNum, timeCol: 11-NV-Importance_u_mean, 5, 11-NV-Importance_wall_time
# ## min
# 0.02943610623478887
# --idxmin
# 44
# --time
# 2.320230576131079
# [[0.028867764398455564, 71, 2.2037693115075427], [0.02777713984251017, 50, 2.1417313008838232], [0.02943610623478887, 44, 2.320230576131079]]
# Index(['Full_Size_Baseline_75-11_r1.0_u_step',
#        'Full_Size_Baseline_75-11_wall_time',
#        'Full_Size_Baseline_75-11_r1.0_u_mean',
#        'Full_Size_Baseline_75-11_r0.85_u_mean',
#        'Full_Size_Baseline_75-11_r0.75_u_mean',
#        'Full_Size_Baseline_75-11_u_mean'],
#       dtype='object')
# minCol, minColNum, timeCol: Full_Size_Baseline_75-11_u_mean, 5, Full_Size_Baseline_75-11_wall_time
# ## min
# 0.028450035303831066
# --idxmin
# 45
# --time
# 3.6330202901363373
# [[0.028867764398455564, 71, 2.2037693115075427], [0.02777713984251017, 50, 2.1417313008838232], [0.02943610623478887, 44, 2.320230576131079], [0.028450035303831066, 45, 3.6330202901363373]]
#     11-XuvYuv_lVcm_wall_time  11-XuvYuv_lVcm_u_mean
# 44                  2.001275               0.028322
# 45                  2.010648               0.028306
# 46                  2.038165               0.028379
# 47                  2.048499               0.028223
# 48                  2.084678               0.028110
# 49                  2.094365               0.028121
# 50                  2.141731               0.027777
# 51                  2.157957               0.028154
# 52                  2.209967               0.027989
# 53                  2.219971               0.027834
# 54                  2.304776               0.027991
# 55                  2.340174               0.027972
# 56                  2.426535               0.027849
# 57                  2.529224               0.028043
# 58                  2.543151               0.028016
# 59                  2.554700               0.028108
# 60                  2.575395               0.028117
# 61                  2.620580               0.028203
# 62                  2.650368               0.028251
# 63                  2.659750               0.028370
# 64                  2.693092               0.028348
# 65                  2.729358               0.028407
# 66                  2.756683               0.028354
# 67                  2.766326               0.028378
# 68                  2.804292               0.028345
# 69                  2.814330               0.028363
# 70                  2.835287               0.028365
# 71                  2.951937               0.028265
# 72                  2.999905               0.028183
# 73                  3.030376               0.028193
# 74                  3.048582               0.028189
# 75                  3.081025               0.028140
# 76                  3.111897               0.028121
# 77                  3.122096               0.028138
# 78                  3.144122               0.028109
# 79                  3.166482               0.028194
# 80                  3.231481               0.028138
# 81                  3.274563               0.028127
# 82                  3.285799               0.028114
# 83                  3.399261               0.028230
# 84                  3.421567               0.028229
# 85                  3.436086               0.028220
# 86                  3.446794               0.028236
# 87                  3.491342               0.028246
# 88                  3.528897               0.028235
# 89                  3.542732               0.028261
# 90                  3.637478               0.028270
# 91                  3.656678               0.028286
# 92                  3.680629               0.028266
# 93                  3.709463               0.028274
# 94                  3.767388               0.028288
# 95                  3.884926               0.028274
# 96                  3.938292               0.028241
# 97                  3.974597               0.028250
# 98                  3.994936               0.028246
# 99                  4.045260               0.028204
# 0.02943610623478887
#     11-XuvYuv_lVcm_wall_time  11-XuvYuv_lVcm_u_mean
# 44                  2.001275               0.028322
# 45                  2.010648               0.028306
# 46                  2.038165               0.028379
# 47                  2.048499               0.028223
# 48                  2.084678               0.028110
# 49                  2.094365               0.028121
# 50                  2.141731               0.027777
# 51                  2.157957               0.028154
# 52                  2.209967               0.027989
# 53                  2.219971               0.027834
# 54                  2.304776               0.027991
# 55                  2.340174               0.027972
# 56                  2.426535               0.027849
# 57                  2.529224               0.028043
# 58                  2.543151               0.028016
# 59                  2.554700               0.028108
# 60                  2.575395               0.028117
# 61                  2.620580               0.028203
# 62                  2.650368               0.028251
# 63                  2.659750               0.028370
# 64                  2.693092               0.028348
# 65                  2.729358               0.028407
# 66                  2.756683               0.028354
# 67                  2.766326               0.028378
# 68                  2.804292               0.028345
# 69                  2.814330               0.028363
# 70                  2.835287               0.028365
# 71                  2.951937               0.028265
# 72                  2.999905               0.028183
# 73                  3.030376               0.028193
# 74                  3.048582               0.028189
# 75                  3.081025               0.028140
# 76                  3.111897               0.028121
# 77                  3.122096               0.028138
# 78                  3.144122               0.028109
# 79                  3.166482               0.028194
# 80                  3.231481               0.028138
# 81                  3.274563               0.028127
# 82                  3.285799               0.028114
# 83                  3.399261               0.028230
# 84                  3.421567               0.028229
# 85                  3.436086               0.028220
# 86                  3.446794               0.028236
# 87                  3.491342               0.028246
# 88                  3.528897               0.028235
# 89                  3.542732               0.028261
# 90                  3.637478               0.028270
# 91                  3.656678               0.028286
# 92                  3.680629               0.028266
# 93                  3.709463               0.028274
# 94                  3.767388               0.028288
# 95                  3.884926               0.028274
# 96                  3.938292               0.028241
# 97                  3.974597               0.028250
# 98                  3.994936               0.028246
# 99                  4.045260               0.028204
# 0.02943610623478887
#     11-XuvYuv_lVcm_wall_time  11-XuvYuv_lVcm_u_mean
# 44                  2.001275               0.028322
# 45                  2.010648               0.028306
# 46                  2.038165               0.028379
# 47                  2.048499               0.028223
# 48                  2.084678               0.028110
# 49                  2.094365               0.028121
# 50                  2.141731               0.027777
# 51                  2.157957               0.028154
# 52                  2.209967               0.027989
# 53                  2.219971               0.027834
# 54                  2.304776               0.027991
# 55                  2.340174               0.027972
# 56                  2.426535               0.027849
# 57                  2.529224               0.028043
# 58                  2.543151               0.028016
# 59                  2.554700               0.028108
# 60                  2.575395               0.028117
# 61                  2.620580               0.028203
# 62                  2.650368               0.028251
# 63                  2.659750               0.028370
# 64                  2.693092               0.028348
# 65                  2.729358               0.028407
# 66                  2.756683               0.028354
# 67                  2.766326               0.028378
# 68                  2.804292               0.028345
# 69                  2.814330               0.028363
# 70                  2.835287               0.028365
# 71                  2.951937               0.028265
# 72                  2.999905               0.028183
# 73                  3.030376               0.028193
# 74                  3.048582               0.028189
# 75                  3.081025               0.028140
# 76                  3.111897               0.028121
# 77                  3.122096               0.028138
# 78                  3.144122               0.028109
# 79                  3.166482               0.028194
# 80                  3.231481               0.028138
# 81                  3.274563               0.028127
# 82                  3.285799               0.028114
# 83                  3.399261               0.028230
# 84                  3.421567               0.028229
# 85                  3.436086               0.028220
# 86                  3.446794               0.028236
# 87                  3.491342               0.028246
# 88                  3.528897               0.028235
# 89                  3.542732               0.028261
# 90                  3.637478               0.028270
# 91                  3.656678               0.028286
# 92                  3.680629               0.028266
# 93                  3.709463               0.028274
# 94                  3.767388               0.028288
# 95                  3.884926               0.028274
# 96                  3.938292               0.028241
# 97                  3.974597               0.028250
# 98                  3.994936               0.028246
# 99                  4.045260               0.028204
# Empty DataFrame
# Columns: [11-NV-Importance_wall_time, 11-NV-Importance_u_mean]
# Index: []
# Baseline 4096 vs Importance
#     Full_Size_Baseline_75-11_wall_time  Full_Size_Baseline_75-11_u_mean
# 38                            3.022608                         0.029197
# 39                            3.083871                         0.028991
# 40                            3.206316                         0.028984
# 41                            3.226348                         0.028475
# 42                            3.287546                         0.028616
# ..                                 ...                              ...
# 95                            6.763630                         0.029403
# 96                            6.866336                         0.029403
# 97                            6.926680                         0.029389
# 98                            6.968034                         0.029392
# 99                            7.069659                         0.029400
#
# [62 rows x 2 columns]
# Baseline 1024 vs Importance
#     Baseline_1024x8000_75-11_wall_time  Baseline_1024x8000_75-11_u_mean
# 51                            1.652065                         0.029223
# 52                            1.686320                         0.029320
# 53                            1.694847                         0.029422
# 54                            1.763782                         0.029285
# 55                            1.789896                         0.029150
# 56                            1.850244                         0.029146
# 57                            1.910593                         0.028983
# 58                            1.919112                         0.029014
# 59                            1.927626                         0.029032
# 60                            1.944831                         0.029001
# 61                            1.979434                         0.029090
# 62                            1.996487                         0.029031
# 63                            2.005014                         0.029089
# 64                            2.030744                         0.029066
# 65                            2.056889                         0.028984
# 66                            2.082606                         0.029006
# 67                            2.091226                         0.028999
# 68                            2.117426                         0.028954
# 69                            2.125976                         0.028903
# 70                            2.143099                         0.029013
# 71                            2.203769                         0.028868
# 72                            2.238193                         0.028923
# 73                            2.264466                         0.028944
# 74                            2.273017                         0.028934
# 75                            2.298872                         0.028916
# 76                            2.325138                         0.028896
# 77                            2.333696                         0.028931
# 78                            2.350827                         0.028925
# 79                            2.368120                         0.028983
# 80                            2.420065                         0.028926
# 81                            2.454570                         0.028982
# 82                            2.463697                         0.028916
# 83                            2.523791                         0.028887
# 84                            2.541483                         0.028914
# 85                            2.550038                         0.028949
# 86                            2.558601                         0.028899
# 87                            2.593028                         0.028914
# 88                            2.619294                         0.028899
# 89                            2.627851                         0.028925
# 90                            2.705824                         0.028908
# 91                            2.722936                         0.028929
# 92                            2.740640                         0.028936
# 93                            2.757752                         0.028945
# 94                            2.783613                         0.028941
# 95                            2.870033                         0.028922
# 96                            2.913585                         0.028921
# 97                            2.939256                         0.028931
# 98                            2.956958                         0.028919
# 99                            2.999925                         0.028913
#     Full_Size_Baseline_75-11_wall_time  Full_Size_Baseline_75-11_u_mean
# 41                            3.226348                         0.028475

# %%
#plot time series v
plotVar = 'v'
plotVars_p_allValidators = [[(f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
#set plotVar to uppercase
#ylims = [(.022,.05),(.022,.05),(.022,.05)]
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (20,5))
    #fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    ylims = [(.023,.038),(.023,.026),(.030,.033)]
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        if ylims[k] != ():
            axes[k].set_ylim(*ylims[k])
        axes[k].set_xlim((1,6))
        #axes[k].set_ylim(*ylims[k])
        for l in j:
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
            rawdat[rawdat[l[0]] >= .7].plot(x=l[0],y=l[1],ax=axes[k], markersize=mSize)
            axes[k].set_xlabel('Wall Time (h)', fontdict=font2)
            axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
            axes[k].tick_params(axis='both', labelsize=15)
        axes[k].legend(manualLegend_v[k])


#plot time series v averaged
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (7,5))
    #fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes.set_ylabel('l2_relative_error', fontdict=font2)
    axes.ticklabel_format(axis='x', style='sci',scilimits=(0,0))
    axes.tick_params(axis='both', labelsize=18)
    axes.set_xlim((1.5,5.5))
    axes.set_ylim((.027,.0285))
    set_cycler(axes)
    for k,j in enumerate(plotVars_p_allValidators[0]): ##k is 0-3
        l = [plotVars_p_allValidators[j][k] for j in range(len(plotVars_p_allValidators))]
        l = [l[0][0]] + [j[1] for j in l]
        #print('###############################')
        #print(l)
        rawdat = dataframes[i][l]
        rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
        rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
        rawdat[rawdat[l[0]] >= 1.1].plot(x=l[0],y=f'{subfolders[k]}_{plotVar}_mean',ax=axes, markersize=mSize)
        time = [(q) for q in dataframes[i][l[0]]]
        print(f'{(time[-1]-time[1])/60/60}')
        axes.set_xlabel('Wall Time (h)', fontdict=font2)
        axes.legend(manualLegend_v_agg)


####find mins
plotVars_p_allValidators = [[(f'{i}_{j}_{plotVar}_step',f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
for i in range(len(dataframes)):
    rawdat_runs = []
    for k,j in enumerate(plotVars_p_allValidators[0]): ##k is 0-3
        l = [plotVars_p_allValidators[j][k] for j in range(len(plotVars_p_allValidators))] #k is a given RUN, j is a given VALIDATOR (r1.0, r0.85, r0.75)
        l = [l[0][0]] + [l[0][1]] + [j[2] for j in l] ##step, time, r1.0, r0.85, r0.75
        print('###############################')
        print(l)
        rawdat = dataframes[i][l]
        rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
        rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75
        rawdat_runs.append(rawdat)
        time = [(q) for q in dataframes[i][l[1]]]
        print(f'{(time[-1]-time[1])/60/60}')
    
    print('###############################')
    minimums = []
    for k,rawdat in enumerate(rawdat_runs):
        print(rawdat.columns)
        tm = []
        minCol = list(rawdat.columns)[-1]
        minColNum = len(list(rawdat.columns))-1
        timeCol = [j for j in list(rawdat.columns) if 'wall_time' in j][0]
        print(f'minCol, minColNum, timeCol: {minCol}, {minColNum}, {timeCol}')
        print('## min')
        tm.append(rawdat.min()[minColNum])
        print(rawdat.min()[minColNum])
        print('--idxmin')
        tm.append(rawdat.idxmin()[minColNum])
        print(rawdat.idxmin()[minColNum])
        print('--time')
        tm.append(rawdat.loc[rawdat.idxmin()[minColNum],timeCol])
        print(rawdat.loc[rawdat.idxmin()[minColNum],timeCol])
        #minimums.append((j[2],'val/idx/hr',tm))
        minimums.append(tm)
        print(minimums)

#SPADE vs baseline 4096

meanFilter = rawdat_runs[1][f'11-XuvYuv_lVcm_{plotVar}_mean'] <= minimums[-1][0]
rawdat = rawdat_runs[1][['11-XuvYuv_lVcm_wall_time',f'11-XuvYuv_lVcm_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat)

#SPADE vs Importance
meanFilter = rawdat_runs[1][f'11-XuvYuv_lVcm_{plotVar}_mean'] <= minimums[-2][0]
rawdat = rawdat_runs[1][['11-XuvYuv_lVcm_wall_time',f'11-XuvYuv_lVcm_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat)

#Importance vs baseline 4096
meanFilter = rawdat_runs[2][f'11-NV-Importance_{plotVar}_mean'] <= minimums[-1][0]
rawdat = rawdat_runs[2][['11-NV-Importance_wall_time',f'11-NV-Importance_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat)

#Baseline 4096 vs Importance
meanFilter = rawdat_runs[3][f'Full_Size_Baseline_75-11_{plotVar}_mean'] <= minimums[-2][0]
rawdat = rawdat_runs[3][['Full_Size_Baseline_75-11_wall_time',f'Full_Size_Baseline_75-11_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat)

#SPADE vs 1024
meanFilter = rawdat_runs[1][f'11-XuvYuv_lVcm_{plotVar}_mean'] <= minimums[0][0]
print(minimums[-2][0])
rawdat = rawdat_runs[1][['11-XuvYuv_lVcm_wall_time',f'11-XuvYuv_lVcm_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat[0:1])

#Importance vs 1024
meanFilter = rawdat_runs[2][f'11-NV-Importance_{plotVar}_mean'] <= minimums[0][0]
rawdat = rawdat_runs[2][['11-NV-Importance_wall_time',f'11-NV-Importance_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat[0:1])

#Baseline 4096 vs 1024
meanFilter = rawdat_runs[3][f'Full_Size_Baseline_75-11_{plotVar}_mean'] <= minimums[0][0]
rawdat = rawdat_runs[3][['Full_Size_Baseline_75-11_wall_time',f'Full_Size_Baseline_75-11_{plotVar}_mean']]
rawdat = rawdat[meanFilter]
print(rawdat[0:1])
# Out:
# [[('Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r1.0_v_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_v_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r1.0_v_mean'), ('Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r1.0_v_mean')], [('Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.85_v_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.85_v_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r0.85_v_mean'), ('Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.85_v_mean')], [('Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.75_v_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.75_v_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r0.75_v_mean'), ('Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.75_v_mean')]]
# 2.982753561668926
# 4.0283036708169515
# 4.69313878721661
# 7.028629274368286
# [[('Baseline_1024x8000_75-11_r1.0_v_step', 'Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r1.0_v_mean'), ('11-XuvYuv_lVcm_r1.0_v_step', '11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_v_mean'), ('11-NV-Importance_r1.0_v_step', '11-NV-Importance_wall_time', '11-NV-Importance_r1.0_v_mean'), ('Full_Size_Baseline_75-11_r1.0_v_step', 'Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r1.0_v_mean')], [('Baseline_1024x8000_75-11_r0.85_v_step', 'Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.85_v_mean'), ('11-XuvYuv_lVcm_r0.85_v_step', '11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.85_v_mean'), ('11-NV-Importance_r0.85_v_step', '11-NV-Importance_wall_time', '11-NV-Importance_r0.85_v_mean'), ('Full_Size_Baseline_75-11_r0.85_v_step', 'Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.85_v_mean')], [('Baseline_1024x8000_75-11_r0.75_v_step', 'Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r0.75_v_mean'), ('11-XuvYuv_lVcm_r0.75_v_step', '11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.75_v_mean'), ('11-NV-Importance_r0.75_v_step', '11-NV-Importance_wall_time', '11-NV-Importance_r0.75_v_mean'), ('Full_Size_Baseline_75-11_r0.75_v_step', 'Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r0.75_v_mean')]]
# ###############################
# ['Baseline_1024x8000_75-11_r1.0_v_step', 'Baseline_1024x8000_75-11_wall_time', 'Baseline_1024x8000_75-11_r1.0_v_mean', 'Baseline_1024x8000_75-11_r0.85_v_mean', 'Baseline_1024x8000_75-11_r0.75_v_mean']
# 2.982753561668926
# ###############################
# ['11-XuvYuv_lVcm_r1.0_v_step', '11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_v_mean', '11-XuvYuv_lVcm_r0.85_v_mean', '11-XuvYuv_lVcm_r0.75_v_mean']
# 4.0283036708169515
# ###############################
# ['11-NV-Importance_r1.0_v_step', '11-NV-Importance_wall_time', '11-NV-Importance_r1.0_v_mean', '11-NV-Importance_r0.85_v_mean', '11-NV-Importance_r0.75_v_mean']
# 4.69313878721661
# ###############################
# ['Full_Size_Baseline_75-11_r1.0_v_step', 'Full_Size_Baseline_75-11_wall_time', 'Full_Size_Baseline_75-11_r1.0_v_mean', 'Full_Size_Baseline_75-11_r0.85_v_mean', 'Full_Size_Baseline_75-11_r0.75_v_mean']
# 7.028629274368286
# ###############################
# Index(['Baseline_1024x8000_75-11_r1.0_v_step',
#        'Baseline_1024x8000_75-11_wall_time',
#        'Baseline_1024x8000_75-11_r1.0_v_mean',
#        'Baseline_1024x8000_75-11_r0.85_v_mean',
#        'Baseline_1024x8000_75-11_r0.75_v_mean',
#        'Baseline_1024x8000_75-11_v_mean'],
#       dtype='object')
# minCol, minColNum, timeCol: Baseline_1024x8000_75-11_v_mean, 5, Baseline_1024x8000_75-11_wall_time
# ## min
# 0.027859286467234266
# --idxmin
# 99
# --time
# 2.9999245190620423
# [[0.027859286467234266, 99, 2.9999245190620423]]
# Index(['11-XuvYuv_lVcm_r1.0_v_step', '11-XuvYuv_lVcm_wall_time',
#        '11-XuvYuv_lVcm_r1.0_v_mean', '11-XuvYuv_lVcm_r0.85_v_mean',
#        '11-XuvYuv_lVcm_r0.75_v_mean', '11-XuvYuv_lVcm_v_mean'],
#       dtype='object')
# minCol, minColNum, timeCol: 11-XuvYuv_lVcm_v_mean, 5, 11-XuvYuv_lVcm_wall_time
# ## min
# 0.027380466833710603
# --idxmin
# 72
# --time
# 2.9999047217104167
# [[0.027859286467234266, 99, 2.9999245190620423], [0.027380466833710603, 72, 2.9999047217104167]]
# Index(['11-NV-Importance_r1.0_v_step', '11-NV-Importance_wall_time',
#        '11-NV-Importance_r1.0_v_mean', '11-NV-Importance_r0.85_v_mean',
#        '11-NV-Importance_r0.75_v_mean', '11-NV-Importance_v_mean'],
#       dtype='object')
# minCol, minColNum, timeCol: 11-NV-Importance_v_mean, 5, 11-NV-Importance_wall_time
# ## min
# 0.027766802658637336
# --idxmin
# 68
# --time
# 3.2756294661098058
# [[0.027859286467234266, 99, 2.9999245190620423], [0.027380466833710603, 72, 2.9999047217104167], [0.027766802658637336, 68, 3.2756294661098058]]
# Index(['Full_Size_Baseline_75-11_r1.0_v_step',
#        'Full_Size_Baseline_75-11_wall_time',
#        'Full_Size_Baseline_75-11_r1.0_v_mean',
#        'Full_Size_Baseline_75-11_r0.85_v_mean',
#        'Full_Size_Baseline_75-11_r0.75_v_mean',
#        'Full_Size_Baseline_75-11_v_mean'],
#       dtype='object')
# minCol, minColNum, timeCol: Full_Size_Baseline_75-11_v_mean, 5, Full_Size_Baseline_75-11_wall_time
# ## min
# 0.027531950424114836
# --idxmin
# 89
# --time
# 6.1937409531407885
# [[0.027859286467234266, 99, 2.9999245190620423], [0.027380466833710603, 72, 2.9999047217104167], [0.027766802658637336, 68, 3.2756294661098058], [0.027531950424114836, 89, 6.1937409531407885]]
#     11-XuvYuv_lVcm_wall_time  11-XuvYuv_lVcm_v_mean
# 57                  2.529224               0.027410
# 58                  2.543151               0.027516
# 59                  2.554700               0.027531
# 60                  2.575395               0.027391
# 61                  2.620580               0.027421
# 62                  2.650368               0.027473
# 63                  2.659750               0.027519
# 64                  2.693092               0.027504
# 65                  2.729358               0.027505
# 66                  2.756683               0.027451
# 67                  2.766326               0.027519
# 68                  2.804292               0.027522
# 69                  2.814330               0.027463
# 70                  2.835287               0.027499
# 71                  2.951937               0.027492
# 72                  2.999905               0.027380
# 73                  3.030376               0.027439
# 74                  3.048582               0.027477
# 75                  3.081025               0.027451
# 76                  3.111897               0.027469
# 77                  3.122096               0.027428
# 78                  3.144122               0.027445
# 79                  3.166482               0.027431
# 80                  3.231481               0.027403
# 81                  3.274563               0.027417
# 82                  3.285799               0.027381
# 83                  3.399261               0.027413
# 84                  3.421567               0.027414
# 85                  3.436086               0.027411
# 86                  3.446794               0.027443
# 87                  3.491342               0.027391
# 88                  3.528897               0.027395
# 89                  3.542732               0.027424
# 90                  3.637478               0.027406
# 91                  3.656678               0.027440
# 92                  3.680629               0.027390
# 93                  3.709463               0.027413
# 94                  3.767388               0.027399
# 95                  3.884926               0.027417
# 96                  3.938292               0.027415
# 97                  3.974597               0.027418
# 98                  3.994936               0.027386
# 99                  4.045260               0.027396
#     11-XuvYuv_lVcm_wall_time  11-XuvYuv_lVcm_v_mean
# 50                  2.141731               0.027567
# 51                  2.157957               0.027694
# 52                  2.209967               0.027644
# 53                  2.219971               0.027595
# 54                  2.304776               0.027698
# 55                  2.340174               0.027673
# 56                  2.426535               0.027550
# 57                  2.529224               0.027410
# 58                  2.543151               0.027516
# 59                  2.554700               0.027531
# 60                  2.575395               0.027391
# 61                  2.620580               0.027421
# 62                  2.650368               0.027473
# 63                  2.659750               0.027519
# 64                  2.693092               0.027504
# 65                  2.729358               0.027505
# 66                  2.756683               0.027451
# 67                  2.766326               0.027519
# 68                  2.804292               0.027522
# 69                  2.814330               0.027463
# 70                  2.835287               0.027499
# 71                  2.951937               0.027492
# 72                  2.999905               0.027380
# 73                  3.030376               0.027439
# 74                  3.048582               0.027477
# 75                  3.081025               0.027451
# 76                  3.111897               0.027469
# 77                  3.122096               0.027428
# 78                  3.144122               0.027445
# 79                  3.166482               0.027431
# 80                  3.231481               0.027403
# 81                  3.274563               0.027417
# 82                  3.285799               0.027381
# 83                  3.399261               0.027413
# 84                  3.421567               0.027414
# 85                  3.436086               0.027411
# 86                  3.446794               0.027443
# 87                  3.491342               0.027391
# 88                  3.528897               0.027395
# 89                  3.542732               0.027424
# 90                  3.637478               0.027406
# 91                  3.656678               0.027440
# 92                  3.680629               0.027390
# 93                  3.709463               0.027413
# 94                  3.767388               0.027399
# 95                  3.884926               0.027417
# 96                  3.938292               0.027415
# 97                  3.974597               0.027418
# 98                  3.994936               0.027386
# 99                  4.045260               0.027396
# Empty DataFrame
# Columns: [11-NV-Importance_wall_time, 11-NV-Importance_v_mean]
# Index: []
#     Full_Size_Baseline_75-11_wall_time  Full_Size_Baseline_75-11_v_mean
# 46                            3.673039                         0.027700
# 47                            3.694127                         0.027766
# 48                            3.754145                         0.027638
# 49                            3.775182                         0.027759
# 50                            3.876346                         0.027718
# 51                            3.896386                         0.027689
# 52                            3.977495                         0.027672
# 53                            3.997528                         0.027701
# 54                            4.160318                         0.027696
# 55                            4.221552                         0.027604
# 56                            4.364036                         0.027623
# 57                            4.506619                         0.027563
# 58                            4.526692                         0.027572
# 59                            4.546760                         0.027570
# 60                            4.587991                         0.027695
# 61                            4.669349                         0.027578
# 62                            4.709478                         0.027595
# 63                            4.729561                         0.027547
# 64                            4.790825                         0.027624
# 65                            4.852108                         0.027565
# 66                            4.913445                         0.027633
# 67                            4.933570                         0.027597
# 68                            4.994844                         0.027581
# 69                            5.014909                         0.027572
# 70                            5.055061                         0.027573
# 71                            5.197692                         0.027587
# 72                            5.279037                         0.027577
# 73                            5.340342                         0.027534
# 74                            5.360418                         0.027547
# 75                            5.421703                         0.027560
# 76                            5.483014                         0.027575
# 77                            5.503076                         0.027557
# 78                            5.543240                         0.027573
# 79                            5.584445                         0.027604
# 80                            5.706000                         0.027551
# 81                            5.787482                         0.027561
# 82                            5.808634                         0.027575
# 83                            5.950111                         0.027583
# 84                            5.991242                         0.027550
# 85                            6.011275                         0.027587
# 86                            6.031308                         0.027581
# 87                            6.112510                         0.027554
# 88                            6.173703                         0.027612
# 89                            6.193741                         0.027532
# 90                            6.377311                         0.027595
# 91                            6.417485                         0.027549
# 92                            6.458864                         0.027565
# 93                            6.499092                         0.027599
# 94                            6.560397                         0.027544
# 95                            6.763630                         0.027566
# 96                            6.866336                         0.027574
# 97                            6.926680                         0.027581
# 98                            6.968034                         0.027577
# 99                            7.069659                         0.027573
# 0.027766802658637336
#     11-XuvYuv_lVcm_wall_time  11-XuvYuv_lVcm_v_mean
# 49                  2.094365               0.027856
#     11-NV-Importance_wall_time  11-NV-Importance_v_mean
# 44                    2.320231                 0.027821
#     Full_Size_Baseline_75-11_wall_time  Full_Size_Baseline_75-11_v_mean
# 43                            3.409317                         0.027792
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60 #zero wall time
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_13724\2192341813.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[2:]].mean(axis=1) #mean of r1.0, r0.85, r0.75

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

variablesKey = 'Validators'
variablesSplit = 'l2_relative_error_'
validatorsRename = {'validator':'r1.0','validator_2':'r0.85','validator_3':'r0.75'}
variablesID = 'validator'
subfolders = ['Baseline_1024x8000','SGM_SPADE_1024x8000','NV-Importance','Full_Size_Baseline']

# run aggregates with these subfoldetrs
#folder = 'C:/Users/jacec/Documents/Test_Runs/'
folder = 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/'
aggregates = [folder+f+'/aggregates/' for f in os.listdir(folder) if os.path.isdir(folder+f)][0:1]
#all results will be in /aggregates, separated by tags from subfolders
#find all validation files separated by subfolder
files = []
#for i in aggregates:
#    csvs_by_testcase = [[i + g for g in os.listdir(i) if (g.endswith('.csv')) and (variablesKey in g) and (f in g)] for f in subfolders]
#    files = files+[i for i in csvs_by_testcase if i]
files = [[i+g for g in os.listdir(i) if g.endswith('.csv') and (variablesKey in g)] for i in aggregates]
#files = [[aggregates + g for g in os.listdir(aggregates) if ('.csv' in g) and (f in g)] for f in subfolders] 
#list of lists of the files for each individual aggregation
#Go through sub-list, load into dataframes with descriptive columns
#Find unique variables, create sub-frames with them in a format for plotting

# %%
files
# Out:
# [['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_p-Baseline_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_p-Full_Size_Baseline-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_p-NV-Importance-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_p-SGM_SPADE_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_u-Baseline_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_u-Full_Size_Baseline-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_u-NV-Importance-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_u-SGM_SPADE_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_v-Baseline_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_v-Full_Size_Baseline-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_v-NV-Importance-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_v-SGM_SPADE_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_p-Baseline_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_p-Full_Size_Baseline-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_p-NV-Importance-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_p-SGM_SPADE_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_u-Baseline_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_u-Full_Size_Baseline-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_u-NV-Importance-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_u-SGM_SPADE_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_v-Baseline_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_v-Full_Size_Baseline-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_v-NV-Importance-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_v-SGM_SPADE_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_p-Baseline_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_p-Full_Size_Baseline-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_p-NV-Importance-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_p-SGM_SPADE_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_u-Baseline_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_u-Full_Size_Baseline-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_u-NV-Importance-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_u-SGM_SPADE_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_v-Baseline_1024x8000-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_v-Full_Size_Baseline-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_v-NV-Importance-1024x8000.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_v-SGM_SPADE_1024x8000-1024x8000.csv']]

# %%
#each aggregate becomes one dataframe
#extract common variable names (validator, validator_n, uvpvnu)
#load into df with descriptive columns, uses 'subfolder' name, validator name, variable name
dataframes = []
agNames = []
for aggregation in files:
    dfs = []
    agName = aggregation[0].split('/aggregates/')[0].split('/')[-1]
    for testName in subfolders:
        subtests = [csv for csv in aggregation if testName in csv]
        if not subtests:
            continue
        print(subtests)
        for k,i in enumerate(subtests):
            validatorName = i.split(variablesKey)[1].split(variablesSplit)[0]
            vv = i.split(variablesSplit)[1].split('-'+testName)[0]
            variableName = f'{testName}_{validatorsRename[validatorName]}_{vv}_'
            print(variableName)
            #df = pd.read_csv(i, index_col = 0, delimiter=';')
            df = pd.read_csv(i, delimiter=';')
            oldcols = df.keys()
            print(oldcols)
            #mapping = {i:variableName+i for i in oldcols[0:-1]}
            mapping = {'Unnamed: 0':variableName+'step'}
            if k == 0:
                mapping.update({'wall_time':testName+'_wall_time'})
            mapping.update({i:variableName+i for i in oldcols[1:-1]})
            print(mapping)
            df.rename(columns=mapping, inplace=True)
            newcols = df.keys()
            print(newcols)
            if k > 0:
                df.drop(columns='wall_time')
            dfs.append(df)
    df = pd.concat(dfs, axis=1)
    df = df.loc[:,~df.columns.duplicated()].copy() #drop duplicates based on column name alone
    #append to dataframes list
    dataframes.append(df)
    agNames.append(agName)
# Out:
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_p-Baseline_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_u-Baseline_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_v-Baseline_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_p-Baseline_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_u-Baseline_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_v-Baseline_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_p-Baseline_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_u-Baseline_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_v-Baseline_1024x8000-1024x8000.csv']
# Baseline_1024x8000_r1.0_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r1.0_p_step', 'wall_time': 'Baseline_1024x8000_wall_time', 'mean': 'Baseline_1024x8000_r1.0_p_mean', 'amin': 'Baseline_1024x8000_r1.0_p_amin', 'amax': 'Baseline_1024x8000_r1.0_p_amax', 'median': 'Baseline_1024x8000_r1.0_p_median', 'std': 'Baseline_1024x8000_r1.0_p_std', 'var': 'Baseline_1024x8000_r1.0_p_var'}
# Index(['Baseline_1024x8000_r1.0_p_step', 'Baseline_1024x8000_r1.0_p_mean',
#        'Baseline_1024x8000_r1.0_p_amin', 'Baseline_1024x8000_r1.0_p_amax',
#        'Baseline_1024x8000_r1.0_p_median', 'Baseline_1024x8000_r1.0_p_std',
#        'Baseline_1024x8000_r1.0_p_var', 'Baseline_1024x8000_wall_time'],
#       dtype='object')
# Baseline_1024x8000_r1.0_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r1.0_u_step', 'mean': 'Baseline_1024x8000_r1.0_u_mean', 'amin': 'Baseline_1024x8000_r1.0_u_amin', 'amax': 'Baseline_1024x8000_r1.0_u_amax', 'median': 'Baseline_1024x8000_r1.0_u_median', 'std': 'Baseline_1024x8000_r1.0_u_std', 'var': 'Baseline_1024x8000_r1.0_u_var'}
# Index(['Baseline_1024x8000_r1.0_u_step', 'Baseline_1024x8000_r1.0_u_mean',
#        'Baseline_1024x8000_r1.0_u_amin', 'Baseline_1024x8000_r1.0_u_amax',
#        'Baseline_1024x8000_r1.0_u_median', 'Baseline_1024x8000_r1.0_u_std',
#        'Baseline_1024x8000_r1.0_u_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r1.0_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r1.0_v_step', 'mean': 'Baseline_1024x8000_r1.0_v_mean', 'amin': 'Baseline_1024x8000_r1.0_v_amin', 'amax': 'Baseline_1024x8000_r1.0_v_amax', 'median': 'Baseline_1024x8000_r1.0_v_median', 'std': 'Baseline_1024x8000_r1.0_v_std', 'var': 'Baseline_1024x8000_r1.0_v_var'}
# Index(['Baseline_1024x8000_r1.0_v_step', 'Baseline_1024x8000_r1.0_v_mean',
#        'Baseline_1024x8000_r1.0_v_amin', 'Baseline_1024x8000_r1.0_v_amax',
#        'Baseline_1024x8000_r1.0_v_median', 'Baseline_1024x8000_r1.0_v_std',
#        'Baseline_1024x8000_r1.0_v_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r0.85_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r0.85_p_step', 'mean': 'Baseline_1024x8000_r0.85_p_mean', 'amin': 'Baseline_1024x8000_r0.85_p_amin', 'amax': 'Baseline_1024x8000_r0.85_p_amax', 'median': 'Baseline_1024x8000_r0.85_p_median', 'std': 'Baseline_1024x8000_r0.85_p_std', 'var': 'Baseline_1024x8000_r0.85_p_var'}
# Index(['Baseline_1024x8000_r0.85_p_step', 'Baseline_1024x8000_r0.85_p_mean',
#        'Baseline_1024x8000_r0.85_p_amin', 'Baseline_1024x8000_r0.85_p_amax',
#        'Baseline_1024x8000_r0.85_p_median', 'Baseline_1024x8000_r0.85_p_std',
#        'Baseline_1024x8000_r0.85_p_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r0.85_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r0.85_u_step', 'mean': 'Baseline_1024x8000_r0.85_u_mean', 'amin': 'Baseline_1024x8000_r0.85_u_amin', 'amax': 'Baseline_1024x8000_r0.85_u_amax', 'median': 'Baseline_1024x8000_r0.85_u_median', 'std': 'Baseline_1024x8000_r0.85_u_std', 'var': 'Baseline_1024x8000_r0.85_u_var'}
# Index(['Baseline_1024x8000_r0.85_u_step', 'Baseline_1024x8000_r0.85_u_mean',
#        'Baseline_1024x8000_r0.85_u_amin', 'Baseline_1024x8000_r0.85_u_amax',
#        'Baseline_1024x8000_r0.85_u_median', 'Baseline_1024x8000_r0.85_u_std',
#        'Baseline_1024x8000_r0.85_u_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r0.85_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r0.85_v_step', 'mean': 'Baseline_1024x8000_r0.85_v_mean', 'amin': 'Baseline_1024x8000_r0.85_v_amin', 'amax': 'Baseline_1024x8000_r0.85_v_amax', 'median': 'Baseline_1024x8000_r0.85_v_median', 'std': 'Baseline_1024x8000_r0.85_v_std', 'var': 'Baseline_1024x8000_r0.85_v_var'}
# Index(['Baseline_1024x8000_r0.85_v_step', 'Baseline_1024x8000_r0.85_v_mean',
#        'Baseline_1024x8000_r0.85_v_amin', 'Baseline_1024x8000_r0.85_v_amax',
#        'Baseline_1024x8000_r0.85_v_median', 'Baseline_1024x8000_r0.85_v_std',
#        'Baseline_1024x8000_r0.85_v_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r0.75_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r0.75_p_step', 'mean': 'Baseline_1024x8000_r0.75_p_mean', 'amin': 'Baseline_1024x8000_r0.75_p_amin', 'amax': 'Baseline_1024x8000_r0.75_p_amax', 'median': 'Baseline_1024x8000_r0.75_p_median', 'std': 'Baseline_1024x8000_r0.75_p_std', 'var': 'Baseline_1024x8000_r0.75_p_var'}
# Index(['Baseline_1024x8000_r0.75_p_step', 'Baseline_1024x8000_r0.75_p_mean',
#        'Baseline_1024x8000_r0.75_p_amin', 'Baseline_1024x8000_r0.75_p_amax',
#        'Baseline_1024x8000_r0.75_p_median', 'Baseline_1024x8000_r0.75_p_std',
#        'Baseline_1024x8000_r0.75_p_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r0.75_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r0.75_u_step', 'mean': 'Baseline_1024x8000_r0.75_u_mean', 'amin': 'Baseline_1024x8000_r0.75_u_amin', 'amax': 'Baseline_1024x8000_r0.75_u_amax', 'median': 'Baseline_1024x8000_r0.75_u_median', 'std': 'Baseline_1024x8000_r0.75_u_std', 'var': 'Baseline_1024x8000_r0.75_u_var'}
# Index(['Baseline_1024x8000_r0.75_u_step', 'Baseline_1024x8000_r0.75_u_mean',
#        'Baseline_1024x8000_r0.75_u_amin', 'Baseline_1024x8000_r0.75_u_amax',
#        'Baseline_1024x8000_r0.75_u_median', 'Baseline_1024x8000_r0.75_u_std',
#        'Baseline_1024x8000_r0.75_u_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r0.75_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r0.75_v_step', 'mean': 'Baseline_1024x8000_r0.75_v_mean', 'amin': 'Baseline_1024x8000_r0.75_v_amin', 'amax': 'Baseline_1024x8000_r0.75_v_amax', 'median': 'Baseline_1024x8000_r0.75_v_median', 'std': 'Baseline_1024x8000_r0.75_v_std', 'var': 'Baseline_1024x8000_r0.75_v_var'}
# Index(['Baseline_1024x8000_r0.75_v_step', 'Baseline_1024x8000_r0.75_v_mean',
#        'Baseline_1024x8000_r0.75_v_amin', 'Baseline_1024x8000_r0.75_v_amax',
#        'Baseline_1024x8000_r0.75_v_median', 'Baseline_1024x8000_r0.75_v_std',
#        'Baseline_1024x8000_r0.75_v_var', 'wall_time'],
#       dtype='object')
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_p-SGM_SPADE_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_u-SGM_SPADE_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_v-SGM_SPADE_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_p-SGM_SPADE_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_u-SGM_SPADE_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_v-SGM_SPADE_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_p-SGM_SPADE_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_u-SGM_SPADE_1024x8000-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_v-SGM_SPADE_1024x8000-1024x8000.csv']
# SGM_SPADE_1024x8000_r1.0_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_SPADE_1024x8000_r1.0_p_step', 'wall_time': 'SGM_SPADE_1024x8000_wall_time', 'mean': 'SGM_SPADE_1024x8000_r1.0_p_mean', 'amin': 'SGM_SPADE_1024x8000_r1.0_p_amin', 'amax': 'SGM_SPADE_1024x8000_r1.0_p_amax', 'median': 'SGM_SPADE_1024x8000_r1.0_p_median', 'std': 'SGM_SPADE_1024x8000_r1.0_p_std', 'var': 'SGM_SPADE_1024x8000_r1.0_p_var'}
# Index(['SGM_SPADE_1024x8000_r1.0_p_step', 'SGM_SPADE_1024x8000_r1.0_p_mean',
#        'SGM_SPADE_1024x8000_r1.0_p_amin', 'SGM_SPADE_1024x8000_r1.0_p_amax',
#        'SGM_SPADE_1024x8000_r1.0_p_median', 'SGM_SPADE_1024x8000_r1.0_p_std',
#        'SGM_SPADE_1024x8000_r1.0_p_var', 'SGM_SPADE_1024x8000_wall_time'],
#       dtype='object')
# SGM_SPADE_1024x8000_r1.0_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_SPADE_1024x8000_r1.0_u_step', 'mean': 'SGM_SPADE_1024x8000_r1.0_u_mean', 'amin': 'SGM_SPADE_1024x8000_r1.0_u_amin', 'amax': 'SGM_SPADE_1024x8000_r1.0_u_amax', 'median': 'SGM_SPADE_1024x8000_r1.0_u_median', 'std': 'SGM_SPADE_1024x8000_r1.0_u_std', 'var': 'SGM_SPADE_1024x8000_r1.0_u_var'}
# Index(['SGM_SPADE_1024x8000_r1.0_u_step', 'SGM_SPADE_1024x8000_r1.0_u_mean',
#        'SGM_SPADE_1024x8000_r1.0_u_amin', 'SGM_SPADE_1024x8000_r1.0_u_amax',
#        'SGM_SPADE_1024x8000_r1.0_u_median', 'SGM_SPADE_1024x8000_r1.0_u_std',
#        'SGM_SPADE_1024x8000_r1.0_u_var', 'wall_time'],
#       dtype='object')
# SGM_SPADE_1024x8000_r1.0_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_SPADE_1024x8000_r1.0_v_step', 'mean': 'SGM_SPADE_1024x8000_r1.0_v_mean', 'amin': 'SGM_SPADE_1024x8000_r1.0_v_amin', 'amax': 'SGM_SPADE_1024x8000_r1.0_v_amax', 'median': 'SGM_SPADE_1024x8000_r1.0_v_median', 'std': 'SGM_SPADE_1024x8000_r1.0_v_std', 'var': 'SGM_SPADE_1024x8000_r1.0_v_var'}
# Index(['SGM_SPADE_1024x8000_r1.0_v_step', 'SGM_SPADE_1024x8000_r1.0_v_mean',
#        'SGM_SPADE_1024x8000_r1.0_v_amin', 'SGM_SPADE_1024x8000_r1.0_v_amax',
#        'SGM_SPADE_1024x8000_r1.0_v_median', 'SGM_SPADE_1024x8000_r1.0_v_std',
#        'SGM_SPADE_1024x8000_r1.0_v_var', 'wall_time'],
#       dtype='object')
# SGM_SPADE_1024x8000_r0.85_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_SPADE_1024x8000_r0.85_p_step', 'mean': 'SGM_SPADE_1024x8000_r0.85_p_mean', 'amin': 'SGM_SPADE_1024x8000_r0.85_p_amin', 'amax': 'SGM_SPADE_1024x8000_r0.85_p_amax', 'median': 'SGM_SPADE_1024x8000_r0.85_p_median', 'std': 'SGM_SPADE_1024x8000_r0.85_p_std', 'var': 'SGM_SPADE_1024x8000_r0.85_p_var'}
# Index(['SGM_SPADE_1024x8000_r0.85_p_step', 'SGM_SPADE_1024x8000_r0.85_p_mean',
#        'SGM_SPADE_1024x8000_r0.85_p_amin', 'SGM_SPADE_1024x8000_r0.85_p_amax',
#        'SGM_SPADE_1024x8000_r0.85_p_median', 'SGM_SPADE_1024x8000_r0.85_p_std',
#        'SGM_SPADE_1024x8000_r0.85_p_var', 'wall_time'],
#       dtype='object')
# SGM_SPADE_1024x8000_r0.85_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_SPADE_1024x8000_r0.85_u_step', 'mean': 'SGM_SPADE_1024x8000_r0.85_u_mean', 'amin': 'SGM_SPADE_1024x8000_r0.85_u_amin', 'amax': 'SGM_SPADE_1024x8000_r0.85_u_amax', 'median': 'SGM_SPADE_1024x8000_r0.85_u_median', 'std': 'SGM_SPADE_1024x8000_r0.85_u_std', 'var': 'SGM_SPADE_1024x8000_r0.85_u_var'}
# Index(['SGM_SPADE_1024x8000_r0.85_u_step', 'SGM_SPADE_1024x8000_r0.85_u_mean',
#        'SGM_SPADE_1024x8000_r0.85_u_amin', 'SGM_SPADE_1024x8000_r0.85_u_amax',
#        'SGM_SPADE_1024x8000_r0.85_u_median', 'SGM_SPADE_1024x8000_r0.85_u_std',
#        'SGM_SPADE_1024x8000_r0.85_u_var', 'wall_time'],
#       dtype='object')
# SGM_SPADE_1024x8000_r0.85_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_SPADE_1024x8000_r0.85_v_step', 'mean': 'SGM_SPADE_1024x8000_r0.85_v_mean', 'amin': 'SGM_SPADE_1024x8000_r0.85_v_amin', 'amax': 'SGM_SPADE_1024x8000_r0.85_v_amax', 'median': 'SGM_SPADE_1024x8000_r0.85_v_median', 'std': 'SGM_SPADE_1024x8000_r0.85_v_std', 'var': 'SGM_SPADE_1024x8000_r0.85_v_var'}
# Index(['SGM_SPADE_1024x8000_r0.85_v_step', 'SGM_SPADE_1024x8000_r0.85_v_mean',
#        'SGM_SPADE_1024x8000_r0.85_v_amin', 'SGM_SPADE_1024x8000_r0.85_v_amax',
#        'SGM_SPADE_1024x8000_r0.85_v_median', 'SGM_SPADE_1024x8000_r0.85_v_std',
#        'SGM_SPADE_1024x8000_r0.85_v_var', 'wall_time'],
#       dtype='object')
# SGM_SPADE_1024x8000_r0.75_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_SPADE_1024x8000_r0.75_p_step', 'mean': 'SGM_SPADE_1024x8000_r0.75_p_mean', 'amin': 'SGM_SPADE_1024x8000_r0.75_p_amin', 'amax': 'SGM_SPADE_1024x8000_r0.75_p_amax', 'median': 'SGM_SPADE_1024x8000_r0.75_p_median', 'std': 'SGM_SPADE_1024x8000_r0.75_p_std', 'var': 'SGM_SPADE_1024x8000_r0.75_p_var'}
# Index(['SGM_SPADE_1024x8000_r0.75_p_step', 'SGM_SPADE_1024x8000_r0.75_p_mean',
#        'SGM_SPADE_1024x8000_r0.75_p_amin', 'SGM_SPADE_1024x8000_r0.75_p_amax',
#        'SGM_SPADE_1024x8000_r0.75_p_median', 'SGM_SPADE_1024x8000_r0.75_p_std',
#        'SGM_SPADE_1024x8000_r0.75_p_var', 'wall_time'],
#       dtype='object')
# SGM_SPADE_1024x8000_r0.75_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_SPADE_1024x8000_r0.75_u_step', 'mean': 'SGM_SPADE_1024x8000_r0.75_u_mean', 'amin': 'SGM_SPADE_1024x8000_r0.75_u_amin', 'amax': 'SGM_SPADE_1024x8000_r0.75_u_amax', 'median': 'SGM_SPADE_1024x8000_r0.75_u_median', 'std': 'SGM_SPADE_1024x8000_r0.75_u_std', 'var': 'SGM_SPADE_1024x8000_r0.75_u_var'}
# Index(['SGM_SPADE_1024x8000_r0.75_u_step', 'SGM_SPADE_1024x8000_r0.75_u_mean',
#        'SGM_SPADE_1024x8000_r0.75_u_amin', 'SGM_SPADE_1024x8000_r0.75_u_amax',
#        'SGM_SPADE_1024x8000_r0.75_u_median', 'SGM_SPADE_1024x8000_r0.75_u_std',
#        'SGM_SPADE_1024x8000_r0.75_u_var', 'wall_time'],
#       dtype='object')
# SGM_SPADE_1024x8000_r0.75_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_SPADE_1024x8000_r0.75_v_step', 'mean': 'SGM_SPADE_1024x8000_r0.75_v_mean', 'amin': 'SGM_SPADE_1024x8000_r0.75_v_amin', 'amax': 'SGM_SPADE_1024x8000_r0.75_v_amax', 'median': 'SGM_SPADE_1024x8000_r0.75_v_median', 'std': 'SGM_SPADE_1024x8000_r0.75_v_std', 'var': 'SGM_SPADE_1024x8000_r0.75_v_var'}
# Index(['SGM_SPADE_1024x8000_r0.75_v_step', 'SGM_SPADE_1024x8000_r0.75_v_mean',
#        'SGM_SPADE_1024x8000_r0.75_v_amin', 'SGM_SPADE_1024x8000_r0.75_v_amax',
#        'SGM_SPADE_1024x8000_r0.75_v_median', 'SGM_SPADE_1024x8000_r0.75_v_std',
#        'SGM_SPADE_1024x8000_r0.75_v_var', 'wall_time'],
#       dtype='object')
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_p-NV-Importance-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_u-NV-Importance-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_v-NV-Importance-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_p-NV-Importance-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_u-NV-Importance-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_v-NV-Importance-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_p-NV-Importance-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_u-NV-Importance-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_v-NV-Importance-1024x8000.csv']
# NV-Importance_r1.0_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'NV-Importance_r1.0_p_step', 'wall_time': 'NV-Importance_wall_time', 'mean': 'NV-Importance_r1.0_p_mean', 'amin': 'NV-Importance_r1.0_p_amin', 'amax': 'NV-Importance_r1.0_p_amax', 'median': 'NV-Importance_r1.0_p_median', 'std': 'NV-Importance_r1.0_p_std', 'var': 'NV-Importance_r1.0_p_var'}
# Index(['NV-Importance_r1.0_p_step', 'NV-Importance_r1.0_p_mean',
#        'NV-Importance_r1.0_p_amin', 'NV-Importance_r1.0_p_amax',
#        'NV-Importance_r1.0_p_median', 'NV-Importance_r1.0_p_std',
#        'NV-Importance_r1.0_p_var', 'NV-Importance_wall_time'],
#       dtype='object')
# NV-Importance_r1.0_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'NV-Importance_r1.0_u_step', 'mean': 'NV-Importance_r1.0_u_mean', 'amin': 'NV-Importance_r1.0_u_amin', 'amax': 'NV-Importance_r1.0_u_amax', 'median': 'NV-Importance_r1.0_u_median', 'std': 'NV-Importance_r1.0_u_std', 'var': 'NV-Importance_r1.0_u_var'}
# Index(['NV-Importance_r1.0_u_step', 'NV-Importance_r1.0_u_mean',
#        'NV-Importance_r1.0_u_amin', 'NV-Importance_r1.0_u_amax',
#        'NV-Importance_r1.0_u_median', 'NV-Importance_r1.0_u_std',
#        'NV-Importance_r1.0_u_var', 'wall_time'],
#       dtype='object')
# NV-Importance_r1.0_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'NV-Importance_r1.0_v_step', 'mean': 'NV-Importance_r1.0_v_mean', 'amin': 'NV-Importance_r1.0_v_amin', 'amax': 'NV-Importance_r1.0_v_amax', 'median': 'NV-Importance_r1.0_v_median', 'std': 'NV-Importance_r1.0_v_std', 'var': 'NV-Importance_r1.0_v_var'}
# Index(['NV-Importance_r1.0_v_step', 'NV-Importance_r1.0_v_mean',
#        'NV-Importance_r1.0_v_amin', 'NV-Importance_r1.0_v_amax',
#        'NV-Importance_r1.0_v_median', 'NV-Importance_r1.0_v_std',
#        'NV-Importance_r1.0_v_var', 'wall_time'],
#       dtype='object')
# NV-Importance_r0.85_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'NV-Importance_r0.85_p_step', 'mean': 'NV-Importance_r0.85_p_mean', 'amin': 'NV-Importance_r0.85_p_amin', 'amax': 'NV-Importance_r0.85_p_amax', 'median': 'NV-Importance_r0.85_p_median', 'std': 'NV-Importance_r0.85_p_std', 'var': 'NV-Importance_r0.85_p_var'}
# Index(['NV-Importance_r0.85_p_step', 'NV-Importance_r0.85_p_mean',
#        'NV-Importance_r0.85_p_amin', 'NV-Importance_r0.85_p_amax',
#        'NV-Importance_r0.85_p_median', 'NV-Importance_r0.85_p_std',
#        'NV-Importance_r0.85_p_var', 'wall_time'],
#       dtype='object')
# NV-Importance_r0.85_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'NV-Importance_r0.85_u_step', 'mean': 'NV-Importance_r0.85_u_mean', 'amin': 'NV-Importance_r0.85_u_amin', 'amax': 'NV-Importance_r0.85_u_amax', 'median': 'NV-Importance_r0.85_u_median', 'std': 'NV-Importance_r0.85_u_std', 'var': 'NV-Importance_r0.85_u_var'}
# Index(['NV-Importance_r0.85_u_step', 'NV-Importance_r0.85_u_mean',
#        'NV-Importance_r0.85_u_amin', 'NV-Importance_r0.85_u_amax',
#        'NV-Importance_r0.85_u_median', 'NV-Importance_r0.85_u_std',
#        'NV-Importance_r0.85_u_var', 'wall_time'],
#       dtype='object')
# NV-Importance_r0.85_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'NV-Importance_r0.85_v_step', 'mean': 'NV-Importance_r0.85_v_mean', 'amin': 'NV-Importance_r0.85_v_amin', 'amax': 'NV-Importance_r0.85_v_amax', 'median': 'NV-Importance_r0.85_v_median', 'std': 'NV-Importance_r0.85_v_std', 'var': 'NV-Importance_r0.85_v_var'}
# Index(['NV-Importance_r0.85_v_step', 'NV-Importance_r0.85_v_mean',
#        'NV-Importance_r0.85_v_amin', 'NV-Importance_r0.85_v_amax',
#        'NV-Importance_r0.85_v_median', 'NV-Importance_r0.85_v_std',
#        'NV-Importance_r0.85_v_var', 'wall_time'],
#       dtype='object')
# NV-Importance_r0.75_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'NV-Importance_r0.75_p_step', 'mean': 'NV-Importance_r0.75_p_mean', 'amin': 'NV-Importance_r0.75_p_amin', 'amax': 'NV-Importance_r0.75_p_amax', 'median': 'NV-Importance_r0.75_p_median', 'std': 'NV-Importance_r0.75_p_std', 'var': 'NV-Importance_r0.75_p_var'}
# Index(['NV-Importance_r0.75_p_step', 'NV-Importance_r0.75_p_mean',
#        'NV-Importance_r0.75_p_amin', 'NV-Importance_r0.75_p_amax',
#        'NV-Importance_r0.75_p_median', 'NV-Importance_r0.75_p_std',
#        'NV-Importance_r0.75_p_var', 'wall_time'],
#       dtype='object')
# NV-Importance_r0.75_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'NV-Importance_r0.75_u_step', 'mean': 'NV-Importance_r0.75_u_mean', 'amin': 'NV-Importance_r0.75_u_amin', 'amax': 'NV-Importance_r0.75_u_amax', 'median': 'NV-Importance_r0.75_u_median', 'std': 'NV-Importance_r0.75_u_std', 'var': 'NV-Importance_r0.75_u_var'}
# Index(['NV-Importance_r0.75_u_step', 'NV-Importance_r0.75_u_mean',
#        'NV-Importance_r0.75_u_amin', 'NV-Importance_r0.75_u_amax',
#        'NV-Importance_r0.75_u_median', 'NV-Importance_r0.75_u_std',
#        'NV-Importance_r0.75_u_var', 'wall_time'],
#       dtype='object')
# NV-Importance_r0.75_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'NV-Importance_r0.75_v_step', 'mean': 'NV-Importance_r0.75_v_mean', 'amin': 'NV-Importance_r0.75_v_amin', 'amax': 'NV-Importance_r0.75_v_amax', 'median': 'NV-Importance_r0.75_v_median', 'std': 'NV-Importance_r0.75_v_std', 'var': 'NV-Importance_r0.75_v_var'}
# Index(['NV-Importance_r0.75_v_step', 'NV-Importance_r0.75_v_mean',
#        'NV-Importance_r0.75_v_amin', 'NV-Importance_r0.75_v_amax',
#        'NV-Importance_r0.75_v_median', 'NV-Importance_r0.75_v_std',
#        'NV-Importance_r0.75_v_var', 'wall_time'],
#       dtype='object')
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_p-Full_Size_Baseline-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_u-Full_Size_Baseline-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidatorl2_relative_error_v-Full_Size_Baseline-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_p-Full_Size_Baseline-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_u-Full_Size_Baseline-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_2l2_relative_error_v-Full_Size_Baseline-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_p-Full_Size_Baseline-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_u-Full_Size_Baseline-1024x8000.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/1024x8000/aggregates/Validatorsvalidator_3l2_relative_error_v-Full_Size_Baseline-1024x8000.csv']
# Full_Size_Baseline_r1.0_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_r1.0_p_step', 'wall_time': 'Full_Size_Baseline_wall_time', 'mean': 'Full_Size_Baseline_r1.0_p_mean', 'amin': 'Full_Size_Baseline_r1.0_p_amin', 'amax': 'Full_Size_Baseline_r1.0_p_amax', 'median': 'Full_Size_Baseline_r1.0_p_median', 'std': 'Full_Size_Baseline_r1.0_p_std', 'var': 'Full_Size_Baseline_r1.0_p_var'}
# Index(['Full_Size_Baseline_r1.0_p_step', 'Full_Size_Baseline_r1.0_p_mean',
#        'Full_Size_Baseline_r1.0_p_amin', 'Full_Size_Baseline_r1.0_p_amax',
#        'Full_Size_Baseline_r1.0_p_median', 'Full_Size_Baseline_r1.0_p_std',
#        'Full_Size_Baseline_r1.0_p_var', 'Full_Size_Baseline_wall_time'],
#       dtype='object')
# Full_Size_Baseline_r1.0_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_r1.0_u_step', 'mean': 'Full_Size_Baseline_r1.0_u_mean', 'amin': 'Full_Size_Baseline_r1.0_u_amin', 'amax': 'Full_Size_Baseline_r1.0_u_amax', 'median': 'Full_Size_Baseline_r1.0_u_median', 'std': 'Full_Size_Baseline_r1.0_u_std', 'var': 'Full_Size_Baseline_r1.0_u_var'}
# Index(['Full_Size_Baseline_r1.0_u_step', 'Full_Size_Baseline_r1.0_u_mean',
#        'Full_Size_Baseline_r1.0_u_amin', 'Full_Size_Baseline_r1.0_u_amax',
#        'Full_Size_Baseline_r1.0_u_median', 'Full_Size_Baseline_r1.0_u_std',
#        'Full_Size_Baseline_r1.0_u_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_r1.0_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_r1.0_v_step', 'mean': 'Full_Size_Baseline_r1.0_v_mean', 'amin': 'Full_Size_Baseline_r1.0_v_amin', 'amax': 'Full_Size_Baseline_r1.0_v_amax', 'median': 'Full_Size_Baseline_r1.0_v_median', 'std': 'Full_Size_Baseline_r1.0_v_std', 'var': 'Full_Size_Baseline_r1.0_v_var'}
# Index(['Full_Size_Baseline_r1.0_v_step', 'Full_Size_Baseline_r1.0_v_mean',
#        'Full_Size_Baseline_r1.0_v_amin', 'Full_Size_Baseline_r1.0_v_amax',
#        'Full_Size_Baseline_r1.0_v_median', 'Full_Size_Baseline_r1.0_v_std',
#        'Full_Size_Baseline_r1.0_v_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_r0.85_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_r0.85_p_step', 'mean': 'Full_Size_Baseline_r0.85_p_mean', 'amin': 'Full_Size_Baseline_r0.85_p_amin', 'amax': 'Full_Size_Baseline_r0.85_p_amax', 'median': 'Full_Size_Baseline_r0.85_p_median', 'std': 'Full_Size_Baseline_r0.85_p_std', 'var': 'Full_Size_Baseline_r0.85_p_var'}
# Index(['Full_Size_Baseline_r0.85_p_step', 'Full_Size_Baseline_r0.85_p_mean',
#        'Full_Size_Baseline_r0.85_p_amin', 'Full_Size_Baseline_r0.85_p_amax',
#        'Full_Size_Baseline_r0.85_p_median', 'Full_Size_Baseline_r0.85_p_std',
#        'Full_Size_Baseline_r0.85_p_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_r0.85_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_r0.85_u_step', 'mean': 'Full_Size_Baseline_r0.85_u_mean', 'amin': 'Full_Size_Baseline_r0.85_u_amin', 'amax': 'Full_Size_Baseline_r0.85_u_amax', 'median': 'Full_Size_Baseline_r0.85_u_median', 'std': 'Full_Size_Baseline_r0.85_u_std', 'var': 'Full_Size_Baseline_r0.85_u_var'}
# Index(['Full_Size_Baseline_r0.85_u_step', 'Full_Size_Baseline_r0.85_u_mean',
#        'Full_Size_Baseline_r0.85_u_amin', 'Full_Size_Baseline_r0.85_u_amax',
#        'Full_Size_Baseline_r0.85_u_median', 'Full_Size_Baseline_r0.85_u_std',
#        'Full_Size_Baseline_r0.85_u_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_r0.85_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_r0.85_v_step', 'mean': 'Full_Size_Baseline_r0.85_v_mean', 'amin': 'Full_Size_Baseline_r0.85_v_amin', 'amax': 'Full_Size_Baseline_r0.85_v_amax', 'median': 'Full_Size_Baseline_r0.85_v_median', 'std': 'Full_Size_Baseline_r0.85_v_std', 'var': 'Full_Size_Baseline_r0.85_v_var'}
# Index(['Full_Size_Baseline_r0.85_v_step', 'Full_Size_Baseline_r0.85_v_mean',
#        'Full_Size_Baseline_r0.85_v_amin', 'Full_Size_Baseline_r0.85_v_amax',
#        'Full_Size_Baseline_r0.85_v_median', 'Full_Size_Baseline_r0.85_v_std',
#        'Full_Size_Baseline_r0.85_v_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_r0.75_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_r0.75_p_step', 'mean': 'Full_Size_Baseline_r0.75_p_mean', 'amin': 'Full_Size_Baseline_r0.75_p_amin', 'amax': 'Full_Size_Baseline_r0.75_p_amax', 'median': 'Full_Size_Baseline_r0.75_p_median', 'std': 'Full_Size_Baseline_r0.75_p_std', 'var': 'Full_Size_Baseline_r0.75_p_var'}
# Index(['Full_Size_Baseline_r0.75_p_step', 'Full_Size_Baseline_r0.75_p_mean',
#        'Full_Size_Baseline_r0.75_p_amin', 'Full_Size_Baseline_r0.75_p_amax',
#        'Full_Size_Baseline_r0.75_p_median', 'Full_Size_Baseline_r0.75_p_std',
#        'Full_Size_Baseline_r0.75_p_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_r0.75_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_r0.75_u_step', 'mean': 'Full_Size_Baseline_r0.75_u_mean', 'amin': 'Full_Size_Baseline_r0.75_u_amin', 'amax': 'Full_Size_Baseline_r0.75_u_amax', 'median': 'Full_Size_Baseline_r0.75_u_median', 'std': 'Full_Size_Baseline_r0.75_u_std', 'var': 'Full_Size_Baseline_r0.75_u_var'}
# Index(['Full_Size_Baseline_r0.75_u_step', 'Full_Size_Baseline_r0.75_u_mean',
#        'Full_Size_Baseline_r0.75_u_amin', 'Full_Size_Baseline_r0.75_u_amax',
#        'Full_Size_Baseline_r0.75_u_median', 'Full_Size_Baseline_r0.75_u_std',
#        'Full_Size_Baseline_r0.75_u_var', 'wall_time'],
#       dtype='object')
# Full_Size_Baseline_r0.75_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Full_Size_Baseline_r0.75_v_step', 'mean': 'Full_Size_Baseline_r0.75_v_mean', 'amin': 'Full_Size_Baseline_r0.75_v_amin', 'amax': 'Full_Size_Baseline_r0.75_v_amax', 'median': 'Full_Size_Baseline_r0.75_v_median', 'std': 'Full_Size_Baseline_r0.75_v_std', 'var': 'Full_Size_Baseline_r0.75_v_var'}
# Index(['Full_Size_Baseline_r0.75_v_step', 'Full_Size_Baseline_r0.75_v_mean',
#        'Full_Size_Baseline_r0.75_v_amin', 'Full_Size_Baseline_r0.75_v_amax',
#        'Full_Size_Baseline_r0.75_v_median', 'Full_Size_Baseline_r0.75_v_std',
#        'Full_Size_Baseline_r0.75_v_var', 'wall_time'],
#       dtype='object')

# %%
dataframes[0]
agNames
# Out:
# ['1024x8000']

# %%
#plot step series p
plotVars_p_allValidators = [[f'{subfolders[0]}_{j}_p_step'] + [f'{i}_{j}_p_mean' for i in subfolders ] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
stepFilter = dataframes[0][f'{subfolders[0]}_r1.0_p_step'] >= 150000
def set_cycler(ax):
    ax.set_prop_cycle(plt.cycler('color', ['r', 'b', 'g', 'c'])+
                      plt.cycler('linestyle', ['-','--',':','-.'])+
                      plt.cycler('marker', ['.','*','^','x']))
    
def set_cycler(ax):
    ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'r'])+
                      plt.cycler('linestyle', ['-','--',':','-.'])+
                      plt.cycler('marker', ['x','*','^','x']))
#fmt = '[marker][line][color]' linestyle='--', marker='o', color='b'
#fmts = ['-r','--*b',':^g','-.xc']
#formats = {'marker':['.','*','^','x'], 'linestyle':['-','--',':','-.'], 'color':['r','b','g','c']}

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (28,5))
    fig.suptitle(f'P step series for {agNames[i]}')
    axes[0].set_ylabel('l2_relative_error')
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k])
# Out:
# [['Baseline_1024x8000_r1.0_p_step', 'Baseline_1024x8000_r1.0_p_mean', 'SGM_SPADE_1024x8000_r1.0_p_mean', 'NV-Importance_r1.0_p_mean', 'Full_Size_Baseline_r1.0_p_mean'], ['Baseline_1024x8000_r0.85_p_step', 'Baseline_1024x8000_r0.85_p_mean', 'SGM_SPADE_1024x8000_r0.85_p_mean', 'NV-Importance_r0.85_p_mean', 'Full_Size_Baseline_r0.85_p_mean'], ['Baseline_1024x8000_r0.75_p_step', 'Baseline_1024x8000_r0.75_p_mean', 'SGM_SPADE_1024x8000_r0.75_p_mean', 'NV-Importance_r0.75_p_mean', 'Full_Size_Baseline_r0.75_p_mean']]

# %%
#plot step series u
plotVars_p_allValidators = [[f'{subfolders[0]}_{j}_u_step'] + [f'{i}_{j}_u_mean' for i in subfolders ] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
stepFilter = dataframes[0][f'{subfolders[0]}_r1.0_u_step'] >= 150000
#fmt = '[marker][line][color]' linestyle='--', marker='o', color='b'
#fmts = ['-r','--*b',':^g','-.xc']
#formats = {'marker':['.','*','^','x'], 'linestyle':['-','--',':','-.'], 'color':['r','b','g','c']}

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (28,5))
    fig.suptitle(f'U step series for {agNames[i]}')
    axes[0].set_ylabel('l2_relative_error')
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k])
# Out:
# [['Baseline_1024x8000_r1.0_u_step', 'Baseline_1024x8000_r1.0_u_mean', 'SGM_SPADE_1024x8000_r1.0_u_mean', 'NV-Importance_r1.0_u_mean', 'Full_Size_Baseline_r1.0_u_mean'], ['Baseline_1024x8000_r0.85_u_step', 'Baseline_1024x8000_r0.85_u_mean', 'SGM_SPADE_1024x8000_r0.85_u_mean', 'NV-Importance_r0.85_u_mean', 'Full_Size_Baseline_r0.85_u_mean'], ['Baseline_1024x8000_r0.75_u_step', 'Baseline_1024x8000_r0.75_u_mean', 'SGM_SPADE_1024x8000_r0.75_u_mean', 'NV-Importance_r0.75_u_mean', 'Full_Size_Baseline_r0.75_u_mean']]

# %%
#plot step series v 
plotVars_p_allValidators = [[f'{subfolders[0]}_{j}_v_step'] + [f'{i}_{j}_v_mean' for i in subfolders ] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
stepFilter = dataframes[0][f'{subfolders[0]}_r1.0_v_step'] >= 150000
#fmt = '[marker][line][color]' linestyle='--', marker='o', color='b'
#fmts = ['-r','--*b',':^g','-.xc']
#formats = {'marker':['.','*','^','x'], 'linestyle':['-','--',':','-.'], 'color':['r','b','g','c']}

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (28,5))
    fig.suptitle(f'V step series for {agNames[i]}')
    axes[0].set_ylabel('l2_relative_error')
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k])
# Out:
# [['Baseline_1024x8000_r1.0_v_step', 'Baseline_1024x8000_r1.0_v_mean', 'SGM_SPADE_1024x8000_r1.0_v_mean', 'NV-Importance_r1.0_v_mean', 'Full_Size_Baseline_r1.0_v_mean'], ['Baseline_1024x8000_r0.85_v_step', 'Baseline_1024x8000_r0.85_v_mean', 'SGM_SPADE_1024x8000_r0.85_v_mean', 'NV-Importance_r0.85_v_mean', 'Full_Size_Baseline_r0.85_v_mean'], ['Baseline_1024x8000_r0.75_v_step', 'Baseline_1024x8000_r0.75_v_mean', 'SGM_SPADE_1024x8000_r0.75_v_mean', 'NV-Importance_r0.75_v_mean', 'Full_Size_Baseline_r0.75_v_mean']]

# %%
subfolders[slice(0,2)]
# Out:
# ['Baseline_1024x8000', 'SGM_SPADE_1024x8000']

# %%
#plot time series p
plotVar = 'p'
plotVars_p_allValidators = [[(f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
stepFilter = dataframes[0][f'{subfolders[0]}_r1.0_{plotVar}_step'] >= 150000
#set plotVar to uppercase
# def set_cycler(ax):
#     ax.set_prop_cycle(plt.cycler('color', ['r', 'b', 'g', 'c'])+
#                       plt.cycler('linestyle', ['-','--',':','-.'])+
#                       plt.cycler('marker', ['.','*','^','x']))
    
# def set_cycler(ax):
#     ax.set_prop_cycle(plt.cycler('color', ['r', 'b', 'c', 'g'])+
#                       plt.cycler('linestyle', ['-','--','-.',':'])+
#                       plt.cycler('marker', ['.','*','x','^']))
    
exclude = [2]
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (28,5))
    fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes[0].set_ylabel('l2_relative_error')
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        for l in j:
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
            rawdat[rawdat[l[0]] >= 1.2].plot(x=l[0],y=l[1],ax=axes[k])


# import matplotlib.pyplot as plt
# rawdat = dataframes[0][['SGM_SPADE_validator_2_p_step','SGM_SPADE_wall_time','test_wall_time',
#                         'SGM_SPADE_validator_2_p_mean','test_validator_2_p_mean']
#               ][dataframes[0]['SGM_SPADE_validator_2_p_step'] >= 150000]
# rawdat.loc[:,'SGM_SPADE_wall_time'] = (rawdat.loc[:,'SGM_SPADE_wall_time'] - rawdat.loc[0,'SGM_SPADE_wall_time'])/60/60
# rawdat.loc[:,'test_wall_time'] = (rawdat.loc[:,'test_wall_time'] - rawdat.loc[0,'test_wall_time'])/60/60
# #.plot(x='SGM_SPADE_validator_2_p_step', y = 'SGM_SPADE_validator_2_p_mean')

# #[dataframes[0]['SGM_SPADE_validator_3_p_step'] >= 150000]

# ax = rawdat.plot(x='SGM_SPADE_wall_time', y = 'SGM_SPADE_validator_2_p_mean')
# rawdat.plot(x='test_wall_time', y = 'test_validator_2_p_mean', ax=ax)
# plt.show()
# Out:
# [[('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r1.0_p_mean'), ('SGM_SPADE_1024x8000_wall_time', 'SGM_SPADE_1024x8000_r1.0_p_mean'), ('NV-Importance_wall_time', 'NV-Importance_r1.0_p_mean'), ('Full_Size_Baseline_wall_time', 'Full_Size_Baseline_r1.0_p_mean')], [('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.85_p_mean'), ('SGM_SPADE_1024x8000_wall_time', 'SGM_SPADE_1024x8000_r0.85_p_mean'), ('NV-Importance_wall_time', 'NV-Importance_r0.85_p_mean'), ('Full_Size_Baseline_wall_time', 'Full_Size_Baseline_r0.85_p_mean')], [('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.75_p_mean'), ('SGM_SPADE_1024x8000_wall_time', 'SGM_SPADE_1024x8000_r0.75_p_mean'), ('NV-Importance_wall_time', 'NV-Importance_r0.75_p_mean'), ('Full_Size_Baseline_wall_time', 'Full_Size_Baseline_r0.75_p_mean')]]
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3548644485.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3548644485.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3548644485.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3548644485.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3548644485.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3548644485.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3548644485.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3548644485.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3548644485.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3548644485.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3548644485.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3548644485.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60

# %%
#plot time series u
plotVar = 'u'
plotVars_p_allValidators = [[(f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
stepFilter = dataframes[0][f'{subfolders[0]}_r1.0_{plotVar}_step'] >= 150000
#set plotVar to uppercase
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (28,5))
    fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes[0].set_ylabel('l2_relative_error')
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        for l in j:
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
            rawdat[rawdat[l[0]] >= 1.2].plot(x=l[0],y=l[1],ax=axes[k])


# import matplotlib.pyplot as plt
# rawdat = dataframes[0][['SGM_SPADE_validator_2_p_step','SGM_SPADE_wall_time','test_wall_time',
#                         'SGM_SPADE_validator_2_p_mean','test_validator_2_p_mean']
#               ][dataframes[0]['SGM_SPADE_validator_2_p_step'] >= 150000]
# rawdat.loc[:,'SGM_SPADE_wall_time'] = (rawdat.loc[:,'SGM_SPADE_wall_time'] - rawdat.loc[0,'SGM_SPADE_wall_time'])/60/60
# rawdat.loc[:,'test_wall_time'] = (rawdat.loc[:,'test_wall_time'] - rawdat.loc[0,'test_wall_time'])/60/60
# #.plot(x='SGM_SPADE_validator_2_p_step', y = 'SGM_SPADE_validator_2_p_mean')

# #[dataframes[0]['SGM_SPADE_validator_3_p_step'] >= 150000]

# ax = rawdat.plot(x='SGM_SPADE_wall_time', y = 'SGM_SPADE_validator_2_p_mean')
# rawdat.plot(x='test_wall_time', y = 'test_validator_2_p_mean', ax=ax)
# plt.show()
# Out:
# [[('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r1.0_u_mean'), ('SGM_SPADE_1024x8000_wall_time', 'SGM_SPADE_1024x8000_r1.0_u_mean'), ('NV-Importance_wall_time', 'NV-Importance_r1.0_u_mean'), ('Full_Size_Baseline_wall_time', 'Full_Size_Baseline_r1.0_u_mean')], [('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.85_u_mean'), ('SGM_SPADE_1024x8000_wall_time', 'SGM_SPADE_1024x8000_r0.85_u_mean'), ('NV-Importance_wall_time', 'NV-Importance_r0.85_u_mean'), ('Full_Size_Baseline_wall_time', 'Full_Size_Baseline_r0.85_u_mean')], [('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.75_u_mean'), ('SGM_SPADE_1024x8000_wall_time', 'SGM_SPADE_1024x8000_r0.75_u_mean'), ('NV-Importance_wall_time', 'NV-Importance_r0.75_u_mean'), ('Full_Size_Baseline_wall_time', 'Full_Size_Baseline_r0.75_u_mean')]]
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3554657095.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3554657095.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3554657095.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3554657095.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3554657095.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3554657095.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3554657095.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3554657095.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3554657095.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3554657095.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3554657095.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\3554657095.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60

# %%
#plot time series v
plotVar = 'v'
plotVars_p_allValidators = [[(f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
stepFilter = dataframes[0][f'{subfolders[0]}_r1.0_{plotVar}_step'] >= 150000
#set plotVar to uppercase
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (28,5))
    fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes[0].set_ylabel('l2_relative_error')
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        for l in j:
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
            rawdat[rawdat[l[0]] >= 1.2].plot(x=l[0],y=l[1],ax=axes[k])


# import matplotlib.pyplot as plt
# rawdat = dataframes[0][['SGM_SPADE_validator_2_p_step','SGM_SPADE_wall_time','test_wall_time',
#                         'SGM_SPADE_validator_2_p_mean','test_validator_2_p_mean']
#               ][dataframes[0]['SGM_SPADE_validator_2_p_step'] >= 150000]
# rawdat.loc[:,'SGM_SPADE_wall_time'] = (rawdat.loc[:,'SGM_SPADE_wall_time'] - rawdat.loc[0,'SGM_SPADE_wall_time'])/60/60
# rawdat.loc[:,'test_wall_time'] = (rawdat.loc[:,'test_wall_time'] - rawdat.loc[0,'test_wall_time'])/60/60
# #.plot(x='SGM_SPADE_validator_2_p_step', y = 'SGM_SPADE_validator_2_p_mean')

# #[dataframes[0]['SGM_SPADE_validator_3_p_step'] >= 150000]

# ax = rawdat.plot(x='SGM_SPADE_wall_time', y = 'SGM_SPADE_validator_2_p_mean')
# rawdat.plot(x='test_wall_time', y = 'test_validator_2_p_mean', ax=ax)
# plt.show()
# Out:
# [[('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r1.0_v_mean'), ('SGM_SPADE_1024x8000_wall_time', 'SGM_SPADE_1024x8000_r1.0_v_mean'), ('NV-Importance_wall_time', 'NV-Importance_r1.0_v_mean'), ('Full_Size_Baseline_wall_time', 'Full_Size_Baseline_r1.0_v_mean')], [('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.85_v_mean'), ('SGM_SPADE_1024x8000_wall_time', 'SGM_SPADE_1024x8000_r0.85_v_mean'), ('NV-Importance_wall_time', 'NV-Importance_r0.85_v_mean'), ('Full_Size_Baseline_wall_time', 'Full_Size_Baseline_r0.85_v_mean')], [('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.75_v_mean'), ('SGM_SPADE_1024x8000_wall_time', 'SGM_SPADE_1024x8000_r0.75_v_mean'), ('NV-Importance_wall_time', 'NV-Importance_r0.75_v_mean'), ('Full_Size_Baseline_wall_time', 'Full_Size_Baseline_r0.75_v_mean')]]
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\4180541148.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\4180541148.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\4180541148.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\4180541148.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\4180541148.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\4180541148.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\4180541148.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\4180541148.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\4180541148.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\4180541148.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\4180541148.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_4604\4180541148.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60

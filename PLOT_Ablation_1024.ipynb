# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

variablesKey = 'Validators'
variablesSplit = 'l2_relative_error_'
validatorsRename = {'validator':'r1.0','validator_2':'r0.85','validator_3':'r0.75'}
variablesID = 'validator'
#TODO get subfolders automatically
subfolders = ['Baseline_1024x8000',
              '11-XuvYuv_lVcm',
              '11-NV-Importance',
              'SGM'
              ] ##UPDATE
legendNames = ['Uniform_1024','SGM_SPADE_1024','MIS_1024','SGM_Only_1024']
# run aggregates with these subfoldetrs
#folder = 'C:/Users/jacec/Documents/Test_Runs/'
folder = 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/'
#folder = 'C:/Users/jacec/OneDrive - stevens.edu/4_DATA/Aggregator_Runs/'
#aggregates = [folder+f+'/aggregates/' for f in os.listdir(folder) if os.path.isdir(folder+f)][0:1]
aggregates = [folder+f+'/aggregates/' for f in ['SGM_Ablation_1024'] if os.path.isdir(folder+f)] ##UPDATE
#all results will be in /aggregates, separated by tags from subfolders
#find all validation files separated by subfolder
files = []
#for i in aggregates:
#    csvs_by_testcase = [[i + g for g in os.listdir(i) if (g.endswith('.csv')) and (variablesKey in g) and (f in g)] for f in subfolders]
#    files = files+[i for i in csvs_by_testcase if i]
files = [[i+g for g in os.listdir(i) if g.endswith('.csv') and (variablesKey in g)] for i in aggregates]
#files = [[aggregates + g for g in os.listdir(aggregates) if ('.csv' in g) and (f in g)] for f in subfolders] 
#list of lists of the files for each individual aggregation
#Go through sub-list, load into dataframes with descriptive columns
#Find unique variables, create sub-frames with them in a format for plotting

# %%
files
# Out:
# [['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_p-11-NV-Importance-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_p-11-XuvYuv_lVcm-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_p-Baseline_1024x8000-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_p-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_u-11-NV-Importance-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_u-11-XuvYuv_lVcm-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_u-Baseline_1024x8000-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_u-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_v-11-NV-Importance-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_v-11-XuvYuv_lVcm-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_v-Baseline_1024x8000-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_v-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_p-11-NV-Importance-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_p-11-XuvYuv_lVcm-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_p-Baseline_1024x8000-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_p-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_u-11-NV-Importance-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_u-11-XuvYuv_lVcm-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_u-Baseline_1024x8000-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_u-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_v-11-NV-Importance-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_v-11-XuvYuv_lVcm-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_v-Baseline_1024x8000-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_v-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_p-11-NV-Importance-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_p-11-XuvYuv_lVcm-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_p-Baseline_1024x8000-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_p-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_u-11-NV-Importance-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_u-11-XuvYuv_lVcm-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_u-Baseline_1024x8000-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_u-SGM-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_v-11-NV-Importance-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_v-11-XuvYuv_lVcm-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_v-Baseline_1024x8000-SGM_Ablation_1024.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_v-SGM-SGM_Ablation_1024.csv']]

# %%
#each aggregate becomes one dataframe
#extract common variable names (validator, validator_n, uvpvnu)
#load into df with descriptive columns, uses 'subfolder' name, validator name, variable name
dataframes = []
agNames = []
for aggregation in files:
    dfs = []
    agName = aggregation[0].split('/aggregates/')[0].split('/')[-1]
    for testName in subfolders:
        subtests = [csv for csv in aggregation if testName in csv]
        if not subtests:
            continue
        print(subtests)
        for k,i in enumerate(subtests):
            validatorName = i.split(variablesKey)[1].split(variablesSplit)[0]
            vv = i.split(variablesSplit)[1].split('-'+testName)[0]
            variableName = f'{testName}_{validatorsRename[validatorName]}_{vv}_'
            print(variableName)
            #df = pd.read_csv(i, index_col = 0, delimiter=';')
            df = pd.read_csv(i, delimiter=';')
            oldcols = df.keys()
            print(oldcols)
            #mapping = {i:variableName+i for i in oldcols[0:-1]}
            mapping = {'Unnamed: 0':variableName+'step'}
            if k == 0:
                mapping.update({'wall_time':testName+'_wall_time'})
            mapping.update({i:variableName+i for i in oldcols[1:-1]})
            print(mapping)
            df.rename(columns=mapping, inplace=True)
            newcols = df.keys()
            print(newcols)
            if k > 0:
                df.drop(columns='wall_time')
            dfs.append(df)
    df = pd.concat(dfs, axis=1)
    df = df.loc[:,~df.columns.duplicated()].copy() #drop duplicates based on column name alone
    #append to dataframes list
    dataframes.append(df)
    agNames.append(agName)
# Out:
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_p-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_u-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_v-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_p-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_u-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_v-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_p-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_u-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_v-Baseline_1024x8000-SGM_Ablation_1024.csv']
# Baseline_1024x8000_r1.0_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r1.0_p_step', 'wall_time': 'Baseline_1024x8000_wall_time', 'mean': 'Baseline_1024x8000_r1.0_p_mean', 'amin': 'Baseline_1024x8000_r1.0_p_amin', 'amax': 'Baseline_1024x8000_r1.0_p_amax', 'median': 'Baseline_1024x8000_r1.0_p_median', 'std': 'Baseline_1024x8000_r1.0_p_std', 'var': 'Baseline_1024x8000_r1.0_p_var'}
# Index(['Baseline_1024x8000_r1.0_p_step', 'Baseline_1024x8000_r1.0_p_mean',
#        'Baseline_1024x8000_r1.0_p_amin', 'Baseline_1024x8000_r1.0_p_amax',
#        'Baseline_1024x8000_r1.0_p_median', 'Baseline_1024x8000_r1.0_p_std',
#        'Baseline_1024x8000_r1.0_p_var', 'Baseline_1024x8000_wall_time'],
#       dtype='object')
# Baseline_1024x8000_r1.0_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r1.0_u_step', 'mean': 'Baseline_1024x8000_r1.0_u_mean', 'amin': 'Baseline_1024x8000_r1.0_u_amin', 'amax': 'Baseline_1024x8000_r1.0_u_amax', 'median': 'Baseline_1024x8000_r1.0_u_median', 'std': 'Baseline_1024x8000_r1.0_u_std', 'var': 'Baseline_1024x8000_r1.0_u_var'}
# Index(['Baseline_1024x8000_r1.0_u_step', 'Baseline_1024x8000_r1.0_u_mean',
#        'Baseline_1024x8000_r1.0_u_amin', 'Baseline_1024x8000_r1.0_u_amax',
#        'Baseline_1024x8000_r1.0_u_median', 'Baseline_1024x8000_r1.0_u_std',
#        'Baseline_1024x8000_r1.0_u_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r1.0_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r1.0_v_step', 'mean': 'Baseline_1024x8000_r1.0_v_mean', 'amin': 'Baseline_1024x8000_r1.0_v_amin', 'amax': 'Baseline_1024x8000_r1.0_v_amax', 'median': 'Baseline_1024x8000_r1.0_v_median', 'std': 'Baseline_1024x8000_r1.0_v_std', 'var': 'Baseline_1024x8000_r1.0_v_var'}
# Index(['Baseline_1024x8000_r1.0_v_step', 'Baseline_1024x8000_r1.0_v_mean',
#        'Baseline_1024x8000_r1.0_v_amin', 'Baseline_1024x8000_r1.0_v_amax',
#        'Baseline_1024x8000_r1.0_v_median', 'Baseline_1024x8000_r1.0_v_std',
#        'Baseline_1024x8000_r1.0_v_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r0.85_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r0.85_p_step', 'mean': 'Baseline_1024x8000_r0.85_p_mean', 'amin': 'Baseline_1024x8000_r0.85_p_amin', 'amax': 'Baseline_1024x8000_r0.85_p_amax', 'median': 'Baseline_1024x8000_r0.85_p_median', 'std': 'Baseline_1024x8000_r0.85_p_std', 'var': 'Baseline_1024x8000_r0.85_p_var'}
# Index(['Baseline_1024x8000_r0.85_p_step', 'Baseline_1024x8000_r0.85_p_mean',
#        'Baseline_1024x8000_r0.85_p_amin', 'Baseline_1024x8000_r0.85_p_amax',
#        'Baseline_1024x8000_r0.85_p_median', 'Baseline_1024x8000_r0.85_p_std',
#        'Baseline_1024x8000_r0.85_p_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r0.85_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r0.85_u_step', 'mean': 'Baseline_1024x8000_r0.85_u_mean', 'amin': 'Baseline_1024x8000_r0.85_u_amin', 'amax': 'Baseline_1024x8000_r0.85_u_amax', 'median': 'Baseline_1024x8000_r0.85_u_median', 'std': 'Baseline_1024x8000_r0.85_u_std', 'var': 'Baseline_1024x8000_r0.85_u_var'}
# Index(['Baseline_1024x8000_r0.85_u_step', 'Baseline_1024x8000_r0.85_u_mean',
#        'Baseline_1024x8000_r0.85_u_amin', 'Baseline_1024x8000_r0.85_u_amax',
#        'Baseline_1024x8000_r0.85_u_median', 'Baseline_1024x8000_r0.85_u_std',
#        'Baseline_1024x8000_r0.85_u_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r0.85_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r0.85_v_step', 'mean': 'Baseline_1024x8000_r0.85_v_mean', 'amin': 'Baseline_1024x8000_r0.85_v_amin', 'amax': 'Baseline_1024x8000_r0.85_v_amax', 'median': 'Baseline_1024x8000_r0.85_v_median', 'std': 'Baseline_1024x8000_r0.85_v_std', 'var': 'Baseline_1024x8000_r0.85_v_var'}
# Index(['Baseline_1024x8000_r0.85_v_step', 'Baseline_1024x8000_r0.85_v_mean',
#        'Baseline_1024x8000_r0.85_v_amin', 'Baseline_1024x8000_r0.85_v_amax',
#        'Baseline_1024x8000_r0.85_v_median', 'Baseline_1024x8000_r0.85_v_std',
#        'Baseline_1024x8000_r0.85_v_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r0.75_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r0.75_p_step', 'mean': 'Baseline_1024x8000_r0.75_p_mean', 'amin': 'Baseline_1024x8000_r0.75_p_amin', 'amax': 'Baseline_1024x8000_r0.75_p_amax', 'median': 'Baseline_1024x8000_r0.75_p_median', 'std': 'Baseline_1024x8000_r0.75_p_std', 'var': 'Baseline_1024x8000_r0.75_p_var'}
# Index(['Baseline_1024x8000_r0.75_p_step', 'Baseline_1024x8000_r0.75_p_mean',
#        'Baseline_1024x8000_r0.75_p_amin', 'Baseline_1024x8000_r0.75_p_amax',
#        'Baseline_1024x8000_r0.75_p_median', 'Baseline_1024x8000_r0.75_p_std',
#        'Baseline_1024x8000_r0.75_p_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r0.75_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r0.75_u_step', 'mean': 'Baseline_1024x8000_r0.75_u_mean', 'amin': 'Baseline_1024x8000_r0.75_u_amin', 'amax': 'Baseline_1024x8000_r0.75_u_amax', 'median': 'Baseline_1024x8000_r0.75_u_median', 'std': 'Baseline_1024x8000_r0.75_u_std', 'var': 'Baseline_1024x8000_r0.75_u_var'}
# Index(['Baseline_1024x8000_r0.75_u_step', 'Baseline_1024x8000_r0.75_u_mean',
#        'Baseline_1024x8000_r0.75_u_amin', 'Baseline_1024x8000_r0.75_u_amax',
#        'Baseline_1024x8000_r0.75_u_median', 'Baseline_1024x8000_r0.75_u_std',
#        'Baseline_1024x8000_r0.75_u_var', 'wall_time'],
#       dtype='object')
# Baseline_1024x8000_r0.75_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Baseline_1024x8000_r0.75_v_step', 'mean': 'Baseline_1024x8000_r0.75_v_mean', 'amin': 'Baseline_1024x8000_r0.75_v_amin', 'amax': 'Baseline_1024x8000_r0.75_v_amax', 'median': 'Baseline_1024x8000_r0.75_v_median', 'std': 'Baseline_1024x8000_r0.75_v_std', 'var': 'Baseline_1024x8000_r0.75_v_var'}
# Index(['Baseline_1024x8000_r0.75_v_step', 'Baseline_1024x8000_r0.75_v_mean',
#        'Baseline_1024x8000_r0.75_v_amin', 'Baseline_1024x8000_r0.75_v_amax',
#        'Baseline_1024x8000_r0.75_v_median', 'Baseline_1024x8000_r0.75_v_std',
#        'Baseline_1024x8000_r0.75_v_var', 'wall_time'],
#       dtype='object')
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_p-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_u-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_v-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_p-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_u-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_v-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_p-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_u-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_v-11-XuvYuv_lVcm-SGM_Ablation_1024.csv']
# 11-XuvYuv_lVcm_r1.0_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r1.0_p_step', 'wall_time': '11-XuvYuv_lVcm_wall_time', 'mean': '11-XuvYuv_lVcm_r1.0_p_mean', 'amin': '11-XuvYuv_lVcm_r1.0_p_amin', 'amax': '11-XuvYuv_lVcm_r1.0_p_amax', 'median': '11-XuvYuv_lVcm_r1.0_p_median', 'std': '11-XuvYuv_lVcm_r1.0_p_std', 'var': '11-XuvYuv_lVcm_r1.0_p_var'}
# Index(['11-XuvYuv_lVcm_r1.0_p_step', '11-XuvYuv_lVcm_r1.0_p_mean',
#        '11-XuvYuv_lVcm_r1.0_p_amin', '11-XuvYuv_lVcm_r1.0_p_amax',
#        '11-XuvYuv_lVcm_r1.0_p_median', '11-XuvYuv_lVcm_r1.0_p_std',
#        '11-XuvYuv_lVcm_r1.0_p_var', '11-XuvYuv_lVcm_wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r1.0_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r1.0_u_step', 'mean': '11-XuvYuv_lVcm_r1.0_u_mean', 'amin': '11-XuvYuv_lVcm_r1.0_u_amin', 'amax': '11-XuvYuv_lVcm_r1.0_u_amax', 'median': '11-XuvYuv_lVcm_r1.0_u_median', 'std': '11-XuvYuv_lVcm_r1.0_u_std', 'var': '11-XuvYuv_lVcm_r1.0_u_var'}
# Index(['11-XuvYuv_lVcm_r1.0_u_step', '11-XuvYuv_lVcm_r1.0_u_mean',
#        '11-XuvYuv_lVcm_r1.0_u_amin', '11-XuvYuv_lVcm_r1.0_u_amax',
#        '11-XuvYuv_lVcm_r1.0_u_median', '11-XuvYuv_lVcm_r1.0_u_std',
#        '11-XuvYuv_lVcm_r1.0_u_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r1.0_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r1.0_v_step', 'mean': '11-XuvYuv_lVcm_r1.0_v_mean', 'amin': '11-XuvYuv_lVcm_r1.0_v_amin', 'amax': '11-XuvYuv_lVcm_r1.0_v_amax', 'median': '11-XuvYuv_lVcm_r1.0_v_median', 'std': '11-XuvYuv_lVcm_r1.0_v_std', 'var': '11-XuvYuv_lVcm_r1.0_v_var'}
# Index(['11-XuvYuv_lVcm_r1.0_v_step', '11-XuvYuv_lVcm_r1.0_v_mean',
#        '11-XuvYuv_lVcm_r1.0_v_amin', '11-XuvYuv_lVcm_r1.0_v_amax',
#        '11-XuvYuv_lVcm_r1.0_v_median', '11-XuvYuv_lVcm_r1.0_v_std',
#        '11-XuvYuv_lVcm_r1.0_v_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r0.85_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r0.85_p_step', 'mean': '11-XuvYuv_lVcm_r0.85_p_mean', 'amin': '11-XuvYuv_lVcm_r0.85_p_amin', 'amax': '11-XuvYuv_lVcm_r0.85_p_amax', 'median': '11-XuvYuv_lVcm_r0.85_p_median', 'std': '11-XuvYuv_lVcm_r0.85_p_std', 'var': '11-XuvYuv_lVcm_r0.85_p_var'}
# Index(['11-XuvYuv_lVcm_r0.85_p_step', '11-XuvYuv_lVcm_r0.85_p_mean',
#        '11-XuvYuv_lVcm_r0.85_p_amin', '11-XuvYuv_lVcm_r0.85_p_amax',
#        '11-XuvYuv_lVcm_r0.85_p_median', '11-XuvYuv_lVcm_r0.85_p_std',
#        '11-XuvYuv_lVcm_r0.85_p_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r0.85_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r0.85_u_step', 'mean': '11-XuvYuv_lVcm_r0.85_u_mean', 'amin': '11-XuvYuv_lVcm_r0.85_u_amin', 'amax': '11-XuvYuv_lVcm_r0.85_u_amax', 'median': '11-XuvYuv_lVcm_r0.85_u_median', 'std': '11-XuvYuv_lVcm_r0.85_u_std', 'var': '11-XuvYuv_lVcm_r0.85_u_var'}
# Index(['11-XuvYuv_lVcm_r0.85_u_step', '11-XuvYuv_lVcm_r0.85_u_mean',
#        '11-XuvYuv_lVcm_r0.85_u_amin', '11-XuvYuv_lVcm_r0.85_u_amax',
#        '11-XuvYuv_lVcm_r0.85_u_median', '11-XuvYuv_lVcm_r0.85_u_std',
#        '11-XuvYuv_lVcm_r0.85_u_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r0.85_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r0.85_v_step', 'mean': '11-XuvYuv_lVcm_r0.85_v_mean', 'amin': '11-XuvYuv_lVcm_r0.85_v_amin', 'amax': '11-XuvYuv_lVcm_r0.85_v_amax', 'median': '11-XuvYuv_lVcm_r0.85_v_median', 'std': '11-XuvYuv_lVcm_r0.85_v_std', 'var': '11-XuvYuv_lVcm_r0.85_v_var'}
# Index(['11-XuvYuv_lVcm_r0.85_v_step', '11-XuvYuv_lVcm_r0.85_v_mean',
#        '11-XuvYuv_lVcm_r0.85_v_amin', '11-XuvYuv_lVcm_r0.85_v_amax',
#        '11-XuvYuv_lVcm_r0.85_v_median', '11-XuvYuv_lVcm_r0.85_v_std',
#        '11-XuvYuv_lVcm_r0.85_v_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r0.75_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r0.75_p_step', 'mean': '11-XuvYuv_lVcm_r0.75_p_mean', 'amin': '11-XuvYuv_lVcm_r0.75_p_amin', 'amax': '11-XuvYuv_lVcm_r0.75_p_amax', 'median': '11-XuvYuv_lVcm_r0.75_p_median', 'std': '11-XuvYuv_lVcm_r0.75_p_std', 'var': '11-XuvYuv_lVcm_r0.75_p_var'}
# Index(['11-XuvYuv_lVcm_r0.75_p_step', '11-XuvYuv_lVcm_r0.75_p_mean',
#        '11-XuvYuv_lVcm_r0.75_p_amin', '11-XuvYuv_lVcm_r0.75_p_amax',
#        '11-XuvYuv_lVcm_r0.75_p_median', '11-XuvYuv_lVcm_r0.75_p_std',
#        '11-XuvYuv_lVcm_r0.75_p_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r0.75_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r0.75_u_step', 'mean': '11-XuvYuv_lVcm_r0.75_u_mean', 'amin': '11-XuvYuv_lVcm_r0.75_u_amin', 'amax': '11-XuvYuv_lVcm_r0.75_u_amax', 'median': '11-XuvYuv_lVcm_r0.75_u_median', 'std': '11-XuvYuv_lVcm_r0.75_u_std', 'var': '11-XuvYuv_lVcm_r0.75_u_var'}
# Index(['11-XuvYuv_lVcm_r0.75_u_step', '11-XuvYuv_lVcm_r0.75_u_mean',
#        '11-XuvYuv_lVcm_r0.75_u_amin', '11-XuvYuv_lVcm_r0.75_u_amax',
#        '11-XuvYuv_lVcm_r0.75_u_median', '11-XuvYuv_lVcm_r0.75_u_std',
#        '11-XuvYuv_lVcm_r0.75_u_var', 'wall_time'],
#       dtype='object')
# 11-XuvYuv_lVcm_r0.75_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-XuvYuv_lVcm_r0.75_v_step', 'mean': '11-XuvYuv_lVcm_r0.75_v_mean', 'amin': '11-XuvYuv_lVcm_r0.75_v_amin', 'amax': '11-XuvYuv_lVcm_r0.75_v_amax', 'median': '11-XuvYuv_lVcm_r0.75_v_median', 'std': '11-XuvYuv_lVcm_r0.75_v_std', 'var': '11-XuvYuv_lVcm_r0.75_v_var'}
# Index(['11-XuvYuv_lVcm_r0.75_v_step', '11-XuvYuv_lVcm_r0.75_v_mean',
#        '11-XuvYuv_lVcm_r0.75_v_amin', '11-XuvYuv_lVcm_r0.75_v_amax',
#        '11-XuvYuv_lVcm_r0.75_v_median', '11-XuvYuv_lVcm_r0.75_v_std',
#        '11-XuvYuv_lVcm_r0.75_v_var', 'wall_time'],
#       dtype='object')
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_p-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_u-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_v-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_p-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_u-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_v-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_p-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_u-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_3l2_relative_error_v-11-NV-Importance-SGM_Ablation_1024.csv']
# 11-NV-Importance_r1.0_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r1.0_p_step', 'wall_time': '11-NV-Importance_wall_time', 'mean': '11-NV-Importance_r1.0_p_mean', 'amin': '11-NV-Importance_r1.0_p_amin', 'amax': '11-NV-Importance_r1.0_p_amax', 'median': '11-NV-Importance_r1.0_p_median', 'std': '11-NV-Importance_r1.0_p_std', 'var': '11-NV-Importance_r1.0_p_var'}
# Index(['11-NV-Importance_r1.0_p_step', '11-NV-Importance_r1.0_p_mean',
#        '11-NV-Importance_r1.0_p_amin', '11-NV-Importance_r1.0_p_amax',
#        '11-NV-Importance_r1.0_p_median', '11-NV-Importance_r1.0_p_std',
#        '11-NV-Importance_r1.0_p_var', '11-NV-Importance_wall_time'],
#       dtype='object')
# 11-NV-Importance_r1.0_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r1.0_u_step', 'mean': '11-NV-Importance_r1.0_u_mean', 'amin': '11-NV-Importance_r1.0_u_amin', 'amax': '11-NV-Importance_r1.0_u_amax', 'median': '11-NV-Importance_r1.0_u_median', 'std': '11-NV-Importance_r1.0_u_std', 'var': '11-NV-Importance_r1.0_u_var'}
# Index(['11-NV-Importance_r1.0_u_step', '11-NV-Importance_r1.0_u_mean',
#        '11-NV-Importance_r1.0_u_amin', '11-NV-Importance_r1.0_u_amax',
#        '11-NV-Importance_r1.0_u_median', '11-NV-Importance_r1.0_u_std',
#        '11-NV-Importance_r1.0_u_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r1.0_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r1.0_v_step', 'mean': '11-NV-Importance_r1.0_v_mean', 'amin': '11-NV-Importance_r1.0_v_amin', 'amax': '11-NV-Importance_r1.0_v_amax', 'median': '11-NV-Importance_r1.0_v_median', 'std': '11-NV-Importance_r1.0_v_std', 'var': '11-NV-Importance_r1.0_v_var'}
# Index(['11-NV-Importance_r1.0_v_step', '11-NV-Importance_r1.0_v_mean',
#        '11-NV-Importance_r1.0_v_amin', '11-NV-Importance_r1.0_v_amax',
#        '11-NV-Importance_r1.0_v_median', '11-NV-Importance_r1.0_v_std',
#        '11-NV-Importance_r1.0_v_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r0.85_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r0.85_p_step', 'mean': '11-NV-Importance_r0.85_p_mean', 'amin': '11-NV-Importance_r0.85_p_amin', 'amax': '11-NV-Importance_r0.85_p_amax', 'median': '11-NV-Importance_r0.85_p_median', 'std': '11-NV-Importance_r0.85_p_std', 'var': '11-NV-Importance_r0.85_p_var'}
# Index(['11-NV-Importance_r0.85_p_step', '11-NV-Importance_r0.85_p_mean',
#        '11-NV-Importance_r0.85_p_amin', '11-NV-Importance_r0.85_p_amax',
#        '11-NV-Importance_r0.85_p_median', '11-NV-Importance_r0.85_p_std',
#        '11-NV-Importance_r0.85_p_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r0.85_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r0.85_u_step', 'mean': '11-NV-Importance_r0.85_u_mean', 'amin': '11-NV-Importance_r0.85_u_amin', 'amax': '11-NV-Importance_r0.85_u_amax', 'median': '11-NV-Importance_r0.85_u_median', 'std': '11-NV-Importance_r0.85_u_std', 'var': '11-NV-Importance_r0.85_u_var'}
# Index(['11-NV-Importance_r0.85_u_step', '11-NV-Importance_r0.85_u_mean',
#        '11-NV-Importance_r0.85_u_amin', '11-NV-Importance_r0.85_u_amax',
#        '11-NV-Importance_r0.85_u_median', '11-NV-Importance_r0.85_u_std',
#        '11-NV-Importance_r0.85_u_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r0.85_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r0.85_v_step', 'mean': '11-NV-Importance_r0.85_v_mean', 'amin': '11-NV-Importance_r0.85_v_amin', 'amax': '11-NV-Importance_r0.85_v_amax', 'median': '11-NV-Importance_r0.85_v_median', 'std': '11-NV-Importance_r0.85_v_std', 'var': '11-NV-Importance_r0.85_v_var'}
# Index(['11-NV-Importance_r0.85_v_step', '11-NV-Importance_r0.85_v_mean',
#        '11-NV-Importance_r0.85_v_amin', '11-NV-Importance_r0.85_v_amax',
#        '11-NV-Importance_r0.85_v_median', '11-NV-Importance_r0.85_v_std',
#        '11-NV-Importance_r0.85_v_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r0.75_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r0.75_p_step', 'mean': '11-NV-Importance_r0.75_p_mean', 'amin': '11-NV-Importance_r0.75_p_amin', 'amax': '11-NV-Importance_r0.75_p_amax', 'median': '11-NV-Importance_r0.75_p_median', 'std': '11-NV-Importance_r0.75_p_std', 'var': '11-NV-Importance_r0.75_p_var'}
# Index(['11-NV-Importance_r0.75_p_step', '11-NV-Importance_r0.75_p_mean',
#        '11-NV-Importance_r0.75_p_amin', '11-NV-Importance_r0.75_p_amax',
#        '11-NV-Importance_r0.75_p_median', '11-NV-Importance_r0.75_p_std',
#        '11-NV-Importance_r0.75_p_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r0.75_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r0.75_u_step', 'mean': '11-NV-Importance_r0.75_u_mean', 'amin': '11-NV-Importance_r0.75_u_amin', 'amax': '11-NV-Importance_r0.75_u_amax', 'median': '11-NV-Importance_r0.75_u_median', 'std': '11-NV-Importance_r0.75_u_std', 'var': '11-NV-Importance_r0.75_u_var'}
# Index(['11-NV-Importance_r0.75_u_step', '11-NV-Importance_r0.75_u_mean',
#        '11-NV-Importance_r0.75_u_amin', '11-NV-Importance_r0.75_u_amax',
#        '11-NV-Importance_r0.75_u_median', '11-NV-Importance_r0.75_u_std',
#        '11-NV-Importance_r0.75_u_var', 'wall_time'],
#       dtype='object')
# 11-NV-Importance_r0.75_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': '11-NV-Importance_r0.75_v_step', 'mean': '11-NV-Importance_r0.75_v_mean', 'amin': '11-NV-Importance_r0.75_v_amin', 'amax': '11-NV-Importance_r0.75_v_amax', 'median': '11-NV-Importance_r0.75_v_median', 'std': '11-NV-Importance_r0.75_v_std', 'var': '11-NV-Importance_r0.75_v_var'}
# Index(['11-NV-Importance_r0.75_v_step', '11-NV-Importance_r0.75_v_mean',
#        '11-NV-Importance_r0.75_v_amin', '11-NV-Importance_r0.75_v_amax',
#        '11-NV-Importance_r0.75_v_median', '11-NV-Importance_r0.75_v_std',
#        '11-NV-Importance_r0.75_v_var', 'wall_time'],
#       dtype='object')
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_p-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_p-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_p-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_p-SGM-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_u-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_u-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_u-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_u-SGM-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_v-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_v-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_v-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidatorl2_relative_error_v-SGM-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_p-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_p-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_p-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_p-SGM-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_u-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_u-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_u-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_u-SGM-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_v-11-NV-Importance-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_v-11-XuvYuv_lVcm-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_v-Baseline_1024x8000-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validatorsvalidator_2l2_relative_error_v-SGM-SGM_Ablation_1024.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/SGM_Ablation_1024/aggregates/Validato ...
# SGM_r1.0_p-11-NV-Importance_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r1.0_p-11-NV-Importance_step', 'wall_time': 'SGM_wall_time', 'mean': 'SGM_r1.0_p-11-NV-Importance_mean', 'amin': 'SGM_r1.0_p-11-NV-Importance_amin', 'amax': 'SGM_r1.0_p-11-NV-Importance_amax', 'median': 'SGM_r1.0_p-11-NV-Importance_median', 'std': 'SGM_r1.0_p-11-NV-Importance_std', 'var': 'SGM_r1.0_p-11-NV-Importance_var'}
# Index(['SGM_r1.0_p-11-NV-Importance_step', 'SGM_r1.0_p-11-NV-Importance_mean',
#        'SGM_r1.0_p-11-NV-Importance_amin', 'SGM_r1.0_p-11-NV-Importance_amax',
#        'SGM_r1.0_p-11-NV-Importance_median', 'SGM_r1.0_p-11-NV-Importance_std',
#        'SGM_r1.0_p-11-NV-Importance_var', 'SGM_wall_time'],
#       dtype='object')
# SGM_r1.0_p-11-XuvYuv_lVcm_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r1.0_p-11-XuvYuv_lVcm_step', 'mean': 'SGM_r1.0_p-11-XuvYuv_lVcm_mean', 'amin': 'SGM_r1.0_p-11-XuvYuv_lVcm_amin', 'amax': 'SGM_r1.0_p-11-XuvYuv_lVcm_amax', 'median': 'SGM_r1.0_p-11-XuvYuv_lVcm_median', 'std': 'SGM_r1.0_p-11-XuvYuv_lVcm_std', 'var': 'SGM_r1.0_p-11-XuvYuv_lVcm_var'}
# Index(['SGM_r1.0_p-11-XuvYuv_lVcm_step', 'SGM_r1.0_p-11-XuvYuv_lVcm_mean',
#        'SGM_r1.0_p-11-XuvYuv_lVcm_amin', 'SGM_r1.0_p-11-XuvYuv_lVcm_amax',
#        'SGM_r1.0_p-11-XuvYuv_lVcm_median', 'SGM_r1.0_p-11-XuvYuv_lVcm_std',
#        'SGM_r1.0_p-11-XuvYuv_lVcm_var', 'wall_time'],
#       dtype='object')
# SGM_r1.0_p-Baseline_1024x8000_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r1.0_p-Baseline_1024x8000_step', 'mean': 'SGM_r1.0_p-Baseline_1024x8000_mean', 'amin': 'SGM_r1.0_p-Baseline_1024x8000_amin', 'amax': 'SGM_r1.0_p-Baseline_1024x8000_amax', 'median': 'SGM_r1.0_p-Baseline_1024x8000_median', 'std': 'SGM_r1.0_p-Baseline_1024x8000_std', 'var': 'SGM_r1.0_p-Baseline_1024x8000_var'}
# Index(['SGM_r1.0_p-Baseline_1024x8000_step',
#        'SGM_r1.0_p-Baseline_1024x8000_mean',
#        'SGM_r1.0_p-Baseline_1024x8000_amin',
#        'SGM_r1.0_p-Baseline_1024x8000_amax',
#        'SGM_r1.0_p-Baseline_1024x8000_median',
#        'SGM_r1.0_p-Baseline_1024x8000_std',
#        'SGM_r1.0_p-Baseline_1024x8000_var', 'wall_time'],
#       dtype='object')
# SGM_r1.0_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r1.0_p_step', 'mean': 'SGM_r1.0_p_mean', 'amin': 'SGM_r1.0_p_amin', 'amax': 'SGM_r1.0_p_amax', 'median': 'SGM_r1.0_p_median', 'std': 'SGM_r1.0_p_std', 'var': 'SGM_r1.0_p_var'}
# Index(['SGM_r1.0_p_step', 'SGM_r1.0_p_mean', 'SGM_r1.0_p_amin',
#        'SGM_r1.0_p_amax', 'SGM_r1.0_p_median', 'SGM_r1.0_p_std',
#        'SGM_r1.0_p_var', 'wall_time'],
#       dtype='object')
# SGM_r1.0_u-11-NV-Importance_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r1.0_u-11-NV-Importance_step', 'mean': 'SGM_r1.0_u-11-NV-Importance_mean', 'amin': 'SGM_r1.0_u-11-NV-Importance_amin', 'amax': 'SGM_r1.0_u-11-NV-Importance_amax', 'median': 'SGM_r1.0_u-11-NV-Importance_median', 'std': 'SGM_r1.0_u-11-NV-Importance_std', 'var': 'SGM_r1.0_u-11-NV-Importance_var'}
# Index(['SGM_r1.0_u-11-NV-Importance_step', 'SGM_r1.0_u-11-NV-Importance_mean',
#        'SGM_r1.0_u-11-NV-Importance_amin', 'SGM_r1.0_u-11-NV-Importance_amax',
#        'SGM_r1.0_u-11-NV-Importance_median', 'SGM_r1.0_u-11-NV-Importance_std',
#        'SGM_r1.0_u-11-NV-Importance_var', 'wall_time'],
#       dtype='object')
# SGM_r1.0_u-11-XuvYuv_lVcm_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r1.0_u-11-XuvYuv_lVcm_step', 'mean': 'SGM_r1.0_u-11-XuvYuv_lVcm_mean', 'amin': 'SGM_r1.0_u-11-XuvYuv_lVcm_amin', 'amax': 'SGM_r1.0_u-11-XuvYuv_lVcm_amax', 'median': 'SGM_r1.0_u-11-XuvYuv_lVcm_median', 'std': 'SGM_r1.0_u-11-XuvYuv_lVcm_std', 'var': 'SGM_r1.0_u-11-XuvYuv_lVcm_var'}
# Index(['SGM_r1.0_u-11-XuvYuv_lVcm_step', 'SGM_r1.0_u-11-XuvYuv_lVcm_mean',
#        'SGM_r1.0_u-11-XuvYuv_lVcm_amin', 'SGM_r1.0_u-11-XuvYuv_lVcm_amax',
#        'SGM_r1.0_u-11-XuvYuv_lVcm_median', 'SGM_r1.0_u-11-XuvYuv_lVcm_std',
#        'SGM_r1.0_u-11-XuvYuv_lVcm_var', 'wall_time'],
#       dtype='object')
# SGM_r1.0_u-Baseline_1024x8000_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r1.0_u-Baseline_1024x8000_step', 'mean': 'SGM_r1.0_u-Baseline_1024x8000_mean', 'amin': 'SGM_r1.0_u-Baseline_1024x8000_amin', 'amax': 'SGM_r1.0_u-Baseline_1024x8000_amax', 'median': 'SGM_r1.0_u-Baseline_1024x8000_median', 'std': 'SGM_r1.0_u-Baseline_1024x8000_std', 'var': 'SGM_r1.0_u-Baseline_1024x8000_var'}
# Index(['SGM_r1.0_u-Baseline_1024x8000_step',
#        'SGM_r1.0_u-Baseline_1024x8000_mean',
#        'SGM_r1.0_u-Baseline_1024x8000_amin',
#        'SGM_r1.0_u-Baseline_1024x8000_amax',
#        'SGM_r1.0_u-Baseline_1024x8000_median',
#        'SGM_r1.0_u-Baseline_1024x8000_std',
#        'SGM_r1.0_u-Baseline_1024x8000_var', 'wall_time'],
#       dtype='object')
# SGM_r1.0_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r1.0_u_step', 'mean': 'SGM_r1.0_u_mean', 'amin': 'SGM_r1.0_u_amin', 'amax': 'SGM_r1.0_u_amax', 'median': 'SGM_r1.0_u_median', 'std': 'SGM_r1.0_u_std', 'var': 'SGM_r1.0_u_var'}
# Index(['SGM_r1.0_u_step', 'SGM_r1.0_u_mean', 'SGM_r1.0_u_amin',
#        'SGM_r1.0_u_amax', 'SGM_r1.0_u_median', 'SGM_r1.0_u_std',
#        'SGM_r1.0_u_var', 'wall_time'],
#       dtype='object')
# SGM_r1.0_v-11-NV-Importance_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r1.0_v-11-NV-Importance_step', 'mean': 'SGM_r1.0_v-11-NV-Importance_mean', 'amin': 'SGM_r1.0_v-11-NV-Importance_amin', 'amax': 'SGM_r1.0_v-11-NV-Importance_amax', 'median': 'SGM_r1.0_v-11-NV-Importance_median', 'std': 'SGM_r1.0_v-11-NV-Importance_std', 'var': 'SGM_r1.0_v-11-NV-Importance_var'}
# Index(['SGM_r1.0_v-11-NV-Importance_step', 'SGM_r1.0_v-11-NV-Importance_mean',
#        'SGM_r1.0_v-11-NV-Importance_amin', 'SGM_r1.0_v-11-NV-Importance_amax',
#        'SGM_r1.0_v-11-NV-Importance_median', 'SGM_r1.0_v-11-NV-Importance_std',
#        'SGM_r1.0_v-11-NV-Importance_var', 'wall_time'],
#       dtype='object')
# SGM_r1.0_v-11-XuvYuv_lVcm_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r1.0_v-11-XuvYuv_lVcm_step', 'mean': 'SGM_r1.0_v-11-XuvYuv_lVcm_mean', 'amin': 'SGM_r1.0_v-11-XuvYuv_lVcm_amin', 'amax': 'SGM_r1.0_v-11-XuvYuv_lVcm_amax', 'median': 'SGM_r1.0_v-11-XuvYuv_lVcm_median', 'std': 'SGM_r1.0_v-11-XuvYuv_lVcm_std', 'var': 'SGM_r1.0_v-11-XuvYuv_lVcm_var'}
# Index(['SGM_r1.0_v-11-XuvYuv_lVcm_step', 'SGM_r1.0_v-11-XuvYuv_lVcm_mean',
#        'SGM_r1.0_v-11-XuvYuv_lVcm_amin', 'SGM_r1.0_v-11-XuvYuv_lVcm_amax',
#        'SGM_r1.0_v-11-XuvYuv_lVcm_median', 'SGM_r1.0_v-11-XuvYuv_lVcm_std',
#        'SGM_r1.0_v-11-XuvYuv_lVcm_var', 'wall_time'],
#       dtype='object')
# SGM_r1.0_v-Baseline_1024x8000_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r1.0_v-Baseline_1024x8000_step', 'mean': 'SGM_r1.0_v-Baseline_1024x8000_mean', 'amin': 'SGM_r1.0_v-Baseline_1024x8000_amin', 'amax': 'SGM_r1.0_v-Baseline_1024x8000_amax', 'median': 'SGM_r1.0_v-Baseline_1024x8000_median', 'std': 'SGM_r1.0_v-Baseline_1024x8000_std', 'var': 'SGM_r1.0_v-Baseline_1024x8000_var'}
# Index(['SGM_r1.0_v-Baseline_1024x8000_step',
#        'SGM_r1.0_v-Baseline_1024x8000_mean',
#        'SGM_r1.0_v-Baseline_1024x8000_amin',
#        'SGM_r1.0_v-Baseline_1024x8000_amax',
#        'SGM_r1.0_v-Baseline_1024x8000_median',
#        'SGM_r1.0_v-Baseline_1024x8000_std',
#        'SGM_r1.0_v-Baseline_1024x8000_var', 'wall_time'],
#       dtype='object')
# SGM_r1.0_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r1.0_v_step', 'mean': 'SGM_r1.0_v_mean', 'amin': 'SGM_r1.0_v_amin', 'amax': 'SGM_r1.0_v_amax', 'median': 'SGM_r1.0_v_median', 'std': 'SGM_r1.0_v_std', 'var': 'SGM_r1.0_v_var'}
# Index(['SGM_r1.0_v_step', 'SGM_r1.0_v_mean', 'SGM_r1.0_v_amin',
#        'SGM_r1.0_v_amax', 'SGM_r1.0_v_median', 'SGM_r1.0_v_std',
#        'SGM_r1.0_v_var', 'wall_time'],
#       dtype='object')
# SGM_r0.85_p-11-NV-Importance_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.85_p-11-NV-Importance_step', 'mean': 'SGM_r0.85_p-11-NV-Importance_mean', 'amin': 'SGM_r0.85_p-11-NV-Importance_amin', 'amax': 'SGM_r0.85_p-11-NV-Importance_amax', 'median': 'SGM_r0.85_p-11-NV-Importance_median', 'std': 'SGM_r0.85_p-11-NV-Importance_std', 'var': 'SGM_r0.85_p-11-NV-Importance_var'}
# Index(['SGM_r0.85_p-11-NV-Importance_step',
#        'SGM_r0.85_p-11-NV-Importance_mean',
#        'SGM_r0.85_p-11-NV-Importance_amin',
#        'SGM_r0.85_p-11-NV-Importance_amax',
#        'SGM_r0.85_p-11-NV-Importance_median',
#        'SGM_r0.85_p-11-NV-Importance_std', 'SGM_r0.85_p-11-NV-Importance_var',
#        'wall_time'],
#       dtype='object')
# SGM_r0.85_p-11-XuvYuv_lVcm_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.85_p-11-XuvYuv_lVcm_step', 'mean': 'SGM_r0.85_p-11-XuvYuv_lVcm_mean', 'amin': 'SGM_r0.85_p-11-XuvYuv_lVcm_amin', 'amax': 'SGM_r0.85_p-11-XuvYuv_lVcm_amax', 'median': 'SGM_r0.85_p-11-XuvYuv_lVcm_median', 'std': 'SGM_r0.85_p-11-XuvYuv_lVcm_std', 'var': 'SGM_r0.85_p-11-XuvYuv_lVcm_var'}
# Index(['SGM_r0.85_p-11-XuvYuv_lVcm_step', 'SGM_r0.85_p-11-XuvYuv_lVcm_mean',
#        'SGM_r0.85_p-11-XuvYuv_lVcm_amin', 'SGM_r0.85_p-11-XuvYuv_lVcm_amax',
#        'SGM_r0.85_p-11-XuvYuv_lVcm_median', 'SGM_r0.85_p-11-XuvYuv_lVcm_std',
#        'SGM_r0.85_p-11-XuvYuv_lVcm_var', 'wall_time'],
#       dtype='object')
# SGM_r0.85_p-Baseline_1024x8000_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.85_p-Baseline_1024x8000_step', 'mean': 'SGM_r0.85_p-Baseline_1024x8000_mean', 'amin': 'SGM_r0.85_p-Baseline_1024x8000_amin', 'amax': 'SGM_r0.85_p-Baseline_1024x8000_amax', 'median': 'SGM_r0.85_p-Baseline_1024x8000_median', 'std': 'SGM_r0.85_p-Baseline_1024x8000_std', 'var': 'SGM_r0.85_p-Baseline_1024x8000_var'}
# Index(['SGM_r0.85_p-Baseline_1024x8000_step',
#        'SGM_r0.85_p-Baseline_1024x8000_mean',
#        'SGM_r0.85_p-Baseline_1024x8000_amin',
#        'SGM_r0.85_p-Baseline_1024x8000_amax',
#        'SGM_r0.85_p-Baseline_1024x8000_median',
#        'SGM_r0.85_p-Baseline_1024x8000_std',
#        'SGM_r0.85_p-Baseline_1024x8000_var', 'wall_time'],
#       dtype='object')
# SGM_r0.85_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.85_p_step', 'mean': 'SGM_r0.85_p_mean', 'amin': 'SGM_r0.85_p_amin', 'amax': 'SGM_r0.85_p_amax', 'median': 'SGM_r0.85_p_median', 'std': 'SGM_r0.85_p_std', 'var': 'SGM_r0.85_p_var'}
# Index(['SGM_r0.85_p_step', 'SGM_r0.85_p_mean', 'SGM_r0.85_p_amin',
#        'SGM_r0.85_p_amax', 'SGM_r0.85_p_median', 'SGM_r0.85_p_std',
#        'SGM_r0.85_p_var', 'wall_time'],
#       dtype='object')
# SGM_r0.85_u-11-NV-Importance_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.85_u-11-NV-Importance_step', 'mean': 'SGM_r0.85_u-11-NV-Importance_mean', 'amin': 'SGM_r0.85_u-11-NV-Importance_amin', 'amax': 'SGM_r0.85_u-11-NV-Importance_amax', 'median': 'SGM_r0.85_u-11-NV-Importance_median', 'std': 'SGM_r0.85_u-11-NV-Importance_std', 'var': 'SGM_r0.85_u-11-NV-Importance_var'}
# Index(['SGM_r0.85_u-11-NV-Importance_step',
#        'SGM_r0.85_u-11-NV-Importance_mean',
#        'SGM_r0.85_u-11-NV-Importance_amin',
#        'SGM_r0.85_u-11-NV-Importance_amax',
#        'SGM_r0.85_u-11-NV-Importance_median',
#        'SGM_r0.85_u-11-NV-Importance_std', 'SGM_r0.85_u-11-NV-Importance_var',
#        'wall_time'],
#       dtype='object')
# SGM_r0.85_u-11-XuvYuv_lVcm_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.85_u-11-XuvYuv_lVcm_step', 'mean': 'SGM_r0.85_u-11-XuvYuv_lVcm_mean', 'amin': 'SGM_r0.85_u-11-XuvYuv_lVcm_amin', 'amax': 'SGM_r0.85_u-11-XuvYuv_lVcm_amax', 'median': 'SGM_r0.85_u-11-XuvYuv_lVcm_median', 'std': 'SGM_r0.85_u-11-XuvYuv_lVcm_std', 'var': 'SGM_r0.85_u-11-XuvYuv_lVcm_var'}
# Index(['SGM_r0.85_u-11-XuvYuv_lVcm_step', 'SGM_r0.85_u-11-XuvYuv_lVcm_mean',
#        'SGM_r0.85_u-11-XuvYuv_lVcm_amin', 'SGM_r0.85_u-11-XuvYuv_lVcm_amax',
#        'SGM_r0.85_u-11-XuvYuv_lVcm_median', 'SGM_r0.85_u-11-XuvYuv_lVcm_std',
#        'SGM_r0.85_u-11-XuvYuv_lVcm_var', 'wall_time'],
#       dtype='object')
# SGM_r0.85_u-Baseline_1024x8000_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.85_u-Baseline_1024x8000_step', 'mean': 'SGM_r0.85_u-Baseline_1024x8000_mean', 'amin': 'SGM_r0.85_u-Baseline_1024x8000_amin', 'amax': 'SGM_r0.85_u-Baseline_1024x8000_amax', 'median': 'SGM_r0.85_u-Baseline_1024x8000_median', 'std': 'SGM_r0.85_u-Baseline_1024x8000_std', 'var': 'SGM_r0.85_u-Baseline_1024x8000_var'}
# Index(['SGM_r0.85_u-Baseline_1024x8000_step',
#        'SGM_r0.85_u-Baseline_1024x8000_mean',
#        'SGM_r0.85_u-Baseline_1024x8000_amin',
#        'SGM_r0.85_u-Baseline_1024x8000_amax',
#        'SGM_r0.85_u-Baseline_1024x8000_median',
#        'SGM_r0.85_u-Baseline_1024x8000_std',
#        'SGM_r0.85_u-Baseline_1024x8000_var', 'wall_time'],
#       dtype='object')
# SGM_r0.85_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.85_u_step', 'mean': 'SGM_r0.85_u_mean', 'amin': 'SGM_r0.85_u_amin', 'amax': 'SGM_r0.85_u_amax', 'median': 'SGM_r0.85_u_median', 'std': 'SGM_r0.85_u_std', 'var': 'SGM_r0.85_u_var'}
# Index(['SGM_r0.85_u_step', 'SGM_r0.85_u_mean', 'SGM_r0.85_u_amin',
#        'SGM_r0.85_u_amax', 'SGM_r0.85_u_median', 'SGM_r0.85_u_std',
#        'SGM_r0.85_u_var', 'wall_time'],
#       dtype='object')
# SGM_r0.85_v-11-NV-Importance_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.85_v-11-NV-Importance_step', 'mean': 'SGM_r0.85_v-11-NV-Importance_mean', 'amin': 'SGM_r0.85_v-11-NV-Importance_amin', 'amax': 'SGM_r0.85_v-11-NV-Importance_amax', 'median': 'SGM_r0.85_v-11-NV-Importance_median', 'std': 'SGM_r0.85_v-11-NV-Importance_std', 'var': 'SGM_r0.85_v-11-NV-Importance_var'}
# Index(['SGM_r0.85_v-11-NV-Importance_step',
#        'SGM_r0.85_v-11-NV-Importance_mean',
#        'SGM_r0.85_v-11-NV-Importance_amin',
#        'SGM_r0.85_v-11-NV-Importance_amax',
#        'SGM_r0.85_v-11-NV-Importance_median',
#        'SGM_r0.85_v-11-NV-Importance_std', 'SGM_r0.85_v-11-NV-Importance_var',
#        'wall_time'],
#       dtype='object')
# SGM_r0.85_v-11-XuvYuv_lVcm_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.85_v-11-XuvYuv_lVcm_step', 'mean': 'SGM_r0.85_v-11-XuvYuv_lVcm_mean', 'amin': 'SGM_r0.85_v-11-XuvYuv_lVcm_amin', 'amax': 'SGM_r0.85_v-11-XuvYuv_lVcm_amax', 'median': 'SGM_r0.85_v-11-XuvYuv_lVcm_median', 'std': 'SGM_r0.85_v-11-XuvYuv_lVcm_std', 'var': 'SGM_r0.85_v-11-XuvYuv_lVcm_var'}
# Index(['SGM_r0.85_v-11-XuvYuv_lVcm_step', 'SGM_r0.85_v-11-XuvYuv_lVcm_mean',
#        'SGM_r0.85_v-11-XuvYuv_lVcm_amin', 'SGM_r0.85_v-11-XuvYuv_lVcm_amax',
#        'SGM_r0.85_v-11-XuvYuv_lVcm_median', 'SGM_r0.85_v-11-XuvYuv_lVcm_std',
#        'SGM_r0.85_v-11-XuvYuv_lVcm_var', 'wall_time'],
#       dtype='object')
# SGM_r0.85_v-Baseline_1024x8000_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.85_v-Baseline_1024x8000_step', 'mean': 'SGM_r0.85_v-Baseline_1024x8000_mean', 'amin': 'SGM_r0.85_v-Baseline_1024x8000_amin', 'amax': 'SGM_r0.85_v-Baseline_1024x8000_amax', 'median': 'SGM_r0.85_v-Baseline_1024x8000_median', 'std': 'SGM_r0.85_v-Baseline_1024x8000_std', 'var': 'SGM_r0.85_v-Baseline_1024x8000_var'}
# Index(['SGM_r0.85_v-Baseline_1024x8000_step',
#        'SGM_r0.85_v-Baseline_1024x8000_mean',
#        'SGM_r0.85_v-Baseline_1024x8000_amin',
#        'SGM_r0.85_v-Baseline_1024x8000_amax',
#        'SGM_r0.85_v-Baseline_1024x8000_median',
#        'SGM_r0.85_v-Baseline_1024x8000_std',
#        'SGM_r0.85_v-Baseline_1024x8000_var', 'wall_time'],
#       dtype='object')
# SGM_r0.85_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.85_v_step', 'mean': 'SGM_r0.85_v_mean', 'amin': 'SGM_r0.85_v_amin', 'amax': 'SGM_r0.85_v_amax', 'median': 'SGM_r0.85_v_median', 'std': 'SGM_r0.85_v_std', 'var': 'SGM_r0.85_v_var'}
# Index(['SGM_r0.85_v_step', 'SGM_r0.85_v_mean', 'SGM_r0.85_v_amin',
#        'SGM_r0.85_v_amax', 'SGM_r0.85_v_median', 'SGM_r0.85_v_std',
#        'SGM_r0.85_v_var', 'wall_time'],
#       dtype='object')
# SGM_r0.75_p-11-NV-Importance_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.75_p-11-NV-Importance_step', 'mean': 'SGM_r0.75_p-11-NV-Importance_mean', 'amin': 'SGM_r0.75_p-11-NV-Importance_amin', 'amax': 'SGM_r0.75_p-11-NV-Importance_amax', 'median': 'SGM_r0.75_p-11-NV-Importance_median', 'std': 'SGM_r0.75_p-11-NV-Importance_std', 'var': 'SGM_r0.75_p-11-NV-Importance_var'}
# Index(['SGM_r0.75_p-11-NV-Importance_step',
#        'SGM_r0.75_p-11-NV-Importance_mean',
#        'SGM_r0.75_p-11-NV-Importance_amin',
#        'SGM_r0.75_p-11-NV-Importance_amax',
#        'SGM_r0.75_p-11-NV-Importance_median',
#        'SGM_r0.75_p-11-NV-Importance_std', 'SGM_r0.75_p-11-NV-Importance_var',
#        'wall_time'],
#       dtype='object')
# SGM_r0.75_p-11-XuvYuv_lVcm_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.75_p-11-XuvYuv_lVcm_step', 'mean': 'SGM_r0.75_p-11-XuvYuv_lVcm_mean', 'amin': 'SGM_r0.75_p-11-XuvYuv_lVcm_amin', 'amax': 'SGM_r0.75_p-11-XuvYuv_lVcm_amax', 'median': 'SGM_r0.75_p-11-XuvYuv_lVcm_median', 'std': 'SGM_r0.75_p-11-XuvYuv_lVcm_std', 'var': 'SGM_r0.75_p-11-XuvYuv_lVcm_var'}
# Index(['SGM_r0.75_p-11-XuvYuv_lVcm_step', 'SGM_r0.75_p-11-XuvYuv_lVcm_mean',
#        'SGM_r0.75_p-11-XuvYuv_lVcm_amin', 'SGM_r0.75_p-11-XuvYuv_lVcm_amax',
#        'SGM_r0.75_p-11-XuvYuv_lVcm_median', 'SGM_r0.75_p-11-XuvYuv_lVcm_std',
#        'SGM_r0.75_p-11-XuvYuv_lVcm_var', 'wall_time'],
#       dtype='object')
# SGM_r0.75_p-Baseline_1024x8000_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.75_p-Baseline_1024x8000_step', 'mean': 'SGM_r0.75_p-Baseline_1024x8000_mean', 'amin': 'SGM_r0.75_p-Baseline_1024x8000_amin', 'amax': 'SGM_r0.75_p-Baseline_1024x8000_amax', 'median': 'SGM_r0.75_p-Baseline_1024x8000_median', 'std': 'SGM_r0.75_p-Baseline_1024x8000_std', 'var': 'SGM_r0.75_p-Baseline_1024x8000_var'}
# Index(['SGM_r0.75_p-Baseline_1024x8000_step',
#        'SGM_r0.75_p-Baseline_1024x8000_mean',
#        'SGM_r0.75_p-Baseline_1024x8000_amin',
#        'SGM_r0.75_p-Baseline_1024x8000_amax',
#        'SGM_r0.75_p-Baseline_1024x8000_median',
#        'SGM_r0.75_p-Baseline_1024x8000_std',
#        'SGM_r0.75_p-Baseline_1024x8000_var', 'wall_time'],
#       dtype='object')
# SGM_r0.75_p_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.75_p_step', 'mean': 'SGM_r0.75_p_mean', 'amin': 'SGM_r0.75_p_amin', 'amax': 'SGM_r0.75_p_amax', 'median': 'SGM_r0.75_p_median', 'std': 'SGM_r0.75_p_std', 'var': 'SGM_r0.75_p_var'}
# Index(['SGM_r0.75_p_step', 'SGM_r0.75_p_mean', 'SGM_r0.75_p_amin',
#        'SGM_r0.75_p_amax', 'SGM_r0.75_p_median', 'SGM_r0.75_p_std',
#        'SGM_r0.75_p_var', 'wall_time'],
#       dtype='object')
# SGM_r0.75_u-11-NV-Importance_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.75_u-11-NV-Importance_step', 'mean': 'SGM_r0.75_u-11-NV-Importance_mean', 'amin': 'SGM_r0.75_u-11-NV-Importance_amin', 'amax': 'SGM_r0.75_u-11-NV-Importance_amax', 'median': 'SGM_r0.75_u-11-NV-Importance_median', 'std': 'SGM_r0.75_u-11-NV-Importance_std', 'var': 'SGM_r0.75_u-11-NV-Importance_var'}
# Index(['SGM_r0.75_u-11-NV-Importance_step',
#        'SGM_r0.75_u-11-NV-Importance_mean',
#        'SGM_r0.75_u-11-NV-Importance_amin',
#        'SGM_r0.75_u-11-NV-Importance_amax',
#        'SGM_r0.75_u-11-NV-Importance_median',
#        'SGM_r0.75_u-11-NV-Importance_std', 'SGM_r0.75_u-11-NV-Importance_var',
#        'wall_time'],
#       dtype='object')
# SGM_r0.75_u-11-XuvYuv_lVcm_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.75_u-11-XuvYuv_lVcm_step', 'mean': 'SGM_r0.75_u-11-XuvYuv_lVcm_mean', 'amin': 'SGM_r0.75_u-11-XuvYuv_lVcm_amin', 'amax': 'SGM_r0.75_u-11-XuvYuv_lVcm_amax', 'median': 'SGM_r0.75_u-11-XuvYuv_lVcm_median', 'std': 'SGM_r0.75_u-11-XuvYuv_lVcm_std', 'var': 'SGM_r0.75_u-11-XuvYuv_lVcm_var'}
# Index(['SGM_r0.75_u-11-XuvYuv_lVcm_step', 'SGM_r0.75_u-11-XuvYuv_lVcm_mean',
#        'SGM_r0.75_u-11-XuvYuv_lVcm_amin', 'SGM_r0.75_u-11-XuvYuv_lVcm_amax',
#        'SGM_r0.75_u-11-XuvYuv_lVcm_median', 'SGM_r0.75_u-11-XuvYuv_lVcm_std',
#        'SGM_r0.75_u-11-XuvYuv_lVcm_var', 'wall_time'],
#       dtype='object')
# SGM_r0.75_u-Baseline_1024x8000_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.75_u-Baseline_1024x8000_step', 'mean': 'SGM_r0.75_u-Baseline_1024x8000_mean', 'amin': 'SGM_r0.75_u-Baseline_1024x8000_amin', 'amax': 'SGM_r0.75_u-Baseline_1024x8000_amax', 'median': 'SGM_r0.75_u-Baseline_1024x8000_median', 'std': 'SGM_r0.75_u-Baseline_1024x8000_std', 'var': 'SGM_r0.75_u-Baseline_1024x8000_var'}
# Index(['SGM_r0.75_u-Baseline_1024x8000_step',
#        'SGM_r0.75_u-Baseline_1024x8000_mean',
#        'SGM_r0.75_u-Baseline_1024x8000_amin',
#        'SGM_r0.75_u-Baseline_1024x8000_amax',
#        'SGM_r0.75_u-Baseline_1024x8000_median',
#        'SGM_r0.75_u-Baseline_1024x8000_std',
#        'SGM_r0.75_u-Baseline_1024x8000_var', 'wall_time'],
#       dtype='object')
# SGM_r0.75_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.75_u_step', 'mean': 'SGM_r0.75_u_mean', 'amin': 'SGM_r0.75_u_amin', 'amax': 'SGM_r0.75_u_amax', 'median': 'SGM_r0.75_u_median', 'std': 'SGM_r0.75_u_std', 'var': 'SGM_r0.75_u_var'}
# Index(['SGM_r0.75_u_step', 'SGM_r0.75_u_mean', 'SGM_r0.75_u_amin',
#        'SGM_r0.75_u_amax', 'SGM_r0.75_u_median', 'SGM_r0.75_u_std',
#        'SGM_r0.75_u_var', 'wall_time'],
#       dtype='object')
# SGM_r0.75_v-11-NV-Importance_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.75_v-11-NV-Importance_step', 'mean': 'SGM_r0.75_v-11-NV-Importance_mean', 'amin': 'SGM_r0.75_v-11-NV-Importance_amin', 'amax': 'SGM_r0.75_v-11-NV-Importance_amax', 'median': 'SGM_r0.75_v-11-NV-Importance_median', 'std': 'SGM_r0.75_v-11-NV-Importance_std', 'var': 'SGM_r0.75_v-11-NV-Importance_var'}
# Index(['SGM_r0.75_v-11-NV-Importance_step',
#        'SGM_r0.75_v-11-NV-Importance_mean',
#        'SGM_r0.75_v-11-NV-Importance_amin',
#        'SGM_r0.75_v-11-NV-Importance_amax',
#        'SGM_r0.75_v-11-NV-Importance_median',
#        'SGM_r0.75_v-11-NV-Importance_std', 'SGM_r0.75_v-11-NV-Importance_var',
#        'wall_time'],
#       dtype='object')
# SGM_r0.75_v-11-XuvYuv_lVcm_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.75_v-11-XuvYuv_lVcm_step', 'mean': 'SGM_r0.75_v-11-XuvYuv_lVcm_mean', 'amin': 'SGM_r0.75_v-11-XuvYuv_lVcm_amin', 'amax': 'SGM_r0.75_v-11-XuvYuv_lVcm_amax', 'median': 'SGM_r0.75_v-11-XuvYuv_lVcm_median', 'std': 'SGM_r0.75_v-11-XuvYuv_lVcm_std', 'var': 'SGM_r0.75_v-11-XuvYuv_lVcm_var'}
# Index(['SGM_r0.75_v-11-XuvYuv_lVcm_step', 'SGM_r0.75_v-11-XuvYuv_lVcm_mean',
#        'SGM_r0.75_v-11-XuvYuv_lVcm_amin', 'SGM_r0.75_v-11-XuvYuv_lVcm_amax',
#        'SGM_r0.75_v-11-XuvYuv_lVcm_median', 'SGM_r0.75_v-11-XuvYuv_lVcm_std',
#        'SGM_r0.75_v-11-XuvYuv_lVcm_var', 'wall_time'],
#       dtype='object')
# SGM_r0.75_v-Baseline_1024x8000_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.75_v-Baseline_1024x8000_step', 'mean': 'SGM_r0.75_v-Baseline_1024x8000_mean', 'amin': 'SGM_r0.75_v-Baseline_1024x8000_amin', 'amax': 'SGM_r0.75_v-Baseline_1024x8000_amax', 'median': 'SGM_r0.75_v-Baseline_1024x8000_median', 'std': 'SGM_r0.75_v-Baseline_1024x8000_std', 'var': 'SGM_r0.75_v-Baseline_1024x8000_var'}
# Index(['SGM_r0.75_v-Baseline_1024x8000_step',
#        'SGM_r0.75_v-Baseline_1024x8000_mean',
#        'SGM_r0.75_v-Baseline_1024x8000_amin',
#        'SGM_r0.75_v-Baseline_1024x8000_amax',
#        'SGM_r0.75_v-Baseline_1024x8000_median',
#        'SGM_r0.75_v-Baseline_1024x8000_std',
#        'SGM_r0.75_v-Baseline_1024x8000_var', 'wall_time'],
#       dtype='object')
# SGM_r0.75_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SGM_r0.75_v_step', 'mean': 'SGM_r0.75_v_mean', 'amin': 'SGM_r0.75_v_amin', 'amax': 'SGM_r0.75_v_amax', 'median': 'SGM_r0.75_v_median', 'std': 'SGM_r0.75_v_std', 'var': 'SGM_r0.75_v_var'}
# Index(['SGM_r0.75_v_step', 'SGM_r0.75_v_mean', 'SGM_r0.75_v_amin',
#        'SGM_r0.75_v_amax', 'SGM_r0.75_v_median', 'SGM_r0.75_v_std',
#        'SGM_r0.75_v_var', 'wall_time'],
#       dtype='object')

# %%
dataframes[0]
agNames
# Out:
# ['SGM_Ablation_1024']

# %%
#plot step series p
plotVars_p_allValidators = [[f'{subfolders[0]}_{j}_p_step'] + [f'{i}_{j}_p_mean' for i in subfolders ] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
sFilter = 150000
stepFilter = dataframes[0][f'{subfolders[0]}_r1.0_p_step'] >= sFilter
def set_cycler(ax):
    ax.set_prop_cycle(plt.cycler('color', ['r', 'b', 'g', 'c'])+
                      plt.cycler('linestyle', ['-','--',':','-.'])+
                      plt.cycler('marker', ['.','*','^','x']))
    
def set_cycler(ax):
    ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'g','r'])+
                      plt.cycler('linestyle', ['-','--',':',':','-.'])+
                      plt.cycler('marker', ['x','1','^','d','x']))
    
def set_cycler(ax):
    ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
                      plt.cycler('linestyle', ['-.','--',':','-'])+
                      plt.cycler('marker', ['x','1','^',2]))

mSize=12


plotVar = 'p'
font2 = {'family':'serif','color':'black','size':20}
manualLegend_p = [[f'{j}_{i}_{plotVar}' for j in legendNames] for i in validatorsRename.values()] ##UPDATE
manualLegend_p_agg = [f'{j}_{plotVar}' for j in legendNames] ##UPDATE

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (20,5))
    #fig.suptitle(f'P step series for {agNames[i]}')
    plt.rc('legend', fontsize = 12)
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        axes[k].tick_params(axis='both', labelsize=18)
        print(f'{[(l,dataframes[i][j][l][99]) for l in dataframes[i][j]]}')
        dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k], markersize=mSize)
        axes[k].set_xlabel(j[0].split('_')[0]+str(j[0].split('_')[-3:-1]), fontdict=font2)
        axes[k].legend(manualLegend_p[k])

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (9,5))
    #fig.suptitle(f'P step series for {agNames[i]}')
    axes.set_ylabel('l2_relative_error')
    fig.suptitle(f'P Step Series for {agNames[i]}')
    for k in range(1,len(plotVars_p_allValidators[0])):
        set_cycler(axes)
        axes.ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        dataframes[i][f'{subfolders[k-1]}_p_mean'] = dataframes[i][[plotVars_p_allValidators[q][k] for q in range(len(plotVars_p_allValidators))]].mean(axis=1)
    dataframes[i][[plotVars_p_allValidators[0][0]]+[f'{subfolders[k-1]}_p_mean' for k in range(1,len(plotVars_p_allValidators[0]))]][stepFilter].plot(x=plotVars_p_allValidators[0][0],ax=axes, markersize=mSize)
    axes.legend(manualLegend_p_agg)

# for i in range(len(dataframes)):
#     fig, axes = plt.subplots(nrows=2, ncols=2, figsize = (20,16))
#     #fig.suptitle(f'P step series for {agNames[i]}')
#     plt.rc('legend', fontsize = 12)
#     axes = axes.flatten()
#     axes[0].set_ylabel('l2_relative_error', fontdict=font2)
#     for k,j in enumerate(plotVars_p_allValidators):
#         set_cycler(axes[k])
#         axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
#         axes[k].tick_params(axis='both', labelsize=18)
#         print(f'{[(l,dataframes[i][j][l][99]) for l in dataframes[i][j]]}')
#         dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k],markersize=10)
#         axes[k].set_xlabel('Step_'+str(j[0].split('_')[-3:-1]), fontdict=font2)
#         #axes[k].legend(manualLegend)


#     axes[3].set_ylabel('l2_relative_error')
#     for k in range(1,len(plotVars_p_allValidators[0])):
#         set_cycler(axes[3])
#         axes[3].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
#         dataframes[i][f'{subfolders[k-1]}_p_mean'] = dataframes[i][[plotVars_p_allValidators[q][k] for q in range(len(plotVars_p_allValidators))]].mean(axis=1)
#     dataframes[i][[plotVars_p_allValidators[0][0]]+[f'{subfolders[k-1]}_p_mean' for k in range(1,len(plotVars_p_allValidators[0]))]][stepFilter].plot(x=plotVars_p_allValidators[0][0],ax=axes[3], markersize=10)
#     axes[3].set_xlabel('Step_[mean,p]', fontdict=font2)
#     #axes[3].legend(manualLegend_agg)
# Out:
# [['Baseline_1024x8000_r1.0_p_step', 'Baseline_1024x8000_r1.0_p_mean', '11-XuvYuv_lVcm_r1.0_p_mean', '11-NV-Importance_r1.0_p_mean', 'SGM_r1.0_p_mean'], ['Baseline_1024x8000_r0.85_p_step', 'Baseline_1024x8000_r0.85_p_mean', '11-XuvYuv_lVcm_r0.85_p_mean', '11-NV-Importance_r0.85_p_mean', 'SGM_r0.85_p_mean'], ['Baseline_1024x8000_r0.75_p_step', 'Baseline_1024x8000_r0.75_p_mean', '11-XuvYuv_lVcm_r0.75_p_mean', '11-NV-Importance_r0.75_p_mean', 'SGM_r0.75_p_mean']]
# [('Baseline_1024x8000_r1.0_p_step', 350000), ('Baseline_1024x8000_r1.0_p_mean', 0.1268444657325744), ('11-XuvYuv_lVcm_r1.0_p_mean', 0.0814367964863777), ('11-NV-Importance_r1.0_p_mean', 0.1035114035010337), ('SGM_r1.0_p_mean', 0.1125239789485931)]
# [('Baseline_1024x8000_r0.85_p_step', 350000), ('Baseline_1024x8000_r0.85_p_mean', 0.1204461902379989), ('11-XuvYuv_lVcm_r0.85_p_mean', 0.120225803554058), ('11-NV-Importance_r0.85_p_mean', 0.1433752417564392), ('SGM_r0.85_p_mean', 0.111414135992527)]
# [('Baseline_1024x8000_r0.75_p_step', 350000), ('Baseline_1024x8000_r0.75_p_mean', 0.1516331523656845), ('11-XuvYuv_lVcm_r0.75_p_mean', 0.1455007761716842), ('11-NV-Importance_r0.75_p_mean', 0.1689057826995849), ('SGM_r0.75_p_mean', 0.1427079677581787)]
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+

# %%
#plot step series u
plotVars_p_allValidators = [[f'{subfolders[0]}_{j}_u_step'] + [f'{i}_{j}_u_mean' for i in subfolders ] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
stepFilter = dataframes[0][f'{subfolders[0]}_r1.0_u_step'] >= sFilter
#fmt = '[marker][line][color]' linestyle='--', marker='o', color='b'
#fmts = ['-r','--*b',':^g','-.xc']
#formats = {'marker':['.','*','^','x'], 'linestyle':['-','--',':','-.'], 'color':['r','b','g','c']}

plotVar = 'u'
font2 = {'family':'serif','color':'black','size':20}
manualLegend_u = [[f'{j}_{i}_{plotVar}' for j in legendNames] for i in validatorsRename.values()] ##UPDATE
manualLegend_u_agg = [f'{j}_{plotVar}' for j in legendNames] ##UPDATE

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (20,5))
    #fig.suptitle(f'P step series for {agNames[i]}')
    plt.rc('legend', fontsize = 12)
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        axes[k].tick_params(axis='both', labelsize=18)
        print(f'{[(l,dataframes[i][j][l][99]) for l in dataframes[i][j]]}')
        dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k], markersize=mSize)
        axes[k].set_xlabel(j[0].split('_')[0]+str(j[0].split('_')[-3:-1]), fontdict=font2)
        axes[k].legend(manualLegend_u[k])

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (9,5))
    fig.suptitle(f'U step series for {agNames[i]}')
    axes.set_ylabel('l2_relative_error')
    for k in range(1,len(plotVars_p_allValidators[0])):
        set_cycler(axes)
        axes.ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        dataframes[i][f'{subfolders[k-1]}_u_mean'] = dataframes[i][[plotVars_p_allValidators[q][k] for q in range(len(plotVars_p_allValidators))]].mean(axis=1)
    dataframes[i][[plotVars_p_allValidators[0][0]]+[f'{subfolders[k-1]}_u_mean' for k in range(1,len(plotVars_p_allValidators[0]))]][stepFilter].plot(x=plotVars_p_allValidators[0][0],ax=axes, markersize=mSize)
    axes.legend(manualLegend_u_agg)
# Out:
# [['Baseline_1024x8000_r1.0_u_step', 'Baseline_1024x8000_r1.0_u_mean', '11-XuvYuv_lVcm_r1.0_u_mean', '11-NV-Importance_r1.0_u_mean', 'SGM_r1.0_u_mean'], ['Baseline_1024x8000_r0.85_u_step', 'Baseline_1024x8000_r0.85_u_mean', '11-XuvYuv_lVcm_r0.85_u_mean', '11-NV-Importance_r0.85_u_mean', 'SGM_r0.85_u_mean'], ['Baseline_1024x8000_r0.75_u_step', 'Baseline_1024x8000_r0.75_u_mean', '11-XuvYuv_lVcm_r0.75_u_mean', '11-NV-Importance_r0.75_u_mean', 'SGM_r0.75_u_mean']]
# [('Baseline_1024x8000_r1.0_u_step', 350000), ('Baseline_1024x8000_r1.0_u_mean', 0.0446045771241188), ('11-XuvYuv_lVcm_r1.0_u_mean', 0.0275111079216003), ('11-NV-Importance_r1.0_u_mean', 0.0299384668469429), ('SGM_r1.0_u_mean', 0.0414610333740711)]
# [('Baseline_1024x8000_r0.85_u_step', 350000), ('Baseline_1024x8000_r0.85_u_mean', 0.025067726150155), ('11-XuvYuv_lVcm_r0.85_u_mean', 0.0259526498615741), ('11-NV-Importance_r0.85_u_mean', 0.0292544934898614), ('SGM_r0.85_u_mean', 0.0243789933621883)]
# [('Baseline_1024x8000_r0.75_u_step', 350000), ('Baseline_1024x8000_r0.75_u_mean', 0.0295439541339874), ('11-XuvYuv_lVcm_r0.75_u_mean', 0.0311481025069952), ('11-NV-Importance_r0.75_u_mean', 0.0325848661363124), ('SGM_r0.75_u_mean', 0.0281620681285858)]
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+

# %%
#plot step series v 
plotVars_p_allValidators = [[f'{subfolders[0]}_{j}_v_step'] + [f'{i}_{j}_v_mean' for i in subfolders ] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
stepFilter = dataframes[0][f'{subfolders[0]}_r1.0_v_step'] >= sFilter
#fmt = '[marker][line][color]' linestyle='--', marker='o', color='b'
#fmts = ['-r','--*b',':^g','-.xc']
#formats = {'marker':['.','*','^','x'], 'linestyle':['-','--',':','-.'], 'color':['r','b','g','c']}

plotVar = 'v'
font2 = {'family':'serif','color':'black','size':20}
manualLegend_v = [[f'{j}_{i}_{plotVar}' for j in legendNames] for i in validatorsRename.values()] ##UPDATE
manualLegend_v_agg = [f'{j}_{plotVar}' for j in legendNames] ##UPDATE

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (20,5))
    #fig.suptitle(f'P step series for {agNames[i]}')
    plt.rc('legend', fontsize = 12)
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        axes[k].tick_params(axis='both', labelsize=18)
        print(f'{[(l,dataframes[i][j][l][99]) for l in dataframes[i][j]]}')
        dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k], markersize=mSize)
        axes[k].set_xlabel(j[0].split('_')[0]+str(j[0].split('_')[-3:-1]), fontdict=font2)
        axes[k].legend(manualLegend_v[k])

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (9,5))
    fig.suptitle(f'V Step Series for {agNames[i]}')
    axes.set_ylabel('l2_relative_error')
    for k in range(1,len(plotVars_p_allValidators[0])):
        set_cycler(axes)
        axes.ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        dataframes[i][f'{subfolders[k-1]}_v_mean'] = dataframes[i][[plotVars_p_allValidators[q][k] for q in range(len(plotVars_p_allValidators))]].mean(axis=1)
    dataframes[i][[plotVars_p_allValidators[0][0]]+[f'{subfolders[k-1]}_v_mean' for k in range(1,len(plotVars_p_allValidators[0]))]][stepFilter].plot(x=plotVars_p_allValidators[0][0],ax=axes, markersize=mSize)
    axes.legend(manualLegend_v_agg)
# Out:
# [['Baseline_1024x8000_r1.0_v_step', 'Baseline_1024x8000_r1.0_v_mean', '11-XuvYuv_lVcm_r1.0_v_mean', '11-NV-Importance_r1.0_v_mean', 'SGM_r1.0_v_mean'], ['Baseline_1024x8000_r0.85_v_step', 'Baseline_1024x8000_r0.85_v_mean', '11-XuvYuv_lVcm_r0.85_v_mean', '11-NV-Importance_r0.85_v_mean', 'SGM_r0.85_v_mean'], ['Baseline_1024x8000_r0.75_v_step', 'Baseline_1024x8000_r0.75_v_mean', '11-XuvYuv_lVcm_r0.75_v_mean', '11-NV-Importance_r0.75_v_mean', 'SGM_r0.75_v_mean']]
# [('Baseline_1024x8000_r1.0_v_step', 350000), ('Baseline_1024x8000_r1.0_v_mean', 0.0342695988714695), ('11-XuvYuv_lVcm_r1.0_v_mean', 0.0257783200591802), ('11-NV-Importance_r1.0_v_mean', 0.0260727193206548), ('SGM_r1.0_v_mean', 0.031511041522026)]
# [('Baseline_1024x8000_r0.85_v_step', 350000), ('Baseline_1024x8000_r0.85_v_mean', 0.0238293837755918), ('11-XuvYuv_lVcm_r0.85_v_mean', 0.0238916806876659), ('11-NV-Importance_r0.85_v_mean', 0.0245715096592903), ('SGM_r0.85_v_mean', 0.0236802715808153)]
# [('Baseline_1024x8000_r0.75_v_step', 350000), ('Baseline_1024x8000_r0.75_v_mean', 0.0319689460098743), ('11-XuvYuv_lVcm_r0.75_v_mean', 0.0325191795825958), ('11-NV-Importance_r0.75_v_mean', 0.0328353092074394), ('SGM_r0.75_v_mean', 0.0309961412101984)]
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+

# %%
subfolders[slice(0,2)]
# Out:
# ['Baseline_1024x8000', '11-XuvYuv_lVcm']

# %%
#plot time series p
plotVar = 'p'
plotVars_p_allValidators = [[(f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
ylims = [(.11,.17),(.07,.14),(.08,.17)]
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (20,5))
    #fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    ylims = [(.04,.17),(.07,.17),(.07,.17)]
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        if ylims[k] != ():
            axes[k].set_ylim(*ylims[k])
        axes[k].set_xlim((.5,5))
        #axes[k].set_ylim(*ylims[k])
        for l in j:
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
            rawdat[rawdat[l[0]] >= .7].plot(x=l[0],y=l[1],ax=axes[k], markersize=mSize)
            axes[k].set_xlabel('Wall Time (h)', fontdict=font2)
            axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
            axes[k].tick_params(axis='both', labelsize=18)
            print(l)
            time = [(q) for q in dataframes[i][l[0]]]
            print(f'{(time[-1]-time[1])/60/60}')
        axes[k].legend(manualLegend_p[k])

#plot time series p averaged
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (7,5))
    #fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes.set_ylabel('l2_relative_error', fontdict=font2)
    axes.ticklabel_format(axis='x', style='sci',scilimits=(0,0))
    axes.tick_params(axis='both', labelsize=18)
    axes.set_xlim((1,5))
    axes.set_ylim((.07,.14))
    set_cycler(axes)
    for k,j in enumerate(plotVars_p_allValidators[0]): ##k is 0-3
        l = [plotVars_p_allValidators[j][k] for j in range(len(plotVars_p_allValidators))]
        l = [l[0][0]] + [j[1] for j in l]
        #print('###############################')
        #print(l)
        rawdat = dataframes[i][l]
        rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
        rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
        rawdat[rawdat[l[0]] >= .7].plot(x=l[0],y=f'{subfolders[k]}_{plotVar}_mean',ax=axes, markersize=mSize)
        time = [(q) for q in dataframes[i][l[0]]]
        print(f'{(time[-1]-time[1])/60/60}')
        axes.set_xlabel('Wall Time (h)', fontdict=font2)
        axes.legend(manualLegend_p_agg)
# Out:
# [[('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r1.0_p_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_p_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r1.0_p_mean'), ('SGM_wall_time', 'SGM_r1.0_p_mean')], [('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.85_p_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.85_p_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r0.85_p_mean'), ('SGM_wall_time', 'SGM_r0.85_p_mean')], [('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.75_p_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.75_p_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r0.75_p_mean'), ('SGM_wall_time', 'SGM_r0.75_p_mean')]]
# ('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r1.0_p_mean')
# 3.0414336313141717
# ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_p_mean')
# 4.0283036708169515
# ('11-NV-Importance_wall_time', '11-NV-Importance_r1.0_p_mean')
# 4.69313878721661
# ('SGM_wall_time', 'SGM_r1.0_p_mean')
# 4.69313878721661
# ('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.85_p_mean')
# 3.0414336313141717
# ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.85_p_mean')
# 4.0283036708169515
# ('11-NV-Importance_wall_time', '11-NV-Importance_r0.85_p_mean')
# 4.69313878721661
# ('SGM_wall_time', 'SGM_r0.85_p_mean')
# 4.69313878721661
# ('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.75_p_mean')
# 3.0414336313141717
# ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.75_p_mean')
# 4.0283036708169515
# ('11-NV-Importance_wall_time', '11-NV-Importance_r0.75_p_mean')
# 4.69313878721661
# ('SGM_wall_time', 'SGM_r0.75_p_mean')
# 4.69313878721661
# 3.0414336313141717
# 4.0283036708169515
# 4.69313878721661
# 4.69313878721661
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3733100599.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)

# %%
#plot time series u
plotVar = 'u'
plotVars_p_allValidators = [[(f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
#set plotVar to uppercase
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (20,5))
    #fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    ylims = [(.025,.055),(.02,.04),(.02,.04)]
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        if ylims[k] != ():
            axes[k].set_ylim(*ylims[k])
        axes[k].set_xlim((1,6))
        #axes[k].set_ylim(*ylims[k])
        for l in j:
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
            rawdat[rawdat[l[0]] >= .7].plot(x=l[0],y=l[1],ax=axes[k], markersize=mSize)
            axes[k].set_xlabel('Wall Time (h)', fontdict=font2)
            axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
            axes[k].tick_params(axis='both', labelsize=18)
        axes[k].legend(manualLegend_u[k])

#plot time series u averaged
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (7,5))
    #fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes.set_ylabel('l2_relative_error', fontdict=font2)
    axes.ticklabel_format(axis='x', style='sci',scilimits=(0,0))
    axes.tick_params(axis='both', labelsize=18)
    axes.set_xlim((1,5))
    axes.set_ylim((.024,.04))
    set_cycler(axes)
    for k,j in enumerate(plotVars_p_allValidators[0]): ##k is 0-3
        l = [plotVars_p_allValidators[j][k] for j in range(len(plotVars_p_allValidators))]
        l = [l[0][0]] + [j[1] for j in l]
        #print('###############################')
        #print(l)
        rawdat = dataframes[i][l]
        rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
        rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
        rawdat[rawdat[l[0]] >= .7].plot(x=l[0],y=f'{subfolders[k]}_{plotVar}_mean',ax=axes, markersize=mSize)
        time = [(q) for q in dataframes[i][l[0]]]
        print(f'{(time[-1]-time[1])/60/60}')
        axes.set_xlabel('Wall Time (h)', fontdict=font2)
        axes.legend(manualLegend_u_agg)
# Out:
# [[('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r1.0_u_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_u_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r1.0_u_mean'), ('SGM_wall_time', 'SGM_r1.0_u_mean')], [('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.85_u_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.85_u_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r0.85_u_mean'), ('SGM_wall_time', 'SGM_r0.85_u_mean')], [('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.75_u_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.75_u_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r0.75_u_mean'), ('SGM_wall_time', 'SGM_r0.75_u_mean')]]
# 3.0414336313141717
# 4.0283036708169515
# 4.69313878721661
# 4.69313878721661
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\3665281623.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)

# %%
#plot time series v
plotVar = 'v'
plotVars_p_allValidators = [[(f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
#set plotVar to uppercase
#ylims = [(.022,.05),(.022,.05),(.022,.05)]
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize = (20,5))
    #fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    ylims = [(.023,.038),(.023,.026),(.030,.033)]
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        if ylims[k] != ():
            axes[k].set_ylim(*ylims[k])
        axes[k].set_xlim((1,6))
        #axes[k].set_ylim(*ylims[k])
        for l in j:
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
            rawdat[rawdat[l[0]] >= .7].plot(x=l[0],y=l[1],ax=axes[k], markersize=mSize)
            axes[k].set_xlabel('Wall Time (h)', fontdict=font2)
            axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
            axes[k].tick_params(axis='both', labelsize=15)
        axes[k].legend(manualLegend_v[k])


#plot time series v averaged
for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (7,5))
    #fig.suptitle(f'{str.upper(plotVar)} time series for {agNames[i]}')
    axes.set_ylabel('l2_relative_error', fontdict=font2)
    axes.ticklabel_format(axis='x', style='sci',scilimits=(0,0))
    axes.tick_params(axis='both', labelsize=18)
    axes.set_xlim((1,5))
    axes.set_ylim((.024,.030))
    set_cycler(axes)
    for k,j in enumerate(plotVars_p_allValidators[0]): ##k is 0-3
        l = [plotVars_p_allValidators[j][k] for j in range(len(plotVars_p_allValidators))]
        l = [l[0][0]] + [j[1] for j in l]
        #print('###############################')
        #print(l)
        rawdat = dataframes[i][l]
        rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
        rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
        rawdat[rawdat[l[0]] >= 1.1].plot(x=l[0],y=f'{subfolders[k]}_{plotVar}_mean',ax=axes, markersize=mSize)
        time = [(q) for q in dataframes[i][l[0]]]
        print(f'{(time[-1]-time[1])/60/60}')
        axes.set_xlabel('Wall Time (h)', fontdict=font2)
        axes.legend(manualLegend_v_agg)
# Out:
# [[('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r1.0_v_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r1.0_v_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r1.0_v_mean'), ('SGM_wall_time', 'SGM_r1.0_v_mean')], [('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.85_v_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.85_v_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r0.85_v_mean'), ('SGM_wall_time', 'SGM_r0.85_v_mean')], [('Baseline_1024x8000_wall_time', 'Baseline_1024x8000_r0.75_v_mean'), ('11-XuvYuv_lVcm_wall_time', '11-XuvYuv_lVcm_r0.75_v_mean'), ('11-NV-Importance_wall_time', '11-NV-Importance_r0.75_v_mean'), ('SGM_wall_time', 'SGM_r0.75_v_mean')]]
# 3.0414336313141717
# 4.0283036708169515
# 4.69313878721661
# 4.69313878721661
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\220530659.py:17: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'c'])+
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_35080\918150441.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat[f'{subfolders[k]}_{plotVar}_mean'] = dataframes[i][l[1:]].mean(axis=1)

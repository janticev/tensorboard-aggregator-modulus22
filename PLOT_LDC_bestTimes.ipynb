# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

variablesKey = 'Validators'
variablesSplit = 'l2_relative_error_'
validatorsRename = {'validator':'Validator'}
variablesID = 'validator'
#TODO get subfolders automatically
subfolders = ['Uniform_500','SPADE_500','MIS_500','Uniform_4000']

# run aggregates with these subfoldetrs
#folder = 'C:/Users/jacec/Documents/Test_Runs/'
folder = 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/'
#folder = 'C:/Users/jacec/OneDrive - stevens.edu/4_DATA/Aggregator_Runs/'
#aggregates = [folder+f+'/aggregates/' for f in os.listdir(folder) if os.path.isdir(folder+f)][0:1]
aggregates = [folder+f+'/aggregates/' for f in ['ldc'] if os.path.isdir(folder+f)]
#all results will be in /aggregates, separated by tags from subfolders
#find all validation files separated by subfolder
files = []
#for i in aggregates:
#    csvs_by_testcase = [[i + g for g in os.listdir(i) if (g.endswith('.csv')) and (variablesKey in g) and (f in g)] for f in subfolders]
#    files = files+[i for i in csvs_by_testcase if i]
files = [[i+g for g in os.listdir(i) if g.endswith('.csv') and (variablesKey in g)] for i in aggregates]
#files = [[aggregates + g for g in os.listdir(aggregates) if ('.csv' in g) and (f in g)] for f in subfolders] 
#list of lists of the files for each individual aggregation
#Go through sub-list, load into dataframes with descriptive columns
#Find unique variables, create sub-frames with them in a format for plotting

# %%
files
# Out:
# [['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_nu-MIS_500-ldc.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_nu-SPADE_500-ldc.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_nu-Uniform_4000-ldc.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_nu-Uniform_500-ldc.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_u-MIS_500-ldc.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_u-SPADE_500-ldc.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_u-Uniform_4000-ldc.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_u-Uniform_500-ldc.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_v-MIS_500-ldc.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_v-SPADE_500-ldc.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_v-Uniform_4000-ldc.csv',
#   'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_v-Uniform_500-ldc.csv']]

# %%
#each aggregate becomes one dataframe
#extract common variable names (validator, validator_n, uvpvnu)
#load into df with descriptive columns, uses 'subfolder' name, validator name, variable name
dataframes = []
agNames = []
for aggregation in files:
    dfs = []
    agName = aggregation[0].split('/aggregates/')[0].split('/')[-1]
    for testName in subfolders:
        subtests = [csv for csv in aggregation if testName in csv]
        if not subtests:
            continue
        print(subtests)
        for k,i in enumerate(subtests):
            validatorName = i.split(variablesKey)[1].split(variablesSplit)[0]
            vv = i.split(variablesSplit)[1].split('-'+testName)[0]
            variableName = f'{testName}_{validatorsRename[validatorName]}_{vv}_'
            print(variableName)
            #df = pd.read_csv(i, index_col = 0, delimiter=';')
            df = pd.read_csv(i, delimiter=';')
            oldcols = df.keys()
            print(oldcols)
            #mapping = {i:variableName+i for i in oldcols[0:-1]}
            mapping = {'Unnamed: 0':variableName+'step'}
            if k == 0:
                mapping.update({'wall_time':testName+'_wall_time'})
            mapping.update({i:variableName+i for i in oldcols[1:-1]})
            print(mapping)
            df.rename(columns=mapping, inplace=True)
            newcols = df.keys()
            print(newcols)
            if k > 0:
                df.drop(columns='wall_time')
            dfs.append(df)
    df = pd.concat(dfs, axis=1)
    df = df.loc[:,~df.columns.duplicated()].copy() #drop duplicates based on column name alone
    #append to dataframes list
    dataframes.append(df)
    agNames.append(agName)
# Out:
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_nu-Uniform_500-ldc.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_u-Uniform_500-ldc.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_v-Uniform_500-ldc.csv']
# Uniform_500_Validator_nu_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Uniform_500_Validator_nu_step', 'wall_time': 'Uniform_500_wall_time', 'mean': 'Uniform_500_Validator_nu_mean', 'amin': 'Uniform_500_Validator_nu_amin', 'amax': 'Uniform_500_Validator_nu_amax', 'median': 'Uniform_500_Validator_nu_median', 'std': 'Uniform_500_Validator_nu_std', 'var': 'Uniform_500_Validator_nu_var'}
# Index(['Uniform_500_Validator_nu_step', 'Uniform_500_Validator_nu_mean',
#        'Uniform_500_Validator_nu_amin', 'Uniform_500_Validator_nu_amax',
#        'Uniform_500_Validator_nu_median', 'Uniform_500_Validator_nu_std',
#        'Uniform_500_Validator_nu_var', 'Uniform_500_wall_time'],
#       dtype='object')
# Uniform_500_Validator_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Uniform_500_Validator_u_step', 'mean': 'Uniform_500_Validator_u_mean', 'amin': 'Uniform_500_Validator_u_amin', 'amax': 'Uniform_500_Validator_u_amax', 'median': 'Uniform_500_Validator_u_median', 'std': 'Uniform_500_Validator_u_std', 'var': 'Uniform_500_Validator_u_var'}
# Index(['Uniform_500_Validator_u_step', 'Uniform_500_Validator_u_mean',
#        'Uniform_500_Validator_u_amin', 'Uniform_500_Validator_u_amax',
#        'Uniform_500_Validator_u_median', 'Uniform_500_Validator_u_std',
#        'Uniform_500_Validator_u_var', 'wall_time'],
#       dtype='object')
# Uniform_500_Validator_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Uniform_500_Validator_v_step', 'mean': 'Uniform_500_Validator_v_mean', 'amin': 'Uniform_500_Validator_v_amin', 'amax': 'Uniform_500_Validator_v_amax', 'median': 'Uniform_500_Validator_v_median', 'std': 'Uniform_500_Validator_v_std', 'var': 'Uniform_500_Validator_v_var'}
# Index(['Uniform_500_Validator_v_step', 'Uniform_500_Validator_v_mean',
#        'Uniform_500_Validator_v_amin', 'Uniform_500_Validator_v_amax',
#        'Uniform_500_Validator_v_median', 'Uniform_500_Validator_v_std',
#        'Uniform_500_Validator_v_var', 'wall_time'],
#       dtype='object')
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_nu-SPADE_500-ldc.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_u-SPADE_500-ldc.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_v-SPADE_500-ldc.csv']
# SPADE_500_Validator_nu_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SPADE_500_Validator_nu_step', 'wall_time': 'SPADE_500_wall_time', 'mean': 'SPADE_500_Validator_nu_mean', 'amin': 'SPADE_500_Validator_nu_amin', 'amax': 'SPADE_500_Validator_nu_amax', 'median': 'SPADE_500_Validator_nu_median', 'std': 'SPADE_500_Validator_nu_std', 'var': 'SPADE_500_Validator_nu_var'}
# Index(['SPADE_500_Validator_nu_step', 'SPADE_500_Validator_nu_mean',
#        'SPADE_500_Validator_nu_amin', 'SPADE_500_Validator_nu_amax',
#        'SPADE_500_Validator_nu_median', 'SPADE_500_Validator_nu_std',
#        'SPADE_500_Validator_nu_var', 'SPADE_500_wall_time'],
#       dtype='object')
# SPADE_500_Validator_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SPADE_500_Validator_u_step', 'mean': 'SPADE_500_Validator_u_mean', 'amin': 'SPADE_500_Validator_u_amin', 'amax': 'SPADE_500_Validator_u_amax', 'median': 'SPADE_500_Validator_u_median', 'std': 'SPADE_500_Validator_u_std', 'var': 'SPADE_500_Validator_u_var'}
# Index(['SPADE_500_Validator_u_step', 'SPADE_500_Validator_u_mean',
#        'SPADE_500_Validator_u_amin', 'SPADE_500_Validator_u_amax',
#        'SPADE_500_Validator_u_median', 'SPADE_500_Validator_u_std',
#        'SPADE_500_Validator_u_var', 'wall_time'],
#       dtype='object')
# SPADE_500_Validator_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'SPADE_500_Validator_v_step', 'mean': 'SPADE_500_Validator_v_mean', 'amin': 'SPADE_500_Validator_v_amin', 'amax': 'SPADE_500_Validator_v_amax', 'median': 'SPADE_500_Validator_v_median', 'std': 'SPADE_500_Validator_v_std', 'var': 'SPADE_500_Validator_v_var'}
# Index(['SPADE_500_Validator_v_step', 'SPADE_500_Validator_v_mean',
#        'SPADE_500_Validator_v_amin', 'SPADE_500_Validator_v_amax',
#        'SPADE_500_Validator_v_median', 'SPADE_500_Validator_v_std',
#        'SPADE_500_Validator_v_var', 'wall_time'],
#       dtype='object')
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_nu-MIS_500-ldc.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_u-MIS_500-ldc.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_v-MIS_500-ldc.csv']
# MIS_500_Validator_nu_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'MIS_500_Validator_nu_step', 'wall_time': 'MIS_500_wall_time', 'mean': 'MIS_500_Validator_nu_mean', 'amin': 'MIS_500_Validator_nu_amin', 'amax': 'MIS_500_Validator_nu_amax', 'median': 'MIS_500_Validator_nu_median', 'std': 'MIS_500_Validator_nu_std', 'var': 'MIS_500_Validator_nu_var'}
# Index(['MIS_500_Validator_nu_step', 'MIS_500_Validator_nu_mean',
#        'MIS_500_Validator_nu_amin', 'MIS_500_Validator_nu_amax',
#        'MIS_500_Validator_nu_median', 'MIS_500_Validator_nu_std',
#        'MIS_500_Validator_nu_var', 'MIS_500_wall_time'],
#       dtype='object')
# MIS_500_Validator_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'MIS_500_Validator_u_step', 'mean': 'MIS_500_Validator_u_mean', 'amin': 'MIS_500_Validator_u_amin', 'amax': 'MIS_500_Validator_u_amax', 'median': 'MIS_500_Validator_u_median', 'std': 'MIS_500_Validator_u_std', 'var': 'MIS_500_Validator_u_var'}
# Index(['MIS_500_Validator_u_step', 'MIS_500_Validator_u_mean',
#        'MIS_500_Validator_u_amin', 'MIS_500_Validator_u_amax',
#        'MIS_500_Validator_u_median', 'MIS_500_Validator_u_std',
#        'MIS_500_Validator_u_var', 'wall_time'],
#       dtype='object')
# MIS_500_Validator_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'MIS_500_Validator_v_step', 'mean': 'MIS_500_Validator_v_mean', 'amin': 'MIS_500_Validator_v_amin', 'amax': 'MIS_500_Validator_v_amax', 'median': 'MIS_500_Validator_v_median', 'std': 'MIS_500_Validator_v_std', 'var': 'MIS_500_Validator_v_var'}
# Index(['MIS_500_Validator_v_step', 'MIS_500_Validator_v_mean',
#        'MIS_500_Validator_v_amin', 'MIS_500_Validator_v_amax',
#        'MIS_500_Validator_v_median', 'MIS_500_Validator_v_std',
#        'MIS_500_Validator_v_var', 'wall_time'],
#       dtype='object')
# ['C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_nu-Uniform_4000-ldc.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_u-Uniform_4000-ldc.csv', 'C:/Users/John Anticev/Documents/SCHOOL/aggregator_runs/ldc/aggregates/Validatorsvalidatorl2_relative_error_v-Uniform_4000-ldc.csv']
# Uniform_4000_Validator_nu_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Uniform_4000_Validator_nu_step', 'wall_time': 'Uniform_4000_wall_time', 'mean': 'Uniform_4000_Validator_nu_mean', 'amin': 'Uniform_4000_Validator_nu_amin', 'amax': 'Uniform_4000_Validator_nu_amax', 'median': 'Uniform_4000_Validator_nu_median', 'std': 'Uniform_4000_Validator_nu_std', 'var': 'Uniform_4000_Validator_nu_var'}
# Index(['Uniform_4000_Validator_nu_step', 'Uniform_4000_Validator_nu_mean',
#        'Uniform_4000_Validator_nu_amin', 'Uniform_4000_Validator_nu_amax',
#        'Uniform_4000_Validator_nu_median', 'Uniform_4000_Validator_nu_std',
#        'Uniform_4000_Validator_nu_var', 'Uniform_4000_wall_time'],
#       dtype='object')
# Uniform_4000_Validator_u_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Uniform_4000_Validator_u_step', 'mean': 'Uniform_4000_Validator_u_mean', 'amin': 'Uniform_4000_Validator_u_amin', 'amax': 'Uniform_4000_Validator_u_amax', 'median': 'Uniform_4000_Validator_u_median', 'std': 'Uniform_4000_Validator_u_std', 'var': 'Uniform_4000_Validator_u_var'}
# Index(['Uniform_4000_Validator_u_step', 'Uniform_4000_Validator_u_mean',
#        'Uniform_4000_Validator_u_amin', 'Uniform_4000_Validator_u_amax',
#        'Uniform_4000_Validator_u_median', 'Uniform_4000_Validator_u_std',
#        'Uniform_4000_Validator_u_var', 'wall_time'],
#       dtype='object')
# Uniform_4000_Validator_v_
# Index(['Unnamed: 0', 'mean', 'amin', 'amax', 'median', 'std', 'var',
#        'wall_time'],
#       dtype='object')
# {'Unnamed: 0': 'Uniform_4000_Validator_v_step', 'mean': 'Uniform_4000_Validator_v_mean', 'amin': 'Uniform_4000_Validator_v_amin', 'amax': 'Uniform_4000_Validator_v_amax', 'median': 'Uniform_4000_Validator_v_median', 'std': 'Uniform_4000_Validator_v_std', 'var': 'Uniform_4000_Validator_v_var'}
# Index(['Uniform_4000_Validator_v_step', 'Uniform_4000_Validator_v_mean',
#        'Uniform_4000_Validator_v_amin', 'Uniform_4000_Validator_v_amax',
#        'Uniform_4000_Validator_v_median', 'Uniform_4000_Validator_v_std',
#        'Uniform_4000_Validator_v_var', 'wall_time'],
#       dtype='object')

# %%
dataframes[0]
# Out:
#     Uniform_500_Validator_nu_step  Uniform_500_Validator_nu_mean  \
# 0                           16000                       1.254211
# 1                           70000                       1.131567
# 2                          154000                       1.115846
# 3                          160000                       1.114677
# 4                          287000                       0.935159
# ..                            ...                            ...
# 95                        2418000                       0.218009
# 96                        2428000                       0.217923
# 97                        2439000                       0.217856
# 98                        2445000                       0.217631
# 99                        2500000                       0.217287
#
#     Uniform_500_Validator_nu_amin  Uniform_500_Validator_nu_amax  \
# 0                        1.254211                       1.254211
# 1                        1.131567                       1.131567
# 2                        1.115846                       1.115846
# 3                        1.114677                       1.114677
# 4                        0.935159                       0.935159
# ..                            ...                            ...
# 95                       0.218009                       0.218009
# 96                       0.217923                       0.217923
# 97                       0.217856                       0.217856
# 98                       0.217631                       0.217631
# 99                       0.217287                       0.217287
#
#     Uniform_500_Validator_nu_median  Uniform_500_Validator_nu_std  \
# 0                          1.254211                           0.0
# 1                          1.131567                           0.0
# 2                          1.115846                           0.0
# 3                          1.114677                           0.0
# 4                          0.935159                           0.0
# ..                              ...                           ...
# 95                         0.218009                           0.0
# 96                         0.217923                           0.0
# 97                         0.217856                           0.0
# 98                         0.217631                           0.0
# 99                         0.217287                           0.0
#
#     Uniform_500_Validator_nu_var  Uniform_500_wall_time  \
# 0                            0.0           1.686358e+09
# 1                            0.0           1.686359e+09
# 2                            0.0           1.686361e+09
# 3                            0.0           1.686361e+09
# 4                            0.0           1.686365e+09
# ..                           ...                    ...
# 95                           0.0           1.686419e+09
# 96                           0.0           1.686419e+09
# 97                           0.0           1.686419e+09
# 98                           0.0           1.686420e+09
# 99                           0.0           1.686421e+09
#
#     Uniform_500_Validator_u_step  Uniform_500_Validator_u_mean  ...  \
# 0                          16000                      0.604409  ...
# 1                          70000                      0.593512  ...
# 2                         154000                      0.593664  ...
# 3                         160000                      0.592931  ...
# 4                         287000                      0.448405  ...
# ..                           ...                           ...  ...
# 95                       2418000                      0.088147  ...
# 96                       2428000                      0.088216  ...
# 97                       2439000                      0.088257  ...
# 98                       2445000                      0.087945  ...
# 99                       2500000                      0.088055  ...
#
#     Uniform_4000_Validator_u_median  Uniform_4000_Validator_u_std  \
# 0                          0.600004                      0.002754
# 1                          0.488526                      0.000758
# 2                          0.364053                      0.091155
# 3                          0.362719                      0.055793
# 4                          0.176974                      0.006293
# ..                              ...                           ...
# 95                         0.051840                      0.000421
# 96                         0.051779                      0.000447
# 97                         0.051823                      0.000456
# 98                         0.051926                      0.000449
# 99                         0.051881                      0.000441
#
#     Uniform_4000_Validator_u_var  Uniform_4000_Validator_v_step  \
# 0                   7.585221e-06                          16000
# 1                   5.749642e-07                          70000
# 2                   8.309274e-03                         154000
# 3                   3.112817e-03                         160000
# 4                   3.960683e-05                         287000
# ..                           ...                            ...
# 95                  1.768298e-07                        2418000
# 96                  2.000452e-07                        2428000
# 97                  2.080296e-07                        2439000
# 98                  2.013023e-07                        2445000
# 99                  1.945616e-07                        2500000
#
#     Uniform_4000_Validator_v_mean  Uniform_4000_Validator_v_amin  \
# 0                        0.847834                       0.837847
# 1                        0.656025                       0.652703
# 2                        0.571993                       0.475264
# 3                        0.531404                       0.479258
# 4                        0.224978                       0.210293
# ..                            ...                            ...
# 95                       0.063450                       0.063165
# 96                       0.063486                       0.063186
# 97                       0.063506                       0.063151
# 98                       0.063464                       0.063167
# 99                       0.063593                       0.063261
#
#     Uniform_4000_Validator_v_amax  Uniform_4000_Validator_v_median  \
# 0                        0.852828                         0.852828
# 1                        0.657686                         0.657686
# 2                        0.765450                         0.475264
# 3                        0.635696                         0.479258
# 4                        0.232321                         0.232321
# ..                            ...                              ...
# 95                       0.064020                         0.063165
# 96                       0.064085                         0.063186
# 97                       0.064214                         0.063151
# 98                       0.064057                         0.063167
# 99                       0.064255                         0.063261
#
#     Uniform_4000_Validator_v_std  Uniform_4000_Validator_v_var
# 0                       0.007062                  4.987521e-05
# 1                       0.002349                  5.518388e-06
# 2                       0.136795                  1.871293e-02
# 3                       0.073745                  5.438385e-03
# 4                       0.010384                  1.078296e-04
# ..                           ...                           ...
# 95                      0.000403                  1.624580e-07
# 96                      0.000424                  1.796040e-07
# 97                      0.000501                  2.510921e-07
# 98                      0.000420                  1.762263e-07
# 99                      0.000469                  2.195819e-07
#
# [100 rows x 89 columns]

# %%
plotVar = 'nu'
#plot step series p
plotVars_p_allValidators = [[(f'{i}_{j}_{plotVar}_step',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
stepFilter = dataframes[0][f'{subfolders[0]}_Validator_nu_step'] >= 150000
def set_cycler(ax):
    ax.set_prop_cycle(plt.cycler('color', ['r', 'b', 'g', 'c'])+
                      plt.cycler('linestyle', ['-','--',':','-.'])+
                      plt.cycler('marker', ['.','*','^','x']))
    
def set_cycler(ax):
    ax.set_prop_cycle(plt.cycler('color', ['c', 'b', 'g', 'r'])+
                      plt.cycler('linestyle', ['-','--',':','-.'])+
                      plt.cycler('marker', ['x','1','^','x']))
    
def set_cycler(ax):
    ax.set_prop_cycle(plt.cycler('color', ['k', 'b', 'g', 'r'])+
                      plt.cycler('linestyle', ['-.','--',':','-'])+
                      plt.cycler('marker', ['x','1','^','x']))
    
font2 = {'family':'serif','color':'black','size':20}
manualLegend = ['Uniform_500_nu','SGM-PINN_500_nu','MIS_500_nu','Uniform_4000_nu']
legendloc = 'best'
legendfontsize = 15

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize = (20,7))
    #fig.suptitle(f'P step series for {agNames[i]}')
    plt.rc('legend', fontsize = 12)
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        print(j)
        axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        axes[k].tick_params(axis='both', labelsize=18)
        #print(f'{[(l,dataframes[i][j][l][99]) for l in dataframes[i][j]]}')
        for l in j:
            #print(l)
            rawdat = dataframes[i][list(l)]
            #print(rawdat)
            rawdat.plot(x=l[0],y=l[1],ax=axes[k],markersize=10)
        #dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k], markersize=10)
        axes[k].set_ylim((.15,.5))
        axes[k].set_xlim((.5,2.5e6))
        axes[k].set_xlabel('Step_'+str(l[0].split('_')[-2]), fontdict=font2)
        axes[k].legend(manualLegend, loc = legendloc, fontsize = legendfontsize)
    plotVars_p_allValidators = [[(f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
    for kk,j in enumerate(plotVars_p_allValidators):
        k = kk+1
        set_cycler(axes[k])
        axes[k].set_ylim((.15,.5))
        axes[k].set_xlim((.5,17.5))
        for l in j:
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
            rawdat[rawdat[l[0]] >= .7].plot(x=l[0],y=l[1],ax=axes[k],markersize=10)
            axes[k].set_xlabel(f'Wall_time_{plotVar} (h)', fontdict=font2)
            axes[k].ticklabel_format(axis='x', style='plain',scilimits=(0,0)) #whats the code for numeric? 
            #axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0)) is for sci, but not for numeric
            #axes[k].ticklabel_format(axis='x', style='plain',scilimits=(0,0)) 
            axes[k].tick_params(axis='both', labelsize=18)
            #print(l)
            time = [(q) for q in dataframes[i][l[0]]]
            #print(f'{(time[-1]-time[1])/60/60}')
        axes[k].legend(manualLegend, loc = legendloc, fontsize = legendfontsize)

plotVars_p_allValidators = [[(f'{i}_{j}_{plotVar}_step',f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
for i in range(len(dataframes)):
    for k,j in enumerate(plotVars_p_allValidators):
        minimums = []
        for l in j:
            print(l)
            tm = []
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
            print('## min')
            tm.append(rawdat.min()[2])
            print(rawdat.min()[2])
            print('--idxmin')
            tm.append(rawdat.idxmin()[2])
            print(rawdat.idxmin()[2])
            print('-- loc')
            tm.append(rawdat.loc[rawdat.idxmin()[2],l[1]])
            print(rawdat.loc[rawdat.idxmin()[2],l[1]])
            minimums.append(tm)
        print(minimums)
# Out:
# [[('Uniform_500_Validator_nu_step', 'Uniform_500_Validator_nu_mean'), ('SPADE_500_Validator_nu_step', 'SPADE_500_Validator_nu_mean'), ('MIS_500_Validator_nu_step', 'MIS_500_Validator_nu_mean'), ('Uniform_4000_Validator_nu_step', 'Uniform_4000_Validator_nu_mean')]]
# [('Uniform_500_Validator_nu_step', 'Uniform_500_Validator_nu_mean'), ('SPADE_500_Validator_nu_step', 'SPADE_500_Validator_nu_mean'), ('MIS_500_Validator_nu_step', 'MIS_500_Validator_nu_mean'), ('Uniform_4000_Validator_nu_step', 'Uniform_4000_Validator_nu_mean')]
# [[('Uniform_500_Validator_nu_step', 'Uniform_500_wall_time', 'Uniform_500_Validator_nu_mean'), ('SPADE_500_Validator_nu_step', 'SPADE_500_wall_time', 'SPADE_500_Validator_nu_mean'), ('MIS_500_Validator_nu_step', 'MIS_500_wall_time', 'MIS_500_Validator_nu_mean'), ('Uniform_4000_Validator_nu_step', 'Uniform_4000_wall_time', 'Uniform_4000_Validator_nu_mean')]]
# ('Uniform_500_Validator_nu_step', 'Uniform_500_wall_time', 'Uniform_500_Validator_nu_mean')
# ## min
# 0.2172871679067611
# --idxmin
# 99
# -- loc
# 17.608412399556904
# ('SPADE_500_Validator_nu_step', 'SPADE_500_wall_time', 'SPADE_500_Validator_nu_mean')
# ## min
# 0.1595473140478134
# --idxmin
# 81
# -- loc
# 15.085723130438062
# ('MIS_500_Validator_nu_step', 'MIS_500_wall_time', 'MIS_500_Validator_nu_mean')
# ## min
# 0.173452208439509
# --idxmin
# 61
# -- loc
# 28.714321345157092
# ('Uniform_4000_Validator_nu_step', 'Uniform_4000_wall_time', 'Uniform_4000_Validator_nu_mean')
# ## min
# 0.1788267791271209
# --idxmin
# 36
# -- loc
# 35.2302660589748
# [[0.2172871679067611, 99, 17.608412399556904], [0.1595473140478134, 81, 15.085723130438062], [0.173452208439509, 61, 28.714321345157092], [0.1788267791271209, 36, 35.2302660589748]]
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\1689776360.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\1689776360.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\1689776360.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\1689776360.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\1689776360.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\1689776360.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\1689776360.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\1689776360.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60

# %%
plotVar = 'u'
#plot step series u
plotVars_p_allValidators = [[(f'{i}_{j}_{plotVar}_step',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
    
font2 = {'family':'serif','color':'black','size':20}
manualLegend = ['Uniform_500_u','SGM-PINN_500_u','MIS_500_u','Uniform_4000_u']

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize = (20,7))
    #fig.suptitle(f'P step series for {agNames[i]}')
    plt.rc('legend', fontsize = 12)
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        #print(j)
        axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        axes[k].tick_params(axis='both', labelsize=18)
        #print(f'{[(l,dataframes[i][j][l][99]) for l in dataframes[i][j]]}')
        for l in j:
            #print(l)
            rawdat = dataframes[i][list(l)]
            #print(rawdat)
            rawdat.plot(x=l[0],y=l[1],ax=axes[k],markersize=10)
        #dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k], markersize=10)
        axes[k].set_ylim((.03,.3))
        axes[k].set_xlim((.5,2.5e6))
        #axes[k].set_xlabel(l[0].split('_')[0]+str(l[0].split('_')[-3:-1]), fontdict=font2)
        axes[k].set_xlabel('Step_'+str(l[0].split('_')[-2]), fontdict=font2)
        axes[k].legend(manualLegend, loc = legendloc, fontsize = legendfontsize)
    plotVars_p_allValidators = [[(f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
    for kk,j in enumerate(plotVars_p_allValidators):
        k = kk+1
        set_cycler(axes[k])
        #axes[k].set_ylim((.15,.5))
        axes[k].set_xlim((.5,17.5))
        for l in j:
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
            rawdat[rawdat[l[0]] >= .7].plot(x=l[0],y=l[1],ax=axes[k],markersize=10)
            axes[k].set_xlabel(f'Wall_time_{plotVar} (h)', fontdict=font2)
            axes[k].ticklabel_format(axis='x', style='plain',scilimits=(0,0)) #whats the code for numeric? 
            #axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0)) is for sci, but not for numeric
            #axes[k].ticklabel_format(axis='x', style='plain',scilimits=(0,0)) 
            axes[k].tick_params(axis='both', labelsize=18)
            #print(l)
            time = [(q) for q in dataframes[i][l[0]]]
            #print(f'{(time[-1]-time[1])/60/60}')
        axes[k].legend(manualLegend, loc = legendloc, fontsize = legendfontsize)

plotVars_p_allValidators = [[(f'{i}_{j}_{plotVar}_step',f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
for i in range(len(dataframes)):
    for k,j in enumerate(plotVars_p_allValidators):
        minimums = []
        for l in j:
            print(l)
            tm = []
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
            print('## min')
            tm.append(rawdat.min()[2])
            print(rawdat.min()[2])
            print('--idxmin')
            tm.append(rawdat.idxmin()[2])
            print(rawdat.idxmin()[2])
            print('-- loc')
            tm.append(rawdat.loc[rawdat.idxmin()[2],l[1]])
            print(rawdat.loc[rawdat.idxmin()[2],l[1]])
            minimums.append(tm)
        print(minimums)
        
meanFilter = dataframes[0][f'SPADE_500_Validator_u_mean'] <= minimums[-1][0]
rawdat = dataframes[0][['SPADE_500_wall_time',f'SPADE_500_Validator_u_mean']]
rawdat.loc[:,'SPADE_500_wall_time'] = (rawdat.loc[:,'SPADE_500_wall_time'] - rawdat.loc[0,'SPADE_500_wall_time'])/60/60
rawdat = rawdat[meanFilter]
print(rawdat)

meanFilter = dataframes[0][f'SPADE_500_Validator_u_mean'] <= minimums[-2][0]
rawdat = dataframes[0][['SPADE_500_wall_time',f'SPADE_500_Validator_u_mean']]
rawdat.loc[:,'SPADE_500_wall_time'] = (rawdat.loc[:,'SPADE_500_wall_time'] - rawdat.loc[0,'SPADE_500_wall_time'])/60/60
rawdat = rawdat[meanFilter]
print(rawdat)

meanFilter = dataframes[0][f'MIS_500_Validator_u_mean'] <= minimums[-1][0]
rawdat = dataframes[0][['MIS_500_wall_time',f'MIS_500_Validator_u_mean']]
rawdat.loc[:,'MIS_500_wall_time'] = (rawdat.loc[:,'MIS_500_wall_time'] - rawdat.loc[0,'MIS_500_wall_time'])/60/60
rawdat = rawdat[meanFilter]
print(rawdat)
# Out:
# [[('Uniform_500_Validator_u_step', 'Uniform_500_Validator_u_mean'), ('SPADE_500_Validator_u_step', 'SPADE_500_Validator_u_mean'), ('MIS_500_Validator_u_step', 'MIS_500_Validator_u_mean'), ('Uniform_4000_Validator_u_step', 'Uniform_4000_Validator_u_mean')]]
# [[('Uniform_500_Validator_u_step', 'Uniform_500_wall_time', 'Uniform_500_Validator_u_mean'), ('SPADE_500_Validator_u_step', 'SPADE_500_wall_time', 'SPADE_500_Validator_u_mean'), ('MIS_500_Validator_u_step', 'MIS_500_wall_time', 'MIS_500_Validator_u_mean'), ('Uniform_4000_Validator_u_step', 'Uniform_4000_wall_time', 'Uniform_4000_Validator_u_mean')]]
# ('Uniform_500_Validator_u_step', 'Uniform_500_wall_time', 'Uniform_500_Validator_u_mean')
# ## min
# 0.0879449769854545
# --idxmin
# 98
# -- loc
# 17.217366598910754
# ('SPADE_500_Validator_u_step', 'SPADE_500_wall_time', 'SPADE_500_Validator_u_mean')
# ## min
# 0.0412139346202214
# --idxmin
# 90
# -- loc
# 16.914500046041276
# ('MIS_500_Validator_u_step', 'MIS_500_wall_time', 'MIS_500_Validator_u_mean')
# ## min
# 0.0431266613304615
# --idxmin
# 49
# -- loc
# 24.192824234366416
# ('Uniform_4000_Validator_u_step', 'Uniform_4000_wall_time', 'Uniform_4000_Validator_u_mean')
# ## min
# 0.0479689165949821
# --idxmin
# 34
# -- loc
# 32.54940717511707
# [[0.0879449769854545, 98, 17.217366598910754], [0.0412139346202214, 90, 16.914500046041276], [0.0431266613304615, 49, 24.192824234366416], [0.0479689165949821, 34, 32.54940717511707]]
#     SPADE_500_wall_time  SPADE_500_Validator_u_mean
# 38             9.477203                    0.047823
# 39             9.623364                    0.047061
# 40             9.790640                    0.047482
# 41             9.811784                    0.046718
# 42             9.948775                    0.046479
# ..                  ...                         ...
# 95            18.180778                    0.041276
# 96            18.261572                    0.041270
# 97            18.341128                    0.041310
# 98            18.383890                    0.041269
# 99            18.875672                    0.041756
#
# [62 rows x 2 columns]
#     SPADE_500_wall_time  SPADE_500_Validator_u_mean
# 51            11.257167                    0.042451
# 52            11.323975                    0.042380
# 53            11.453596                    0.042733
# 55            11.731432                    0.042867
# 56            11.833070                    0.042916
# 57            11.978893                    0.042055
# 58            12.059042                    0.042632
# 59            12.246742                    0.041848
# 60            12.508647                    0.041543
# 61            12.552200                    0.041637
# 62            12.908609                    0.041898
# 63            12.944356                    0.041965
# 64            12.975133                    0.042008
# 65            13.307449                    0.041450
# 66            13.359012                    0.041432
# 67            13.509621                    0.041334
# 68            13.633406                    0.041532
# 69            13.640518                    0.041694
# 70            13.772506                    0.041349
# 71            13.815916                    0.041364
# 72            13.975546                    0.041546
# 73            13.997145                    0.041502
# 74            14.090531                    0.041639
# 75            14.099590                    0.041584
# 76            14.106475                    0.041592
# 77            14.192233                    0.041681
# 78            14.540604                    0.041536
# 79            14.598153                    0.041560
# 80            14.716119                    0.041567
# 81            15.085723                    0.041214
# 82            15.114148                    0.041225
# 83            15.222508                    0.041428
# 84            15.593626                    0.041358
# 85            15.827416                    0.041405
# 86            16.183357                    0.041352
# 87            16.247848                    0.041649
# 88            16.298459                    0.041632
# 89            16.756296                    0.041227
# 90            16.914500                    0.041214
# 91            16.937929                    0.041266
# 92            17.206313                    0.041555
# 93            17.480900                    0.041506
# 94            17.496724                    0.041444
# 95            18.180778                    0.041276
# 96            18.261572                    0.041270
# 97            18.341128                    0.041310
# 98            18.383890                    0.041269
# 99            18.875672                    0.041756
#     MIS_500_wall_time  MIS_500_Validator_u_mean
# 31          16.531639                  0.046395
# 32          17.873369                  0.045114
# 33          17.893182                  0.044596
# 34          17.968347                  0.044937
# 35          18.005373                  0.044661
# ..                ...                       ...
# 95          43.361627                  0.044068
# 96          43.565964                  0.044065
# 97          43.790797                  0.044094
# 98          43.913450                  0.044046
# 99          45.037755                  0.044177
#
# [69 rows x 2 columns]
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\812068118.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\812068118.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\812068118.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\812068118.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\812068118.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\812068118.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\812068118.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\812068118.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\812068118.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,'SPADE_500_wall_time'] = (rawdat.loc[:,'SPADE_500_wall_time'] - rawdat.loc[0,'SPADE_500_wall_time'])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\812068118.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,'SPADE_500_wall_time'] = (rawdat.loc[:,'SPADE_500_wall_time'] - rawdat.loc[0,'SPADE_500_wall_time'])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\812068118.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,'MIS_500_wall_time'] = (rawdat.loc[:,'MIS_500_wall_time'] - rawdat.loc[0,'MIS_500_wall_time'])/60/60

# %%
plotVar = 'v'
#plot step series v
plotVars_p_allValidators = [[(f'{i}_{j}_{plotVar}_step',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
    
font2 = {'family':'serif','color':'black','size':20}
manualLegend = ['Uniform_500_v','SGM-PINN_500_v','MIS_500_v','Uniform_4000_v']

for i in range(len(dataframes)):
    fig, axes = plt.subplots(nrows=2, ncols=1, figsize = (7,12))
    #fig.suptitle(f'P step series for {agNames[i]}')
    plt.rc('legend', fontsize = 12)
    axes[0].set_ylabel('l2_relative_error', fontdict=font2)
    for k,j in enumerate(plotVars_p_allValidators):
        set_cycler(axes[k])
        print(j)
        axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0))
        axes[k].tick_params(axis='both', labelsize=18)
        #print(f'{[(l,dataframes[i][j][l][99]) for l in dataframes[i][j]]}')
        for l in j:
            print(l)
            rawdat = dataframes[i][list(l)]
            print(rawdat)
            rawdat.plot(x=l[0],y=l[1],ax=axes[k],markersize=10)
        #dataframes[i][j][stepFilter].plot(x=j[0],ax=axes[k], markersize=10)
        axes[k].set_ylim((.05,.15))
        axes[k].set_xlim((.5,2.5e6))
        #axes[k].set_xlabel(l[0].split('_')[0]+str(l[0].split('_')[-3:-1]), fontdict=font2)
        axes[k].set_xlabel('Step_'+str(l[0].split('_')[-2]), fontdict=font2)
        axes[k].legend(manualLegend, loc = legendloc, fontsize = legendfontsize)
    plotVars_p_allValidators = [[(f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
    for kk,j in enumerate(plotVars_p_allValidators):
        k = kk+1
        axes[k].set_ylabel('l2_relative_error', fontdict=font2)
        set_cycler(axes[k])
        axes[k].set_ylim((.05,.4))
        axes[k].set_xlim((.5,20))
        for l in j:
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
            rawdat[rawdat[l[0]] >= .7].plot(x=l[0],y=l[1],ax=axes[k],markersize=10)
            axes[k].set_xlabel(f'Wall_time_{plotVar} (h)', fontdict=font2)
            axes[k].ticklabel_format(axis='x', style='plain',scilimits=(0,0)) #whats the code for numeric? 
            #axes[k].ticklabel_format(axis='x', style='sci',scilimits=(0,0)) is for sci, but not for numeric
            #axes[k].ticklabel_format(axis='x', style='plain',scilimits=(0,0)) 
            axes[k].tick_params(axis='both', labelsize=18)
            print(l)
            time = [(q) for q in dataframes[i][l[0]]]
            print(f'{(time[-1]-time[1])/60/60}')
        axes[k].legend(manualLegend, loc = legendloc, fontsize = legendfontsize)

plotVars_p_allValidators = [[(f'{i}_{j}_{plotVar}_step',f'{i}_wall_time',f'{i}_{j}_{plotVar}_mean') for i in subfolders] for j in validatorsRename.values()]
print(plotVars_p_allValidators)
for i in range(len(dataframes)):
    for k,j in enumerate(plotVars_p_allValidators):
        minimums = []
        for l in j:
            print(l)
            tm = []
            rawdat = dataframes[i][list(l)]
            rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
            print('## min')
            tm.append(rawdat.min()[2])
            print(rawdat.min()[2])
            print('--idxmin')
            tm.append(rawdat.idxmin()[2])
            print(rawdat.idxmin()[2])
            print('-- loc')
            tm.append(rawdat.loc[rawdat.idxmin()[2],l[1]])
            print(rawdat.loc[rawdat.idxmin()[2],l[1]])
            minimums.append(tm)
        print(minimums)


meanFilter = dataframes[0][f'SPADE_500_Validator_{plotVar}_mean'] <= minimums[-1][0]
rawdat = dataframes[0][['SPADE_500_wall_time',f'SPADE_500_Validator_{plotVar}_mean']]
rawdat.loc[:,'SPADE_500_wall_time'] = (rawdat.loc[:,'SPADE_500_wall_time'] - rawdat.loc[0,'SPADE_500_wall_time'])/60/60
rawdat = rawdat[meanFilter]
print(rawdat)

meanFilter = dataframes[0][f'SPADE_500_Validator_{plotVar}_mean'] <= minimums[-2][0]
rawdat = dataframes[0][['SPADE_500_wall_time',f'SPADE_500_Validator_{plotVar}_mean']]
rawdat.loc[:,'SPADE_500_wall_time'] = (rawdat.loc[:,'SPADE_500_wall_time'] - rawdat.loc[0,'SPADE_500_wall_time'])/60/60
rawdat = rawdat[meanFilter]
print(rawdat)

meanFilter = dataframes[0][f'MIS_500_Validator_{plotVar}_mean'] <= minimums[-1][0]
rawdat = dataframes[0][['MIS_500_wall_time',f'MIS_500_Validator_{plotVar}_mean']]
rawdat.loc[:,'MIS_500_wall_time'] = (rawdat.loc[:,'MIS_500_wall_time'] - rawdat.loc[0,'MIS_500_wall_time'])/60/60
rawdat = rawdat[meanFilter]
print(rawdat)

meanFilter = dataframes[0][f'Uniform_4000_Validator_{plotVar}_mean'] <= minimums[-2][0]
rawdat = dataframes[0][['Uniform_4000_wall_time',f'Uniform_4000_Validator_{plotVar}_mean']]
rawdat.loc[:,'Uniform_4000_wall_time'] = (rawdat.loc[:,'Uniform_4000_wall_time'] - rawdat.loc[0,'Uniform_4000_wall_time'])/60/60
rawdat = rawdat[meanFilter]
print(rawdat)
# Out:
# [[('Uniform_500_Validator_v_step', 'Uniform_500_Validator_v_mean'), ('SPADE_500_Validator_v_step', 'SPADE_500_Validator_v_mean'), ('MIS_500_Validator_v_step', 'MIS_500_Validator_v_mean'), ('Uniform_4000_Validator_v_step', 'Uniform_4000_Validator_v_mean')]]
# [('Uniform_500_Validator_v_step', 'Uniform_500_Validator_v_mean'), ('SPADE_500_Validator_v_step', 'SPADE_500_Validator_v_mean'), ('MIS_500_Validator_v_step', 'MIS_500_Validator_v_mean'), ('Uniform_4000_Validator_v_step', 'Uniform_4000_Validator_v_mean')]
# ('Uniform_500_Validator_v_step', 'Uniform_500_Validator_v_mean')
#     Uniform_500_Validator_v_step  Uniform_500_Validator_v_mean
# 0                          16000                      0.915716
# 1                          70000                      0.819342
# 2                         154000                      0.802758
# 3                         160000                      0.803090
# 4                         287000                      0.593143
# ..                           ...                           ...
# 95                       2418000                      0.117498
# 96                       2428000                      0.117426
# 97                       2439000                      0.117436
# 98                       2445000                      0.117273
# 99                       2500000                      0.116866
#
# [100 rows x 2 columns]
# ('SPADE_500_Validator_v_step', 'SPADE_500_Validator_v_mean')
#     SPADE_500_Validator_v_step  SPADE_500_Validator_v_mean
# 0                        16000                    0.854215
# 1                        70000                    0.765836
# 2                       154000                    0.405204
# 3                       160000                    0.418402
# 4                       287000                    0.299515
# ..                         ...                         ...
# 95                     2418000                    0.057256
# 96                     2428000                    0.057317
# 97                     2439000                    0.057337
# 98                     2445000                    0.057325
# 99                     2500000                    0.057431
#
# [100 rows x 2 columns]
# ('MIS_500_Validator_v_step', 'MIS_500_Validator_v_mean')
#     MIS_500_Validator_v_step  MIS_500_Validator_v_mean
# 0                      16000                  0.834810
# 1                      70000                  0.646391
# 2                     154000                  0.476775
# 3                     160000                  0.461824
# 4                     287000                  0.288105
# ..                       ...                       ...
# 95                   2418000                  0.062613
# 96                   2428000                  0.062506
# 97                   2439000                  0.062648
# 98                   2445000                  0.062586
# 99                   2500000                  0.062550
#
# [100 rows x 2 columns]
# ('Uniform_4000_Validator_v_step', 'Uniform_4000_Validator_v_mean')
#     Uniform_4000_Validator_v_step  Uniform_4000_Validator_v_mean
# 0                           16000                       0.847834
# 1                           70000                       0.656025
# 2                          154000                       0.571993
# 3                          160000                       0.531404
# 4                          287000                       0.224978
# ..                            ...                            ...
# 95                        2418000                       0.063450
# 96                        2428000                       0.063486
# 97                        2439000                       0.063506
# 98                        2445000                       0.063464
# 99                        2500000                       0.063593
#
# [100 rows x 2 columns]
# ('Uniform_500_wall_time', 'Uniform_500_Validator_v_mean')
# 17.220614739722677
# ('SPADE_500_wall_time', 'SPADE_500_Validator_v_mean')
# 18.466642630431387
# ('MIS_500_wall_time', 'MIS_500_Validator_v_mean')
# 44.23684657116731
# ('Uniform_4000_wall_time', 'Uniform_4000_Validator_v_mean')
# 72.6281924986177
# [[('Uniform_500_Validator_v_step', 'Uniform_500_wall_time', 'Uniform_500_Validator_v_mean'), ('SPADE_500_Validator_v_step', 'SPADE_500_wall_time', 'SPADE_500_Validator_v_mean'), ('MIS_500_Validator_v_step', 'MIS_500_wall_time', 'MIS_500_Validator_v_mean'), ('Uniform_4000_Validator_v_step', 'Uniform_4000_wall_time', 'Uniform_4000_Validator_v_mean')]]
# ('Uniform_500_Validator_v_step', 'Uniform_500_wall_time', 'Uniform_500_Validator_v_mean')
# ## min
# 0.1168656423687934
# --idxmin
# 99
# -- loc
# 17.608412399556904
# ('SPADE_500_Validator_v_step', 'SPADE_500_wall_time', 'SPADE_500_Validator_v_mean')
# ## min
# 0.0572562490900357
# --idxmin
# 95
# -- loc
# 18.18077779372533
# ('MIS_500_Validator_v_step', 'MIS_500_wall_time', 'MIS_500_Validator_v_mean')
# ## min
# 0.0623317609230677
# --idxmin
# 82
# -- loc
# 35.287736807995365
# ('Uniform_4000_Validator_v_step', 'Uniform_4000_wall_time', 'Uniform_4000_Validator_v_mean')
# ## min
# 0.0589231389264265
# --idxmin
# 35
# -- loc
# 32.60977881901794
# [[0.1168656423687934, 99, 17.608412399556904], [0.0572562490900357, 95, 18.18077779372533], [0.0623317609230677, 82, 35.287736807995365], [0.0589231389264265, 35, 32.60977881901794]]
#     SPADE_500_wall_time  SPADE_500_Validator_v_mean
# 53            11.453596                    0.058772
# 57            11.978893                    0.058335
# 58            12.059042                    0.058659
# 59            12.246742                    0.058063
# 60            12.508647                    0.057812
# 61            12.552200                    0.058056
# 62            12.908609                    0.058245
# 63            12.944356                    0.058640
# 64            12.975133                    0.058260
# 65            13.307449                    0.058031
# 66            13.359012                    0.057934
# 67            13.509621                    0.057520
# 68            13.633406                    0.057815
# 69            13.640518                    0.057797
# 70            13.772506                    0.058003
# 71            13.815916                    0.057797
# 72            13.975546                    0.057879
# 73            13.997145                    0.058148
# 74            14.090531                    0.057960
# 75            14.099590                    0.057799
# 76            14.106475                    0.057895
# 77            14.192233                    0.058025
# 78            14.540604                    0.057799
# 79            14.598153                    0.057500
# 80            14.716119                    0.057512
# 81            15.085723                    0.057409
# 82            15.114148                    0.057493
# 83            15.222508                    0.057336
# 84            15.593626                    0.057394
# 85            15.827416                    0.057299
# 86            16.183357                    0.057456
# 87            16.247848                    0.057387
# 88            16.298459                    0.057423
# 89            16.756296                    0.057531
# 90            16.914500                    0.057322
# 91            16.937929                    0.057310
# 92            17.206313                    0.057536
# 93            17.480900                    0.057430
# 94            17.496724                    0.057564
# 95            18.180778                    0.057256
# 96            18.261572                    0.057317
# 97            18.341128                    0.057337
# 98            18.383890                    0.057325
# 99            18.875672                    0.057431
#     SPADE_500_wall_time  SPADE_500_Validator_v_mean
# 44            10.253970                    0.061606
# 45            10.268505                    0.060942
# 46            10.442795                    0.061133
# 47            10.479054                    0.061197
# 48            10.543919                    0.060751
# 49            10.755500                    0.060708
# 50            10.901388                    0.060165
# 51            11.257167                    0.059429
# 52            11.323975                    0.059250
# 53            11.453596                    0.058772
# 54            11.716152                    0.059291
# 55            11.731432                    0.059429
# 56            11.833070                    0.059771
# 57            11.978893                    0.058335
# 58            12.059042                    0.058659
# 59            12.246742                    0.058063
# 60            12.508647                    0.057812
# 61            12.552200                    0.058056
# 62            12.908609                    0.058245
# 63            12.944356                    0.058640
# 64            12.975133                    0.058260
# 65            13.307449                    0.058031
# 66            13.359012                    0.057934
# 67            13.509621                    0.057520
# 68            13.633406                    0.057815
# 69            13.640518                    0.057797
# 70            13.772506                    0.058003
# 71            13.815916                    0.057797
# 72            13.975546                    0.057879
# 73            13.997145                    0.058148
# 74            14.090531                    0.057960
# 75            14.099590                    0.057799
# 76            14.106475                    0.057895
# 77            14.192233                    0.058025
# 78            14.540604                    0.057799
# 79            14.598153                    0.057500
# 80            14.716119                    0.057512
# 81            15.085723                    0.057409
# 82            15.114148                    0.057493
# 83            15.222508                    0.057336
# 84            15.593626                    0.057394
# 85            15.827416                    0.057299
# 86            16.183357                    0.057456
# 87            16.247848                    0.057387
# 88            16.298459                    0.057423
# 89            16.756296                    0.057531
# 90            16.914500                    0.057322
# 91            16.937929                    0.057310
# 92            17.206313                    0.057536
# 93            17.480900                    0.057430
# 94            17.496724                    0.057564
# 95            18.180778                    0.057256
# 96            18.261572                    0.057317
# 97            18.341128                    0.057337
# 98            18.383890                    0.057325
# 99            18.875672                    0.057431
# Empty DataFrame
# Columns: [MIS_500_wall_time, MIS_500_Validator_v_mean]
# Index: []
#     Uniform_4000_wall_time  Uniform_4000_Validator_v_mean
# 31               30.227226                       0.059995
# 32               32.397258                       0.059488
# 33               32.428610                       0.059159
# 34               32.549407                       0.059609
# 35               32.609779                       0.058923
# 36               35.230266                       0.059073
# 37               36.285821                       0.059343
# 38               37.338816                       0.059255
# 39               37.911659                       0.059363
# 40               38.574101                       0.059545
# 41               38.663236                       0.059706
# 42               39.205471                       0.059918
# 43               39.566560                       0.059708
# 44               40.439516                       0.059960
# 45               40.499560                       0.060004
# 46               41.191025                       0.060511
# 47               41.342728                       0.060173
# 48               41.583668                       0.060046
# 49               42.425865                       0.060326
# 50               42.997069                       0.060674
# 51               44.413534                       0.060824
# 52               44.682971                       0.061220
# 53               45.195164                       0.060917
# 54               46.248404                       0.061281
# 55               46.308601                       0.061287
# 56               46.701055                       0.061289
# 57               47.304368                       0.061580
# 58               47.605500                       0.061452
# 59               48.357306                       0.061509
# 60               49.412056                       0.061652
# 61               49.592233                       0.061860
# 62               51.006448                       0.061938
# 63               51.126966                       0.062020
# 64               51.247880                       0.061858
# 65               52.606697                       0.062110
# 66               52.788270                       0.062292
# 67               53.391872                       0.062278
# 68               53.902936                       0.062297
# 69               53.934413                       0.062277
# 71               54.625937                       0.062296
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\2046470771.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\2046470771.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\2046470771.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\2046470771.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[0]] = (rawdat.loc[:,l[0]] - rawdat.loc[0,l[0]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\2046470771.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\2046470771.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\2046470771.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\2046470771.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,l[1]] = (rawdat.loc[:,l[1]] - rawdat.loc[0,l[1]])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\2046470771.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,'SPADE_500_wall_time'] = (rawdat.loc[:,'SPADE_500_wall_time'] - rawdat.loc[0,'SPADE_500_wall_time'])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\2046470771.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,'SPADE_500_wall_time'] = (rawdat.loc[:,'SPADE_500_wall_time'] - rawdat.loc[0,'SPADE_500_wall_time'])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\2046470771.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,'MIS_500_wall_time'] = (rawdat.loc[:,'MIS_500_wall_time'] - rawdat.loc[0,'MIS_500_wall_time'])/60/60
# C:\Users\John Anticev\AppData\Local\Temp\ipykernel_28944\2046470771.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdat.loc[:,'Uniform_4000_wall_time'] = (rawdat.loc[:,'Uniform_4000_wall_time'] - rawdat.loc[0,'Uniform_4000_wall_time'])/60/60
